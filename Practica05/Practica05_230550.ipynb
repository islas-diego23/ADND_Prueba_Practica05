# %% [markdown]
# ![](https://i.imgur.com/X6bTc7G.png)
#
# Un viaje visual y revelador - DonorsChoose
#
# ## Ciencia de datos para el bien social: DonorsChoose
#
# DonorsChoose es una organización sin fines de lucro con sede en Estados Unidos que permite a particulares donar directamente a proyectos para aulas de escuelas públicas. Para enero de 2018, DonorsChoose.org había financiado un millón de proyectos; de hecho, el 77 % de las escuelas públicas de Estados Unidos ha solicitado al menos un proyecto a través de esta plataforma. DonorsChoose ha compartido un conjunto de datos completo que incluye todos los proyectos anteriores y los recursos asociados, así como metadatos sobre docentes, escuelas, donantes y donaciones. Estos datos permiten extraer información valiosa y desarrollar una solución que posibilite a DonorsChoose.org crear campañas de correo electrónico dirigidas, recomendando solicitudes específicas de aulas a donantes anteriores. En este *notebook*, he realizado un análisis y una exploración exhaustivos del conjunto de datos compartido. Este documento no solo aporta información clave derivada de los datos de DonorsChoose, sino que también sirve como tutorial para llevar a cabo análisis de datos (incluido el análisis exploratorio) y visualizaciones de datos.
#
# ## Contenidos
#
# [1. Preparación del conjunto de datos](#1)
#
# [2. Explorando a los donantes](#2)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.1 Resumen de donantes](#2.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.2 Donantes de diferentes estados](#2.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.3 Estados con la mayor proporción de donantes por habitante ](#2.3)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.4 Visualizando donde se encuentran l@s donantes.](#2.5)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.1 Donde se encuentran las donantes en California](#2.4.1)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.2 Donde se encuentran las donantes en Florida](#2.4.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.3 Dónde se encuentran los donantes en Nueva York](#2.4.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.4 Donde se encuentran los donantes en Texas](#2.4.4)
# &thinsp;&thinsp; &thinsp;&thinsp; [2.5 Donde se encuentran las donantes](#2.5)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.6 Donantes docentes y no docentes de diferentes estados](#2.6)
#
# [3. Exploring the Donations](#3)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.1 Resumen de donaciones](#3.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.2 Proyectos y sus donaciones](#3.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.2.1 Proyectos con el mayor número de donantes](#3.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.2.2 Proyectos con el mayor monto total financiado](#3.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.2.3 Proyectos con el mayor monto promedio por donante](#3.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.2.4 Proyectos con la mayor donación individual](#3.2)
#  &thinsp;&thinsp;&thinsp;&thinsp; [3.3 Donantes y sus donaciones](#3.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.3.1 Donantes que han realizado el mayor número de donaciones](#3.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.3.2 Donantes que han aportado el mayor monto total](#3.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.3.3 Donantes con el mayor monto promedio por donación](#3.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.3.4 Donantes que han realizado la mayor donación individual](#3.3)
# &thinsp;&thinsp; &thinsp;&thinsp; [3.4 Montos de las donaciones por año, mes, día y hora](#3.4)
# &thinsp;&thinsp; &thinsp;&thinsp; [3.5 Donaciones opcionales y donaciones de docentes](#3.5)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.5.1 Número y monto promedio de las donaciones: donaciones opcionales](#3.5.1)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; &thinsp;&thinsp; [- 3.5.2 Número y monto promedio de las donaciones: donaciones de docentes](#3.5.2)
#  &thinsp;&thinsp; &thinsp;&thinsp; [3.6 ¿Qué estado ha recibido el mayor monto de donaciones?](#3.6)
#  &thinsp;&thinsp; &thinsp;&thinsp; [3.7 ¿Qué estado recibe el mayor monto promedio de donaciones?](#3.7)
#  &thinsp;&thinsp; &thinsp;&thinsp; [3.8 Estados y el total de donaciones recibidas](#3.8)
#  &thinsp;&thinsp; &thinsp;&thinsp; [3.9 Donaciones de California a lo largo del tiempo](#3.9)
#
# [4. Exploración de los docentes](#4)
# &thinsp;&thinsp; &thinsp;&thinsp; [4.1 Resumen de los datos de los docentes](#4.1)
# &thinsp;&thinsp; &thinsp;&thinsp; [4.2 ¿Quiénes fueron los primeros docentes en DonorsChoose?](#4.2)
# &thinsp;&thinsp; &thinsp;&thinsp; [4.3 Crecimiento en el número de docentes a lo largo de los años](#4.3)
# &thinsp;&thinsp; &thinsp;&thinsp; [4.4 ¿Cuál es la distribución de los prefijos de los docentes?](#4.4)
# &thinsp;&thinsp; &thinsp;&thinsp; [4.5 Serie temporal de los docentes que publicaron su primer proyecto](#4.5)
#
# [5. Exploración de las escuelas](#5)
# &thinsp;&thinsp; &thinsp;&thinsp; [5.1 Resumen de los datos de las escuelas](#5.1)
# &thinsp;&thinsp; &thinsp;&thinsp; [5.2 ¿Qué tipos de escuelas según el área metropolitana publican proyectos? (y principales estados y ciudades)](#5.2)
# &thinsp;&thinsp; &thinsp;&thinsp; [5.3 Distribución del porcentaje de estudiantes con almuerzo gratuito](#5.3)
# &thinsp;&thinsp; &thinsp;&thinsp; [5.4 ¿Qué tipos de escuelas están registrados en mayor proporción?](#5.4)
#
# [6. Exploración de los recursos](#6)
# &thinsp;&thinsp; &thinsp;&thinsp; [6.1 Resumen de los datos de los recursos](#6.1)
# &thinsp;&thinsp; &thinsp;&thinsp; [6.2 ¿Qué artículos son los más populares en DonorsChoose?](#6.2)
# &thinsp;&thinsp; &thinsp;&thinsp; [6.3 ¿Cuáles son los artículos más costosos?](#6.3)
# &thinsp;&thinsp; &thinsp;&thinsp; [6.4 ¿Cuáles son los proveedores más populares y cuál es el costo promedio asociado a ellos?](#6.4)
#
# [7. Exploración de los proyectos](#7)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.1 Resumen de los datos de los proyectos](#7.1)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.2 Categorías, subcategorías y categorías de recursos más frecuentes de los proyectos](#7.2)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.3 Tipo de proyecto y estado del proyecto](#7.3)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.4 Día de publicación y día de financiación](#7.4)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.5 Trimestre de publicación y trimestre de financiación](#7.5)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.6 ¿En qué mes se publican la mayoría de los proyectos?](#7.6)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.7 ¿Está aumentando el número de proyectos?](#7.7)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.8 ¿En qué año y mes el costo de los proyectos es más alto?](#7.8)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.9 ¿En qué año y categoría de grado el costo de los proyectos es más alto?](#7.9)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.10 ¿Para qué categoría de grado y categoría de recursos el costo de los proyectos es más alto?](#7.10)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.11 Estado de los proyectos por año](#7.11)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.12 Duración de los proyectos financiados con éxito](#7.12)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.13 Estado de los proyectos por diferentes estados](#7.13)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.14 Costo promedio de los proyectos según el tipo de área metropolitana de la escuela y la categoría de recursos](#7.14)
# &thinsp;&thinsp; &thinsp;&thinsp; [7.15 Costo promedio de los proyectos según el tipo de área metropolitana de la escuela y la categoría del nivel educativo](#7.15)
#
# [8. Análisis de texto de los proyectos](#8)
# &thinsp;&thinsp; &thinsp;&thinsp; [8.1 Limpieza del texto](#8.1)
# &thinsp;&thinsp; &thinsp;&thinsp; [8.2 Análisis de bolsa de palabras](#8.2)
# &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; [8.2.1 Palabras y n-gramas más utilizados por los docentes en todos los ensayos](#8.2.1)
# &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; [8.2.2 Palabras y n-gramas más utilizados en diferentes estados](#8.2.2)
# &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; [8.2.3 Contexto de "Mis estudiantes son..."](#8.2.3)
# &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; [8.2.4 Contexto de "Mis estudiantes necesitan..."](#8.2.4)
# &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; &thinsp;&thinsp; [8.2.5 Título del proyecto: palabras clave más utilizadas](#8.2.5)
#
# [9. Comprensión y comparación de las características de los proyectos](#9)
# &thinsp;&thinsp; &thinsp;&thinsp; [9.1 Proyectos expirados vs. proyectos financiados con éxito](#9.1)
# &thinsp;&thinsp; &thinsp;&thinsp; [9.2 Proyectos con menor vs. mayor duración de financiación](#9.2)
# &thinsp;&thinsp; &thinsp;&thinsp; [9.3 Proyectos con un solo donante vs. múltiples donantes](#9.3)
#
# <br>
# ##  <a id="1">1. Preparación del conjunto de datos</a>
#
# Importemos las bibliotecas necesarias y carguemos el conjunto de datos.

# %%
pip cache purge
# Out:
# Files removed: 0 (0 bytes)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: No matching packages

# %%
# !pip install wordcloud
# !pip install folium
# Out:
# Requirement already satisfied: wordcloud in c:\users\diego\anaconda3\lib\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\diego\anaconda3\lib\site-packages (from wordcloud) (2.3.5)
# Requirement already satisfied: pillow in c:\users\diego\anaconda3\lib\site-packages (from wordcloud) (12.0.0)
# Requirement already satisfied: matplotlib in c:\users\diego\anaconda3\lib\site-packages (from wordcloud) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\diego\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\diego\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\diego\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\diego\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\diego\anaconda3\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\diego\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\diego\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\diego\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Requirement already satisfied: folium in c:\users\diego\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\diego\anaconda3\lib\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\diego\anaconda3\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\diego\anaconda3\lib\site-packages (from folium) (2.3.5)
# Requirement already satisfied: requests in c:\users\diego\anaconda3\lib\site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in c:\users\diego\anaconda3\lib\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\diego\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\diego\anaconda3\lib\site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\diego\anaconda3\lib\site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\diego\anaconda3\lib\site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\diego\anaconda3\lib\site-packages (from requests->folium) (2026.6.17)

# %%
from plotly.offline import init_notebook_mode, iplot
from wordcloud import WordCloud
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
from plotly import tools
from datetime import date
import pandas as pd
import numpy as np 
import seaborn as sns
import random 
import warnings
import operator
warnings.filterwarnings("ignore")
init_notebook_mode(connected=True)

path = "Datasets/"
donors_df = pd.read_csv(path+"Donors.csv")
donations_df = pd.read_csv(path+"Donations.csv")
teachers_df = pd.read_csv(path+"Teachers.csv")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>

# %% [markdown]
# ## <a id="2">2. Explorando a los donantes</a>
#
# El conjunto de datos de donantes contiene información sobre cada donante que ha realizado al menos una donación en DonorsChoose, incluyendo datos como su ciudad, estado, código postal y si son docentes.
#
# ## <a id="2.1">2.1 Resumen de donantes</a>
#
# Echemos un vistazo a una muestra de las primeras filas del conjunto de datos de donantes.

# %%
###### Total de filas
# donors_df.shape

###### Total de ciudades
# len(donors_df['Donor City'].value_counts())

# Donantes con más de una donación
# t = donations_df['Donor ID'].value_counts().to_frame()
# len(t[t['Donor ID'] > 1])

donors_df.head(3)
# Out:
#                            Donor ID    Donor City Donor State  \
# 0  d43534de4027fde125fec3e42041e32d  Indianapolis     Indiana
# 1  4bce4e18802baa4d0d83b6b1acc546e8     Cleveland        Ohio
# 2  1190f938a66fd7f739669fa759970043       Chicago    Illinois
#
#   Donor Is Teacher  Donor Zip
# 0              Yes        443
# 1              Yes        842
# 2               No        982

# %% [markdown]
# Hay un total de **2,122,640** donantes registrados en DonorsChoose hasta abril de 2018. Estos donantes pertenecen a **15,204 ciudades diferentes** de Estados Unidos y de algunos otros países. De este gran número de donantes, solo **552,941 (es decir, aproximadamente el 26 %)** han realizado más de una donación.
#
# Uno de los principales objetivos del desafío **Data Science for Good** es encontrar información relevante y generar recomendaciones que permitan motivar a los donantes a volver a contribuir. Existen alrededor de **1,471,613 donantes** que solo han realizado una donación, por lo que DonorsChoose tiene la oportunidad de incentivar a estas personas para que realicen una segunda contribución.
#
# ## <a id="2.2">2.2 Donantes por estado</a>
#
# ## <a id="2.2.1">2.2.1 Número de donantes por estado</a>

# %%
import folium
from folium import plugins
from io import StringIO
import folium 


statesll=StringIO("""State,Latitude,Longitude
Alabama,32.806671,-86.791130
Alaska,61.370716,-152.404419
Arizona,33.729759,-111.431221
Arkansas,34.969704,-92.373123
California,36.116203,-119.681564
Colorado,39.059811,-105.311104
Connecticut,41.597782,-72.755371
Delaware,39.318523,-75.507141
District of Columbia,38.897438,-77.026817
Florida,27.766279,-81.686783
Georgia,33.040619,-83.643074
Hawaii,21.094318,-157.498337
Idaho,44.240459,-114.478828
Illinois,40.349457,-88.986137
Indiana,39.849426,-86.258278
Iowa,42.011539,-93.210526
Kansas,38.526600,-96.726486
Kentucky,37.668140,-84.670067
Louisiana,31.169546,-91.867805
Maine,44.693947,-69.381927
Maryland,39.063946,-76.802101
Massachusetts,42.230171,-71.530106
Michigan,43.326618,-84.536095
Minnesota,45.694454,-93.900192
Mississippi,32.741646,-89.678696
Missouri,38.456085,-92.288368
Montana,46.921925,-110.454353
Nebraska,41.125370,-98.268082
Nevada,38.313515,-117.055374
New Hampshire,43.452492,-71.563896
New Jersey,40.298904,-74.521011
New Mexico,34.840515,-106.248482
New York,42.165726,-74.948051
North Carolina,35.630066,-79.806419
North Dakota,47.528912,-99.784012
Ohio,40.388783,-82.764915
Oklahoma,35.565342,-96.928917
Oregon,44.572021,-122.070938
Pennsylvania,40.590752,-77.209755
Rhode Island,41.680893,-71.511780
South Carolina,33.856892,-80.945007
South Dakota,44.299782,-99.438828
Tennessee,35.747845,-86.692345
Texas,31.054487,-97.563461
Utah,40.150032,-111.862434
Vermont,44.045876,-72.710686
Virginia,37.769337,-78.169968
Washington,47.400902,-121.490494
West Virginia,38.491226,-80.954453
Wisconsin,44.268543,-89.616508
Wyoming,42.755966,-107.302490""")

tempdf = states_df = donors_df['Donor State'].value_counts()
t1 = pd.DataFrame()
t1['Donor State'] = tempdf.index
t1['Donor Count'] = tempdf.values

# tempdf = combined_df.groupby(['Donor State']).agg({'Donation Amount':'sum'}).reset_index()
# t1 = tempdf.sort_values('Donation Amount', ascending=False)

sdf = pd.read_csv(statesll).rename(columns={'State':'Donor State'})
sdf = sdf.merge(t1, on='Donor State', how='inner')
sdf 

map4 = folium.Map(location=[39.50, -98.35], tiles='CartoDB dark_matter', zoom_start=3.5)
for j, rown in sdf.iterrows():
    rown = list(rown)
    folium.CircleMarker([float(rown[1]), float(rown[2])], popup="<b>State:</b>" + rown[0].title() +"<br> <b>Donors:</b> "+str(int(rown[3])), radius=float(rown[3])*0.0001, color='#be0eef', fill=True).add_to(map4)
map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db29db95269a39a42fb475dce363490f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db29db95269a39a42fb475dce363490f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db29db95269a39a42fb475dce363490f = L.map(
#                 &quot;map_db29db95269a39a42fb475dce363490f&quot;,
#                 {
#                     center: [39.5, -98.35],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d29b83734bbae44c1e465e64ed769577 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d29b83734bbae44c1e465e64ed769577.addTo(map_db29db95269a39a42fb475dce363490f);
#
#
#             var circle_marker_b4082a73ad892c33155f1db78c9ad691 = L.circleMarker(
#                 [32.806671, -86.79113],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#be0eef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#be0eef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.0007, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_db29db95269a39a42fb475dce363490f);
#
#
#         var popup_ab56bc5cdff9b08a2d3cc5039d614d5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_761a01fa568829f2d946bb64efc6179d = $(`&lt;div id=&quot;html_761a01fa568829f2d946bb64efc6179d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;State:&lt;/b&gt;Alabama&lt;br&gt; &lt;b&gt;Donors:&lt;/b&gt; 7&lt;/div&gt;`)[0];
#                 popup_ab56bc5cdff9b08a2d3cc5039d614d5a.setContent(html_761a01fa568829f2d946bb64efc6179d);
#
#
#
#         circle_marker_b4082a73ad892c33155f1db78c9ad691.bindPopup(popup_ab56bc5cdff9b08a2d3cc5039d614d5a)
#         ;
#
#
#
#
#             var circle_marker_57f8eaa030a806a9348bfb9ab6768d10 = L.circleMarker(
#                 [61.370716, -152.404419],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#be0eef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#be0eef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.0002, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_db29db95269a39a42fb475dce363490f);
#
#
#         var popup_900a318a0ee1701b85bee60b271b3e40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23ade5645f4f2cc7a7d83bf49128165c = $(`&lt;div id=&quot;html_23ade5645f4f2cc7a7d83bf49128165c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;State:&lt;/b&gt;Alaska&lt;br&gt; &lt;b&gt;Donors:&lt;/b&gt; 2&lt;/div&gt;`)[0];
#                 popup_900a318a0ee1701b85bee60b271b3e40.setContent(html_23ade5645f4f2cc7a7d83bf49128165c);
#
#
#
#         circle_marker_57f8eaa030a806a9348bfb9ab6768d10.bindPopup(popup_900a318a0ee1701b85bee60b271b3e40)
#         ;
#
#
#
#
#             var circle_marker_68d556097dee3574cef302d0a4c1c82f = L.circleMarker(
#                 [33.729759, -111.431221],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#be0eef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#be0eef&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.0015, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_db29db95269a39a42fb475dce363490f);
#
#
#         var popup_234beec9f592d5a16e339f783150b617 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e9ef8db5f3a5e206ec0b64140120a52 = $(`&lt;div id=&quot;html_7e9ef8db5f3a5e206ec0b64140120a52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;State:&lt;/b&gt;Arizona&lt;br&gt; &lt;b&gt;Donors:&lt;/b&gt; 15&lt;/div&gt;`)[0];
#                 popup_234b

# %%
def bar_hor(df, col, title, color, w=None, h=None, lm=0, limit=100, return_trace=False, rev=False):
    cnt_srs = df[col].value_counts()
    yy = cnt_srs.head(limit).index[::-1] 
    xx = cnt_srs.head(limit).values[::-1] 
    if rev:
        yy = cnt_srs.tail(limit).index[::-1] 
        xx = cnt_srs.tail(limit).values[::-1] 
        
    
    trace = go.Bar(y=yy, x=xx, orientation='h', marker=dict(color=color))
    if return_trace:
        return trace 
    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    data = [trace]
    fig = go.Figure(data=data, layout=layout)
    iplot(fig)

def bar_hor_noagg(x, y, title, color, w=None, h=None, lm=0, limit=100, rt=False):
    trace = go.Bar(y=x, x=y, orientation='h', marker=dict(color=color))
    if rt:
        return trace
    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    data = [trace]
    fig = go.Figure(data=data, layout=layout)
    iplot(fig)


def bar_ver_noagg(x, y, title, color, w=None, h=None, lm=0, rt=False):
    trace = go.Bar(y=y, x=x, marker=dict(color=color))
    if rt:
        return trace
    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    data = [trace]
    fig = go.Figure(data=data, layout=layout)
    iplot(fig)

    
trace1 = bar_hor(donors_df, 'Donor City', "Principales ciudades con el mayor número de donantes", '#c2d2ed', 500, 400, 200, limit=10, return_trace=True)
trace2 = bar_hor(donors_df, 'Donor State', "Principales estados con el mayor número de donantes", '#c2d2ed', 500, 400, 200, limit=10, return_trace=True)
trace4 = bar_hor(donors_df, 'Donor State', "Principales estados con el menor número de donantes", '#c2d2ed', 600, 400, 200, limit=10, return_trace=True, rev=True)


fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        'Estados con el mayor número de donantes',
        'Estados con el menor número de donantes'
    ]
)

# fig = tools.make_subplots(rows=2, cols=2, specs=[[{}, {}], [{'colspan': 2}, None]],
#                           print_grid=False,
#                           subplot_titles=['Estados con el mayor número de donantes',
#                                           'Estados con el menor número de donantes',
#                                           'Ciudades con el mayor número de donantes'])

fig.append_trace(trace2, 1, 1)
fig.append_trace(trace4, 1, 2)
# fig.append_trace(trace1, 2, 1)

fig['layout'].update(height=400, showlegend=False)
iplot(fig)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="bcc12d04-1298-409a-b565-9a32b6faa3cf" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bcc12d04-1298-409a-b565-9a32b6faa3cf")) {                    Plotly.newPlot(                        "bcc12d04-1298-409a-b565-9a32b6faa3cf",                        [{"marker":{"color":"#c2d2ed"},"orientation":"h","x":{"dtype":"i2","bdata":"HgAiACQAMgA3AD8ATgBnAHkAxwA="},"xaxis":"x","y":["Washington","New Jersey","Pennsylvania","North Carolina","Massachusetts","Florida","Illinois","Texas","New York","California"],"yaxis":"y","type":"bar"},{"marker":{"color":"#c2d2ed"},"orientation":"h","x":{"dtype":"i1","bdata":"AQICAgICAgIDAw=="},"xaxis":"x2","y":["Wyoming","Delaware","Rhode Island","Alaska","South Dakota","North Dakota","Vermont","Montana","Hawaii","New Hampshire"],"yaxis":"y2","type":"bar"}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"Estados con el mayor n\u00famero de donantes","x":0.225,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Estados con el menor n\u00famero de donantes","x":0.775,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"}],"height":400,"showlegend":false,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh ...

# %% [markdown]
# > - California, al ser el estado con mayor población, también tiene una gran base de donantes registrados con casi 300,000 donantes. **San Francisco y Los Ángeles** son las principales ciudades de California donde se concentra la mayor cantidad de donantes. El mayor número de escuelas y proyectos también proviene del estado de California.
# > - Nueva York, Texas y Florida, con aproximadamente 137,000, 134,000 y 108,000 donantes respectivamente, son otros tres estados con una alta población de donantes. Las principales ciudades incluyen Nueva York, Miami, Tampa, Houston y Dallas, donde se concentra la mayor cantidad de donantes.
# > - Dakota del Norte, Dakota del Sur, Vermont y Wyoming son los estados con un número muy bajo de donantes, menos de 4,000. Existe una entrada llamada "otros" en los datos de estados, que probablemente indica donantes docentes o donantes de otros países.
# > - Entre todas las ciudades de EE. UU., las tres principales son: **Chicago (aprox. 35K donantes), Nueva York (aprox. 27K donantes) y Brooklyn (aprox. 22K donantes)** con la mayor cantidad de donantes. Las ciudades de California, San Francisco y Los Ángeles, son las siguientes con una gran base de donantes con aproximadamente 18K y 16K donantes.
#
# ## <a>Dataset ajustado por población</a>
#
# Los estados principales en los gráficos anteriores son en realidad aquellos con una población muy alta. Sería interesante calcular el número de donantes por cada 100,000 habitantes en cada estado. Se ha agregado un dataset ajustado por población que incluye la población de cada estado a partir de 2013.
#
# Dataset de población: http://www.enchantedlearning.com/usa/states/population.shtml
#
# ## <a id="2.3">2.3 Estados con la mayor **relación donantes/población**</a>

# %%
census_2013 = {'Mississippi': 2991207, 'Iowa': 3090416, 'Oklahoma': 3850568, 'Delaware': 925749, 'Minnesota': 5420380, 'Alaska': 735132, 'Illinois': 12882135, 'Arkansas': 2959373, 'New Mexico': 2085287, 'Indiana': 6570902, 'Maryland': 5928814, 'Louisiana': 4625470, 'Texas': 26448193, 'Wyoming': 582658, 'Arizona': 6626624, 'Wisconsin': 5742713, 'Michigan': 9895622, 'Kansas': 2893957, 'Utah': 2900872, 'Virginia': 8260405, 'Oregon': 3930065, 'Connecticut': 3596080, 'New York': 19651127, 'California': 38332521, 'Massachusetts': 6692824, 'West Virginia': 1854304, 'South Carolina': 4774839, 'New Hampshire': 1323459, 'Vermont': 626630, 'Georgia': 9992167, 'North Dakota': 723393, 'Pennsylvania': 12773801, 'Florida': 19552860, 'Hawaii': 1404054, 'Kentucky': 4395295, 'Rhode Island': 1051511, 'Nebraska': 1868516, 'Missouri': 6044171, 'Ohio': 11570808, 'Alabama': 4833722, 'South Dakota': 844877, 'Colorado': 5268367, 'Idaho': 1612136, 'New Jersey': 8899339, 'Washington': 6971406, 'North Carolina': 9848060, 'Tennessee': 6495978, 'Montana': 1015165, 'District of Columbia': 646449, 'Nevada': 2790136, 'Maine': 1328302}

donors_from_states = dict(donors_df['Donor State'].value_counts())

don_pop = {}
for state, don in donors_from_states.items():
    if state not in census_2013:
        continue
    don_pop[state]  = float(don) * 100000 / census_2013[state]

import operator
don_pop = sorted(don_pop.items(), key=operator.itemgetter(1), reverse=True)
xx = [x[0] for x in don_pop][1:]
yy = [x[1] for x in don_pop][1:]

trace2 = go.Bar(
    x=xx,
    y=yy,
    name='Relación donantes por población',
    marker=dict(color='green'),
    opacity=0.3
)

data = [trace2]
layout = go.Layout(
    barmode='group',
    legend=dict(dict(x=-.1, y=1.2)),
    margin=dict(b=120),
    title='Estados con la mayor relación donantes/población',
)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="82494b76-5855-4516-ad41-370f3208ddd3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("82494b76-5855-4516-ad41-370f3208ddd3")) {                    Plotly.newPlot(                        "82494b76-5855-4516-ad41-370f3208ddd3",                        [{"marker":{"color":"green"},"name":"Relaci\u00f3n donantes por poblaci\u00f3n","opacity":0.3,"x":["District of Columbia","New York","Illinois","California","North Carolina","Connecticut","Washington","Texas","New Jersey","Colorado","Virginia","Maryland","Florida","Vermont","Pennsylvania","North Dakota","Alaska","Georgia","Oregon","Minnesota","South Dakota","Missouri","New Hampshire","Arizona","Maine","Michigan","Delaware","Nevada","Nebraska","Hawaii","Ohio","Kansas","Utah","Montana","New Mexico","Wisconsin","Rhode Island","South Carolina","Idaho","Indiana","Kentucky","Oklahoma","Louisiana","Wyoming","Tennessee","Arkansas","Mississippi","Iowa","West Virginia","Alabama"],"y":[0.6187649760460608,0.6157407664201651,0.6054896956133436,0.51914143606678,0.5077142097022155,0.4449289226046139,0.43032926213162737,0.3894405942969336,0.38205084669771544,0.34166184702014873,0.3389664308227018,0.33733559528094487,0.32220350373295775,0.31916761087084883,0.28182684230011096,0.27647488985931573,0.27205998378522495,0.26020381765036554,0.254448717769299,0.23983558348307682,0.23672084812345465,0.23162812567678842,0.22667872597488853,0.22635960633951768,0.22585225347850113,0.22232053730427456,0.21604128116800558,0.21504328104436488,0.2140736284837807,0.21366699571384007,0.20741853118641326,0.2073285815926083,0.20683435877212095,0.1970123083439638,0.19182011876542654,0.19154709629403385,0.19020248005013737,0.18848803069590409,0.18608851858652123,0.18262332933895528,0.18201281142676431,0.1817913616900156,0.17295539696506518,0.17162726676712584,0.16933554885807803,0.16895470763570528,0.16715660266908977,0.16179051622823595,0.16178576975512107,0.14481594100777828],"type":"bar"}],                        {"barmode":"group","legend":{"x":-0.1,"y":1.2},"margin":{"b":120},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colo ...

# %% [markdown]
# > - Se genera un gráfico interesante donde los estados: **South Carolina** (con población = 4,774,839), **Massachusetts** (con población = 6,692,824) y **Connecticut** (con población = 3,596,080) tienen la mayor relación de donantes por población, es decir, el mayor número de donantes por cada 100,000 personas. South Carolina = 985 donantes por cada 100K personas, Massachusetts = 907 donantes por cada 100K personas y Connecticut = 878 donantes por cada 100K personas.
# > - Wyoming, Nebraska y New Mexico tienen el menor número de donantes por cada 100K personas, con valores de 285, 335 y 363 donantes respectivamente.
# > - Texas, uno de los estados con mayor número total de donantes, tiene una relación donantes/población menor, equivalente a 508 donantes por cada 100K personas.
#
# ## <a id="2.4">2.4 Visualización de dónde están ubicados los donantes</a>
#
# ## <a id="2.4.1">2.4.1 Ubicación de los donantes en California</a>

# %%
calcit = StringIO(u"""Name,Latitude,Longitude,Total Donors,Color,Size
Los Angeles,34.052233,-118.243686,"17,922.000000",#0061ff,10
San Francisco,37.774931,-122.419417,"16,553.000000",#0061ff,10
San Diego,32.715328,-117.157256,"9,072.000000",#0061ff,10
San Jose,37.339386,-121.894956,"7,674.000000",#0061ff,10
Oakland,37.804364,-122.271114,"6,783.000000",#0061ff,10
Sacramento,38.581572,-121.494400,"4,701.000000",#0061ff,10
Bakersfield,35.373292,-119.018711,"3,758.000000",#0061ff,10
Long Beach,33.768322,-118.195617,"3,120.000000",#0061ff,10
Berkeley,37.871592,-122.272747,"2,898.000000",#0061ff,10
Irvine,33.683947,-117.794694,"2,765.000000",#0061ff,10
Fremont,37.548269,-121.988572,"2,716.000000",#0061ff,10
Walnut Creek,37.910078,-122.065183,"2,255.000000",#0061ff,10
Huntington Beach,33.660297,-117.999225,"2,185.000000",#0061ff,10
Murrieta,33.553914,-117.213922,"1,982.000000",#0061ff,10
Pleasanton,37.662431,-121.874678,"1,970.000000",#0061ff,10
Torrance,33.83585,-118.340628,"1,957.000000",#0061ff,10
San Mateo,37.562992,-122.325525,"1,956.000000",#0061ff,10
Santa Monica,34.019453,-118.491192,"1,780.000000",#0061ff,10
Livermore,37.681875,-121.768008,"1,776.000000",#0061ff,10
Santa Rosa,38.440467,-122.714431,"1,752.000000",#0061ff,10
Concord,37.977978,-122.031072,"1,623.000000",#0061ff,10
Alameda,37.765206,-122.241636,"1,548.000000",#0061ff,10
Fresno,36.746842,-119.772586,"1,543.000000",#0061ff,10
San Ramon,37.779928,-121.978014,"1,533.000000",#0061ff,10
Anaheim,33.835292,-117.914503,"1,475.000000",#0061ff,10
Pasadena,34.147786,-118.144517,"1,429.000000",#0061ff,10
Glendale,34.142508,-118.255075,"1,427.000000",#0061ff,10
Riverside,33.95335,-117.396156,"1,425.000000",#0061ff,10
Sunnyvale,37.368831,-122.036350,"1,406.000000",#0061ff,10
Parlier,36.611617,-119.527072,2.000000,#f9e84a,1
Bell Gardens,33.965292,-118.151458,1.000000,#f9e84a,1
Orange Cove,36.624394,-119.313731,1.000000,#f9e84a,1
San Joaquin,36.606617,-120.189044,1.000000,#f9e84a,1
Westmorland,33.037267,-115.621383,1.000000,#f9e84a,1""")



cities = pd.read_csv(calcit)
cities = cities.dropna()

# map_osm = folium.Map(location=[36.611617,-119.527072], zoom_start=5)

# for i, row in cities.iterrows():
#     folium.CircleMarker([row['Latitude'], row['Longitude']],
#                         radius=row['Size'],
#                         color=row['Color'],
#                         fill_color=row['Color'],
#                        ).add_to(map_osm)



map_osm2 = folium.Map([36.611617,-119.527072], zoom_start=6,tiles='cartodbdark_matter')
ziparr = []
for i, row in cities.iterrows():
    ziparr.append([row['Latitude'],row['Longitude'], float(row['Total Donors'].replace(",",""))])
map_osm2.add_child(plugins.HeatMap(ziparr, radius=12))
map_osm2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b30d62bbc6c4e639bdea5a9f23ec7fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b30d62bbc6c4e639bdea5a9f23ec7fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b30d62bbc6c4e639bdea5a9f23ec7fd = L.map(
#                 &quot;map_8b30d62bbc6c4e639bdea5a9f23ec7fd&quot;,
#                 {
#                     center: [36.611617, -119.527072],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23a35c3a9ae4f14e4baca5ffb1392131 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_23a35c3a9ae4f14e4baca5ffb1392131.addTo(map_8b30d62bbc6c4e639bdea5a9f23ec7fd);
#
#
#             var heat_map_97cf198964236010840cfbd1f11651b4 = L.heatLayer(
#                 [[34.052233, -118.243686, 17922.0], [37.774931, -122.419417, 16553.0], [32.715328, -117.157256, 9072.0], [37.339386, -121.894956, 7674.0], [37.804364, -122.271114, 6783.0], [38.581572, -121.4944, 4701.0], [35.373292, -119.018711, 3758.0], [33.768322, -118.195617, 3120.0], [37.871592, -122.272747, 2898.0], [33.683947, -117.794694, 2765.0], [37.548269, -121.988572, 2716.0], [37.910078, -122.065183, 2255.0], [33.660297, -117.999225, 2185.0], [33.553914, -117.213922, 1982.0], [37.662431, -121.874678, 1970.0], [33.83585, -118.340628, 1957.0], [37.562992, -122.325525, 1956.0], [34.019453, -118.491192, 1780.0], [37.681875, -121.768008, 1776.0], [38.440467, -122.714431, 1752.0], [37.977978, -122.031072, 1623.0], [37.765206, -122.241636, 1548.0], [36.746842, -119.772586, 1543.0], [37.779928, -121.978014, 1533.0], [33.835292, -117.914503, 1475.0], [34.147786, -118.144517, 1429.0], [34.142508, -118.255075, 1427.0], [33.95335, -117.396156, 1425.0], [37.368831, -122.03635, 1406.0], [32.640053, -117.084197, 1398.0], [37.386053, -122.08385, 1398.0], [38.4088, -121.371617, 1397.0], [34.391664, -118.542586, 1382.0], [34.180839, -118.308967, 1357.0], [37.485214, -122.236356, 1323.0], [39.728494, -121.837478, 1322.0], [33.979178, -118.032844, 1280.0], [33.875294, -117.566439, 1239.0], [37.354108, -121.955236, 1233.0], [33.787794, -117.853111, 1229.0], [37.441883, -122.143019, 1219.0], [37.668819, -122.080797, 1162.0], [33.195869, -117.379483, 1157.0], [33.870292, -117.925339, 1151.0], [37.973536, -122.531086, 1136.0], [38.677958, -121.
= L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_707322b275f445f3059abc25dfa830fe.addTo(map_f572b9f18eb959bb233b3b5fa24c5662);
#
#
#             var heat_map_d047c8dce9afacbc2408730b805bce14 = L.heatLayer(
#                 [[28.127834, -82.350338, 19], [28.59965, -80.686159, 19], [25.959719, -80.140267, 17], [30.479666, -81.389305, 5], [30.572171, -84.135913, 3]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 12,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_d047c8dce9afacbc2408730b805bce14.addTo(map_f572b9f18eb959bb233b3b5fa24c5662);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# > La región de los tres condados de Florida: Palm Beach, Miami-Dade y Broward tiene la mayor concentración de donantes. La ciudad capital: Tampa también cuenta con un número significativo de donantes. Algunos donantes también se encuentran en una de las áreas más costosas y en la zona más al sur de EE. UU. llamada Key West en Florida. A continuación se muestran los conteos respectivos de donantes en las principales 5 ciudades:
#
# > Miami (9309), Tampa (6016), Orlando (5658), Jacksonville (4598), Fort Lauderdale (4311), West Palm Beach (2400)
#
# ## <a id="2.4.3">2.4.3 Ubicación de los donantes en Nueva York</a>

# %%
fldf = c[c['state'] == 'NY'][['city', 'latitude', 'longitude']]
fldf = fldf.groupby('city').agg({'latitude': 'max', 'longitude': 'max'}).reset_index()
fldf
t = donors_df[donors_df['Donor State'] == 'New York']['Donor City'].value_counts()

fldons = pd.DataFrame()
fldons['city'] = t.index
fldons['count'] = t.values
florida = fldons.merge(fldf, on='city', how='left').dropna()


map_osm2 = folium.Map([42.315975, -74.065515], zoom_start=6.2,tiles='cartodbdark_matter')
ziparr = []
for i, row in florida.iterrows():
    ziparr.append([row['latitude'],row['longitude'], row['count']])
map_osm2.add_child(plugins.HeatMap(ziparr, radius=12))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9da98d3afb3a972117b7a00114db5f5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9da98d3afb3a972117b7a00114db5f5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9da98d3afb3a972117b7a00114db5f5e = L.map(
#                 &quot;map_9da98d3afb3a972117b7a00114db5f5e&quot;,
#                 {
#                     center: [42.315975, -74.065515],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6.2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c192af897127e35eb0bbcc2d13daf152 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c192af897127e35eb0bbcc2d13daf152.addTo(map_9da98d3afb3a972117b7a00114db5f5e);
#
#
#             var heat_map_fa18257306ce52e298aad5788fde6ca0 = L.heatLayer(
#                 [[40.863194, -73.926959, 43], [43.026016, -78.744053, 32], [40.728388, -73.876754, 30], [43.286024, -77.505705, 6], [40.899178, -73.799802, 4]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 12,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_fa18257306ce52e298aad5788fde6ca0.addTo(map_9da98d3afb3a972117b7a00114db5f5e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# > Los donantes de Nueva York provienen principalmente de la ciudad de Nueva York. Las 5 principales ciudades son:
#
# - Nueva York                26820
# - Brooklyn                21715
# - Staten Island            4516
# - Bronx                    4455
# - Buffalo                  2232
#
# ## <a id="2.4.4">2.4.4 Ubicación de los donantes en Texas</a>

# %%
fldf = c[c['state'] == 'TX'][['city', 'latitude', 'longitude']]
fldf = fldf.groupby('city').agg({'latitude': 'max', 'longitude': 'max'}).reset_index()
fldf
t = donors_df[donors_df['Donor State'] == 'Texas']['Donor City'].value_counts()

fldons = pd.DataFrame()
fldons['city'] = t.index
fldons['count'] = t.values
florida = fldons.merge(fldf, on='city', how='left').dropna()


map_osm2 = folium.Map([31.884540, -97.077218], zoom_start=6.2,tiles='cartodbdark_matter')
ziparr = []
for i, row in florida.iterrows():
    ziparr.append([row['latitude'],row['longitude'], row['count']])
map_osm2.add_child(plugins.HeatMap(ziparr, radius=12))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8635fcaff6ed7f6380ce32076d89305 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8635fcaff6ed7f6380ce32076d89305&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8635fcaff6ed7f6380ce32076d89305 = L.map(
#                 &quot;map_f8635fcaff6ed7f6380ce32076d89305&quot;,
#                 {
#                     center: [31.88454, -97.077218],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6.2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfb8b3e3d9e4ef8636fd991a3c2ab57c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dfb8b3e3d9e4ef8636fd991a3c2ab57c.addTo(map_f8635fcaff6ed7f6380ce32076d89305);
#
#
#             var heat_map_46782bebc55ad7c8501bd94a80ea62eb = L.heatLayer(
#                 [[30.493156, -97.443751, 29], [32.986259, -96.535191, 27], [29.740162, -98.22843, 18], [29.83399, -95.099828, 14], [31.963221, -106.176474, 9], [32.93455, -97.051969, 6]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 12,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_46782bebc55ad7c8501bd94a80ea62eb.addTo(map_f8635fcaff6ed7f6380ce32076d89305);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# >
],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 10,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_9982ce70b7f12725082ffeb6dd79411b.addTo(map_65b0285553d83c96e0b912261598e541);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# > Aunque la mayor cantidad de donantes proviene del estado de California, ubicado en la costa oeste, la región de la costa este de Estados Unidos presenta una mayor densidad de donantes en comparación con el oeste. También se observa un número significativo de donantes en Hawái y Alaska.
#
# ## <a id="2.6">2.6 Número de docentes y no docentes donantes por estado</a>

# %%
# qué ciudad y estado tienen más donantes docentes
tempdf = donors_df.groupby(['Donor State', 'Donor Is Teacher']).agg({'Donor Is Teacher' : 'count' }).rename(columns={'Donor Is Teacher' : 'Teacher Donor Counts'}).reset_index()

no_df = tempdf[tempdf['Donor Is Teacher']=='No']
no_x = no_df['Donor State']
no_y = no_df['Teacher Donor Counts']
yes_df = tempdf[tempdf['Donor Is Teacher']=='Yes']
yes_x = yes_df['Donor State']
yes_y = yes_df['Teacher Donor Counts']

trace1 = go.Bar(
    x=no_x,
    y=no_y,
    name='Donantes no docentes',
    marker=dict(color='#f259d6'),
    opacity=0.8
)
trace2 = go.Bar(
    x=yes_x,
    y=yes_y,
    name='Donantes docentes',
    marker=dict(color='#f7bb31'),
    opacity=0.8
)

data = [trace1, trace2]
layout = go.Layout(
    barmode='group',
    legend=dict(dict(x=-.1, y=1.2)),
    margin=dict(b=120),
    title='Estados y distribución de donantes docentes y no docentes',
)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="99be6784-3256-4a4a-b370-debb71215ed1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("99be6784-3256-4a4a-b370-debb71215ed1")) {                    Plotly.newPlot(                        "99be6784-3256-4a4a-b370-debb71215ed1",                        [{"marker":{"color":"#f259d6"},"name":"Donantes no docentes","opacity":0.8,"x":["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","District of Columbia","Florida","Georgia","Hawaii","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland","Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisconsin"],"y":{"dtype":"i2","bdata":"BAACAAkAAgCTAA4ADQACAAQALgASAAMAAgA4AAoABAAFAAcACAACAA4AKAARAAQABQALAAIABAAFAAIAGwADAF0AJQABABEABQAKAB4AAQAJAAIACQBUAAYAAgAYABgAAwAIAA=="},"type":"bar"},{"marker":{"color":"#f7bb31"},"name":"Donantes docentes","opacity":0.8,"x":["Alabama","Arizona","Arkansas","California","Colorado","Connecticut","Florida","Georgia","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Maine","Maryland","Massachusetts","Michigan","Minnesota","Missouri","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Pennsylvania","Rhode Island","Tennessee","Texas","Virginia","Washington","Wisconsin","Wyoming"],"y":{"dtype":"i1","bdata":"AwYDNAQDEQgBFgIBAQEBBg8FCQMBAQcBHA0BBwIGAQITBAYDAQ=="},"type":"bar"}],                        {"barmode":"group","legend":{"x":-0.1,"y":1.2},"margin":{"b":120},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"], ...

# %% [markdown]
# > El número de donantes docentes es siempre muy bajo en todos los estados. El registro que tiene el estado igual a "others" presenta el mayor número de donantes docentes, con aproximadamente 28,000.
#
# ## <a id="3">3. Exploración de las donaciones</a>
#
# El archivo de donaciones incluye información sobre las donaciones realizadas por los donantes, el monto total donado, la secuencia en el carrito del donante, la fecha, el proyecto y el ID del donante.
#
# ## <a id="3.1">3.1 Resumen de las donaciones</a>

# %%
donations_df[['Donation ID', 'Donation Included Optional Donation', 'Donation Amount',
       'Donor Cart Sequence', 'Donation Received Date', 'Project ID', 'Donor ID']].head(3)
# donations_df.columns

# len(donations_df)
# len(donations_df[donations_df['Donation Amount'] > 20000]) / len(donations_df)
# len(donations_df[donations_df['Donation Amount'] > 10000]) / len(donations_df)
# len(donations_df[donations_df['Donation Amount'] < 1])
# np.mean(donations_df['Donation Amount'])
# Out:
#                         Donation ID Donation Included Optional Donation  \
# 0  0f1259e0a18ff6b6b535106e122c9a56                                  No
# 1  21df306f8a0b3c3336d8393a7c441fe7                                 Yes
# 2  5ab33edf6e595ed3a8b317fa18d0752b                                 Yes
#
#    Donation Amount  Donor Cart Sequence Donation Received Date  \
# 0          2219.27                    2    2016-06-10 07:17:42
# 1            44.02                    8    2017-04-06 13:12:06
# 2           112.07                   11    2016-10-31 20:06:03
#
#                          Project ID                          Donor ID
# 0  a013ac6ededa4e161b3dbd5ce9a1fa6f  17fc695a07a0ca6e0822e8f36c031199
# 1  b09b2a5cbadcc32ac1590f538a0f4efb  366eb16f508ebad7b7c93acfe059a0ee
# 2  5cec4eb5edd968311ca35cfb04fc6d82  aefcfad8efc89849b3aa7efe4458a885

# %% [markdown]
# Hasta abril de 2018 se han realizado un total de **4,687,884 donaciones** en DonorsChoose. El monto más alto donado es de **USD 60,000**, realizado en 2013. Solo **6 donaciones superan los USD 20,000**, mientras que únicamente **61 pagos superan los USD 10,000**.
#
# La mayoría de los pagos (aproximadamente **83% del total de donaciones**) son inferiores a **USD 100**. Existen 350 pagos menores a USD 1, lo cual es una cantidad pequeña, pero aún puede marcar la diferencia.
#
# Hasta abril de 2018, DonorsChoose ha recaudado un total de **USD 284,408,243** a través de su plataforma. El monto promedio donado en DonorsChoose es de aproximadamente **USD 60**.
#
# A continuación, se analizan en detalle los donantes y proyectos relacionados con estas donaciones en las siguientes secciones.
#
# ## <a id="3.2">3.2 Proyectos y sus donaciones</a>
#
# Identificaremos los principales proyectos y sus atributos relacionados:
#
# - 3.2.1 Proyectos con el mayor número de donantes
# - 3.2.2 Proyectos con el mayor monto total financiado
# - 3.2.3 Proyectos con el mayor monto promedio por donante
# - 3.2.4 Proyectos con la mayor donación individual

# %%
# Qué proyectos tuvieron el máximo número de donaciones

tempdf = donations_df.groupby('Project ID').agg({'Project ID': 'count', 'Donation Amount': 'sum'}).rename(columns={'Project ID': "Total Donaciones", 'Donation Amount': "Monto Total"}).reset_index()
tempdf['Monto Promedio de Donación'] = tempdf['Monto Total'] / tempdf['Total Donaciones']

tempdf1 = tempdf.sort_values(by=['Total Donaciones'], ascending=[False])
x = tempdf1.head(5)['Project ID']
x = ["Pa" + str(i+1) for i in range(len(x))]
y = tempdf1.head(5)['Total Donaciones']
tr1 = bar_ver_noagg(x, y, 'Total Donaciones', '#43ef4b', lm=None, rt=True)

tempdf1 = tempdf.sort_values(by=['Monto Total'], ascending=[False])
x = tempdf1.head(5)['Project ID']
x = ["Pb" + str(i+1) for i in range(len(x))]
y = tempdf1.head(5)['Monto Total']
tr2 = bar_ver_noagg(x, y, 'Monto Total de Donaciones', '#7fef84', lm=None, rt=True)

tempdf1 = tempdf.sort_values(by=['Monto Promedio de Donación'], ascending=[False])
x = tempdf1[tempdf1['Total Donaciones'] > 10].head(5)['Project ID']
x = ["Pc" + str(i+1) for i in range(len(x))]
y = tempdf1[tempdf1['Total Donaciones'] > 10].head(5)['Monto Promedio de Donación']
tr3 = bar_ver_noagg(x, y, 'Monto Promedio (mín: 10 donaciones)', '#a5d1a7', lm=None, rt=True)

tempdf = donations_df.groupby('Project ID').agg({'Project ID': 'count', 'Donation Amount': 'max'}).rename(columns={'Project ID': "Total Donaciones", 'Donation Amount': "Donación Máxima"}).reset_index()

tempdf1 = tempdf.sort_values(by=['Donación Máxima'], ascending=[False])
x = tempdf1.head(5)['Project ID']
x = ["Pd" + str(i+1) for i in range(len(x))]
y = tempdf1.head(5)['Donación Máxima']
tr4 = bar_ver_noagg(x, y, 'Donación Máxima Individual', '#c0d1c1', lm=None, rt=True)


fig = tools.make_subplots(
    rows=2,
    cols=2,
    print_grid=False,
    subplot_titles=[
        'Número de donaciones',
        'Monto total donado',
        'Monto promedio por donante (mín 10 donaciones)',
        'Monto máximo de una sola donación'
    ]
)

fig.append_trace(tr1, 1, 1)
fig.append_trace(tr2, 1, 2)
fig.append_trace(tr3, 2, 1)
fig.append_trace(tr4, 2, 2)

fig['layout'].update(
    height=600,
    showlegend=False,
    title='Principales proyectos y sus métricas: donaciones totales, monto total, promedio y máximo'
)

iplot(fig)

# %% [markdown]
# > - **Proyectos principales**
# > - En la historia de DonorsChoose, los distintos proyectos recibieron un número variable de donaciones que va desde tan solo 1 hasta 800 donaciones. El número máximo de donaciones en un solo proyecto es de **863**. Este fue un proyecto liderado por un docente y su título fue "**Vallecito StandUpKids Pilot Standing School!**" (mostrado como Pa1 en el primer gráfico). El monto total financiado en este proyecto fue de **USD 108,248.30** y fue financiado completamente el 26 de agosto de 2015.
# > - Existen otros tres proyectos con un número muy alto de donaciones (mayor a 600).
# > - En noviembre de 2016, se inició un proyecto titulado "**Varsity and After-School Fencing Teams in NYC**" (mostrado como Pc1 en el segundo gráfico) y tuvo 18 donaciones en total. Este proyecto tuvo el mayor monto promedio por donante, equivalente a **USD 1,850**.
# > - En el proyecto titulado "**Learning to Play While Playing to Learn!**" (mostrado como Pd1 en el cuarto gráfico), se realizó la donación individual máxima de **USD 60,000**, que es la donación individual más alta en la historia de DonorsChoose.
#
# ## <a id="3.3">3.3 Quiénes son los principales donantes:</a>
#
# Identificaremos a los donantes que realizaron las mayores contribuciones y sus valores. Es decir:
#
# - 3.3.1 Donantes con el mayor número de donaciones
# - 3.3.2 Donantes con el mayor monto total financiado
# - 3.3.3 Donantes con el mayor monto promedio por donación
# - 3.3.4 Donantes con la mayor donación individual

# %%
# Qué donantes realizaron el máximo número de donaciones

tempdf = donations_df.groupby('Donor ID').agg({'Donor ID': 'count', 'Donation Amount': 'sum'}).rename(columns={'Donor ID': "Total Donaciones", 'Donation Amount': "Monto Total"}).reset_index()
tempdf['Monto Promedio de Donación'] = tempdf['Monto Total'] / tempdf['Total Donaciones']

tempdf1 = tempdf.sort_values(by=['Total Donaciones'], ascending=[False])
x = tempdf1.head(5)['Donor ID']
x = ["D" + str(i+1) for i in range(len(x))]
y = tempdf1.head(5)['Total Donaciones']
tr1 = bar_ver_noagg(x, y, 'Total Donaciones', '#d141ea', lm=None, rt=True)

tempdf1 = tempdf.sort_values(by=['Monto Total'], ascending=[False])
x = tempdf1.head(5)['Donor ID']
x = ["D" + str(i+1) for i in range(len(x))]
y = tempdf1.head(5)['Monto Total']
tr2 = bar_ver_noagg(x, y, 'Monto Total de Donaciones', '#db85ea', lm=None, rt=True)

tempdf1 = tempdf.sort_values(by=['Monto Promedio de Donación'], ascending=[False])
x = tempdf1.head(5)['Donor ID']
x = ["D" + str(i+1) for i in range(len(x))]
y = tempdf1.head(5)['Monto Promedio de Donación']
tr3 = bar_ver_noagg(x, y, 'Monto Promedio de Donación', '#d5b1db', lm=None, rt=True)

tempdf = donations_df.groupby('Donor ID').agg({'Donor ID': 'count', 'Donation Amount': 'max'}).rename(columns={'Donor ID': "Total Donaciones", 'Donation Amount': "Donación Máxima"}).reset_index()
tempdf1 = tempdf.sort_values(by=['Donación Máxima'], ascending=[False])
x = tempdf1.head(5)['Donor ID']
x = ["D" + str(i+1) for i in range(len(x))]
y = tempdf1.head(5)['Donación Máxima']
tr4 = bar_ver_noagg(x, y, 'Donación Máxima', '#ccbece', lm=None, rt=True)

fig = tools.make_subplots(
    rows=2,
    cols=2,
    print_grid=False,
    subplot_titles=[
        'Número de donaciones',
        'Monto total donado',
        'Monto promedio donado',
        'Monto máximo donado'
    ]
)

fig.append_trace(tr1, 1, 1)
fig.append_trace(tr2, 1, 2)
fig.append_trace(tr3, 2, 1)
fig.append_trace(tr4, 2, 2)

fig['layout'].update(
    height=600,
    showlegend=False,
    title='Principales donantes y sus contribuciones'
)

iplot(fig)

# %% [markdown]
# > - **Donantes más generosos:**
# > - Un donante no docente de **Manhattan Beach, California** ha realizado más de **18,000 donaciones** en DonorsChoose (mostrado como D1 en el gráfico superior izquierdo). Otro donante no docente de Nueva York ha donado un monto total masivo de **1.8 millones de USD** en aproximadamente 10,513 donaciones (mostrado como D1 en el gráfico superior derecho).
# > - El mayor pago individual de **60,000 USD** para el proyecto "Learning to Play while Playing to Learn" fue realizado por un donante de **Anahola, Hawái**, quien además ha realizado un total de 223 donaciones hasta la fecha.
#
# ## <a id="3.4">3.4 ¿Qué montos de donación se recibieron en qué momentos?</a>
#
# ### Donaciones por año
# - 3.4.1 Número de donaciones por año
# - 3.4.2 Monto promedio de donaciones por año

# %%
donations_df['Donation Date'] = pd.to_datetime(donations_df['Donation Received Date'])
donations_df['Donation Year'] = donations_df['Donation Date'].dt.year
donations_df['Donation Month'] = donations_df['Donation Date'].dt.month
donations_df['Donation Day'] = donations_df['Donation Date'].dt.day
donations_df['Donation Weekday'] = donations_df['Donation Date'].dt.weekday
donations_df['Donation Hour'] = donations_df['Donation Date'].dt.hour

t1 = donations_df.groupby(['Donation Year']).agg({'Donation Month' : 'count', 'Donation Amount' : 'mean'}).reset_index().rename(columns={'Donation Month' : 'Total Donations', 'Donation Amount' : 'Average Amount'})
x = t1['Donation Year']
y1 = t1['Total Donations']
y2 = t1['Average Amount']
trace1 = go.Scatter(x=x[:-1], y=y1[:-1], fill='tozeroy', fillcolor = '#fcc45f', mode= 'none')
trace2 = go.Scatter(x=x[:-1], y=y2[:-1], fill='tozeroy', fillcolor = "#e993f9", mode= 'none')
fig = tools.make_subplots(rows=1, cols=2, print_grid=False, subplot_titles = ["<b>Donaciones anuales</b>", "<b>Importe promedio de donación anual</b>"])
fig.append_trace(trace1, 1, 1);
fig.append_trace(trace2, 1, 2);

fig['layout'].update(
    height=300,
    showlegend=False,
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        showticklabels=False
    ),
    yaxis2=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        showticklabels=False
    )
);
iplot(fig);

# %% [markdown]
# Desde el año 2012, el número de donaciones en DonorsChoose ha ido aumentando de forma constante. Con aproximadamente 150 donaciones recibidas en 2012, DonorsChoose alcanzó cerca de **1.1 millones de donaciones** en el año 2017. El monto más alto recibido en 2017 fue de **USD 31,856**, el cual fue aportado por un donante de **Lafayette, Colorado**. Esta donación se realizó el 02 de marzo de 2017.
#
# En ese mismo año, también se registró una gran cantidad de donaciones por parte de un donante de **Manhattan Beach, California**, quien realizó **13,751 donaciones**.
#
# El monto promedio de donación por año es cercano a **USD 60**, mientras que fue más alto en el año inicial, es decir, 2012, con un valor de **USD 166**.
#
# ### Donaciones por mes
# - 3.4.3 Número de donaciones por mes
# - 3.4.4 Promedio de donaciones por mes

# %%
t2 = donations_df.groupby(['Donation Month']).agg({'Donation Year' : 'count', 'Donation Amount' : 'mean'}).reset_index().rename(columns={'Donation Year' : 'Total Donations', 'Donation Amount' : 'Average Amount'})
x = t2['Donation Month']
y1 = t2['Total Donations']
y2 = t2['Average Amount']
trace1 = go.Scatter(x=x, y=y1, fill='tozeroy', fillcolor = '#fcc45f', mode= 'none')
trace2 = go.Scatter(x=x, y=y2, fill='tozeroy', fillcolor = "#e993f9", mode= 'none')
fig = tools.make_subplots(rows=1, cols=2, print_grid=False, subplot_titles = ["<b>Donaciones mensuales</b>", "<b>Importe promedio de donación mensual</b>"])
fig.append_trace(trace1, 1, 1);
fig.append_trace(trace2, 1, 2);

fig['layout'].update(
    height=300,
    showlegend=False,
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    ),
    yaxis2=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    )
)

iplot(fig);

# %% [markdown]
# > - El mayor número de donaciones se recibe en el mes de **agosto con 577,274 donaciones**, seguido de **septiembre con 518,908 donaciones**, mientras que el menor número de donaciones se registra en **junio con 191,221 donaciones** y **mayo con 243,440 donaciones**, probablemente debido a la temporada de verano y vacaciones. El monto promedio de donación más alto se recibe en el mes de **diciembre con USD 80**, mientras que el más bajo corresponde al mes de **julio con USD 51**. En promedio, el monto de donación anual es cercano a **USD 59**.
#
# ### Donaciones por Día del Mes
# - 3.4.5 Número de Donaciones por Día del Mes
# - 3.4.6 Promedio de Donaciones por Día del Mes

# %%
t3 = donations_df.groupby(['Donation Day']).agg({
    'Donation Year': 'count',
    'Donation Amount': 'mean'
}).reset_index().rename(columns={
    'Donation Year': 'Total de Donaciones',
    'Donation Amount': 'Monto Promedio'
})

x = t3['Donation Day']
y1 = t3['Total de Donaciones']
y2 = t3['Monto Promedio']

trace1 = go.Scatter(x=x, y=y1, fill='tozeroy', fillcolor='#fcc45f', mode='none')
trace2 = go.Scatter(x=x, y=y2, fill='tozeroy', fillcolor="#e993f9", mode='none')

fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        "<b>Donaciones por Día del Mes</b>",
        "<b>Monto Promedio de Donación por Día del Mes</b>"
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

fig['layout'].update(
    height=300,
    showlegend=False,
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    ),
    yaxis2=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    )
)

iplot(fig)

# %% [markdown]
# ### Donaciones por día de la semana
# - 3.4.7 Número de donaciones por día de la semana
# - 3.4.8 Promedio de donaciones por día de la semana

# %%
t4 = donations_df.groupby(['Donation Weekday']).agg({'Donation Year' : 'count', 'Donation Amount' : 'mean'}).reset_index().rename(columns={'Donation Year' : 'Total de Donaciones', 'Donation Amount' : 'Monto Promedio'})
x = t4['Donation Weekday']
y1 = t4['Total de Donaciones']
y2 = t4['Monto Promedio']

trace1 = go.Scatter(x=x, y=y1, fill='tozeroy', fillcolor='#fcc45f', mode='none')
trace2 = go.Scatter(x=x, y=y2, fill='tozeroy', fillcolor="#e993f9", mode='none')

fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=["<b>Donaciones por Día de la Semana</b>", "<b>Monto Promedio de Donación por Día de la Semana</b>"]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

fig['layout'].update(
    height=300,
    showlegend=False,
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    ),
    yaxis2=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    )
)

iplot(fig)

# %% [markdown]
# El número de donaciones es mayor al inicio de la semana —es decir, los lunes, martes y miércoles—, con un total de 700.000, 800.000 y 750.000 donaciones respectivamente, y la cifra disminuye a medida que avanza la semana. Como se observa en el gráfico, el menor número de donaciones se recibe los sábados.
#
# ### Donaciones por hora
# - 3.4.9 Número de donaciones por hora
# - 3.4.10 Promedio de donaciones por hora

# %%
t5 = donations_df.groupby(['Donation Hour']).agg({'Donation Month' : 'count', 'Donation Amount' : 'mean'}).reset_index().rename(columns={'Donation Month' : 'Total de Donaciones', 'Donation Amount' : 'Monto Promedio'})
x = t5['Donation Hour']
y1 = t5['Total de Donaciones']
y2 = t5['Monto Promedio']

trace1 = go.Scatter(x=x[:-1], y=y1[:-1], fill='tozeroy', fillcolor='#fcc45f', mode='none')
trace2 = go.Scatter(x=x[:-1], y=y2[:-1], fill='tozeroy', fillcolor="#e993f9", mode='none')

fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=["<b>Donaciones por Hora</b>", "<b>Monto Promedio de Donación por Hora</b>"]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

fig['layout'].update(
    height=300,
    showlegend=False,
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    ),
    yaxis2=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    )
)

iplot(fig)

# %% [markdown]
# ## <a id="3.5"> 3.5 Donaciones Opcionales y Donantes Docentes </a>
#
# ### <a id="3.5.1"> 3.5.1 Total de Donaciones Opcionales y su Monto Promedio Asociado </a>

# %%
tempdf = donations_df.groupby('Donation Included Optional Donation').agg({'Donation Included Optional Donation' : 'count', 'Donation Amount' : 'mean'})

values1 = list(tempdf['Donation Included Optional Donation'])
values2 = list(tempdf['Donation Amount'])
values2t = [str("$") + str(int(x)) for x in values2]

domain1 = {'x': [0.2, 0.50], 'y': [0.0, 0.33]}
domain2 = {'x': [0.8, 0.50], 'y': [0.0, 0.33]}

labels = list(tempdf.index)
mp = {'Yes': 'Donaciones Opcionales', 'No': 'Sin Donaciones Opcionales'}
labels = [mp[x] for x in labels]

trace1 = go.Pie(
    labels=labels,
    values=values1,
    marker=dict(colors=['#75e575', '#ea7c96'])
)

trace2 = go.Pie(
    labels=labels,
    values=values2,
    marker=dict(colors=['#75e575', '#ea7c96']),
    textinfo="text",
    text=values2t
)

layout = go.Layout(
    title='Número de Donaciones con Donaciones Opcionales',
    width=800,
    height=400
)
# fig = go.Figure(data=[trace1], layout=layout)
# iplot(fig)

layout = go.Layout(
    title='Monto Promedio Donado en Donaciones Opcionales',
    width=800,
    height=400
)
# fig = go.Figure(data=[trace2], layout=layout)
# iplot(fig)

fig = {
    "data": [
        {
            "values": values1,
            "labels": list(reversed(labels)),
            "domain": {"x": [0, .48]},
            "marker": dict(colors=['#f9345b', '#75e575']),
            "name": "Número de Donaciones con Donaciones Opcionales",
            "type": "pie"
        },
        {
            "values": values2,
            "labels": labels,
            "marker": dict(colors=['75e575', '#f9345b']),
            "domain": {"x": [.52, 1]},
            "name": "Monto Promedio Donado en Donaciones Opcionales",
            "text": values2t,
            "textinfo": "text",
            "type": "pie"
        }
    ],
    "layout": {
        "title": "Donaciones Opcionales: Total de Donaciones y Monto Promedio de Donación"
    }
}

iplot(fig, filename='donut')

# %% [markdown]
# > - Los proyectos de DonorsChoose también ofrecen la opción de realizar donaciones opcionales. El importe medio de las donaciones opcionales es de **58 USD**, frente a los **73 USD** de las donaciones no opcionales. Del total de donaciones realizadas, aproximadamente el **15 %** fueron donaciones opcionales.
#
# ### <a href="3.5.2"> 3.5.2 Total de donaciones de docentes y donantes, e importes medios asociados </a>

# %%
# lets combine donors and donations 
combined_df = donations_df.merge(donors_df, on='Donor ID', how='inner')
# combined_df.head(10)

tempdf = combined_df.groupby('Donor Is Teacher').agg({'Donor Is Teacher' : 'count', 'Donation Amount' : 'mean'})
values1 = list(tempdf['Donor Is Teacher']) 
values2 = list(tempdf['Donation Amount']) 
values2t = [str("$")+str(int(x)) for x in values2]

domain1 = {'x': [0.2, 0.50], 'y': [0.0, 0.33]}
domain2 = {'x': [0.8, 0.50], 'y': [0.0, 0.33]}

labels = list(tempdf.index)
mp = {'Yes' : 'Donante Docente', 'No' : 'Donante No Docente'}
labels = [mp[x] for x in labels]

trace1 = go.Pie(
    labels=labels,
    values=values1,
    marker=dict(colors=['#75e575', '#ea7c96'])
)

trace2 = go.Pie(
    labels=labels,
    values=values2,
    marker=dict(colors=['#75e575', '#ea7c96']),
    textinfo="text",
    text=values2t
)

layout = go.Layout(
    title='Número de Donaciones de Donantes Docentes',
    width=800,
    height=400
)
# fig = go.Figure(data=[trace1], layout=layout)
# iplot(fig)

layout = go.Layout(
    title='Monto Promedio Donado por Donantes Docentes',
    width=800,
    height=400
)
# fig = go.Figure(data=[trace2], layout=layout)
# iplot(fig)

fig = {
  "data": [
    {
      "values": values1,
      "labels": labels,
      "domain": {"x": [0, .48]},
      "marker": dict(colors=['#ab97db', '#b0b1b2']),
      "name": "Número de Donaciones de Donantes Docentes",
      "type": "pie"
    },
    {
      "values": values2,
      "labels": labels,
      "marker": dict(colors=['#ab97db', '#b0b1b2']),
      "domain": {"x": [.52, 1]},
      "name": "Monto Promedio Donado por Donantes Docentes",
      "text": values2t,
      "textinfo": "text",
      "type": "pie"
    }
  ],
  "layout": {
    "title": "Donantes Docentes: Total de Donaciones y Monto Promedio de Donación"
  }
}

iplot(fig, filename='donut')

# %% [markdown]
# > - Alrededor del **29 %** del total de las donaciones en DonorsChoose provienen de donantes que también son docentes. La mayor parte de estos docentes donantes reside en California.
# > - El monto promedio de las donaciones realizadas por docentes es de **45 USD**, mientras que para los donantes que no son docentes es de **66 USD**.

# %%
def mapp(df, scl, t):
    state_to_code = {'District of Columbia' : 'dc','Mississippi': 'MS', 'Oklahoma': 'OK', 'Delaware': 'DE', 'Minnesota': 'MN', 'Illinois': 'IL', 'Arkansas': 'AR', 'New Mexico': 'NM', 'Indiana': 'IN', 'Maryland': 'MD', 'Louisiana': 'LA', 'Idaho': 'ID', 'Wyoming': 'WY', 'Tennessee': 'TN', 'Arizona': 'AZ', 'Iowa': 'IA', 'Michigan': 'MI', 'Kansas': 'KS', 'Utah': 'UT', 'Virginia': 'VA', 'Oregon': 'OR', 'Connecticut': 'CT', 'Montana': 'MT', 'California': 'CA', 'Massachusetts': 'MA', 'West Virginia': 'WV', 'South Carolina': 'SC', 'New Hampshire': 'NH', 'Wisconsin': 'WI', 'Vermont': 'VT', 'Georgia': 'GA', 'North Dakota': 'ND', 'Pennsylvania': 'PA', 'Florida': 'FL', 'Alaska': 'AK', 'Kentucky': 'KY', 'Hawaii': 'HI', 'Nebraska': 'NE', 'Missouri': 'MO', 'Ohio': 'OH', 'Alabama': 'AL', 'Rhode Island': 'RI', 'South Dakota': 'SD', 'Colorado': 'CO', 'New Jersey': 'NJ', 'Washington': 'WA', 'North Carolina': 'NC', 'New York': 'NY', 'Texas': 'TX', 'Nevada': 'NV', 'Maine': 'ME'}
    df['state_code'] = statesdf['state'].apply(lambda x : state_to_code[x] if x in state_to_code else "")

    data = [ dict(
            type='choropleth',
            colorscale = scl,
            autocolorscale = False,
            locations = df['state_code'],
            z = df['counts'],
            locationmode = 'USA-states',
            text = df['state'],
            marker = dict(
                line = dict (
                    color = 'rgb(255,255,255)',
                    width = 2
                ) ),
            colorbar = dict(
                title = "Donors")
            ) ]

    layout = dict(
            title = t,
            geo = dict(
                scope='usa',
                projection=dict( type='albers usa' ),
                showlakes = True,
                lakecolor = 'rgb(255, 255, 255)'),
                 )

    fig = dict( data=data, layout=layout )
    iplot( fig, filename='d3-cloropleth-map' )

# %% [markdown]
# ## <a id="3.6"> 3.6 ¿Qué estados recibieron los mayores importes de donaciones individuales?</a>
# - 3.6.1 Estados con los mayores importes de donaciones
# - 3.6.2 Ciudades con los mayores importes de donaciones

# %%
# Maximum Donation Amounts 
tempdf = combined_df.groupby(['Donor State']).agg({'Donation Amount':'max'}).reset_index()
t1 = tempdf.sort_values('Donation Amount', ascending=False)

tempdf = combined_df.groupby(['Donor City']).agg({'Donation Amount':'max'}).reset_index()
t2 = tempdf.sort_values('Donation Amount', ascending=False)

statesdf = pd.DataFrame()
statesdf['state'] = t1['Donor State']
statesdf['counts'] = t1['Donation Amount']
statesdf

citydf = pd.DataFrame()
citydf['state'] = t2['Donor City']
citydf['counts'] = t2['Donation Amount']
citydf

scl = [
    [0.0, 'rgb(240,240,240)'],
    [0.2, 'rgb(220,220,220)'],
    [0.4, 'rgb(180,180,180)'],
    [0.6, 'rgb(154,154,154)'],
    [0.8, 'rgb(117,117,117)'],
    [1.0, 'rgb(84,84,84)']
]

mapp(statesdf, scl, 'Donaciones Máximas Individuales por Estado')

trace1 = bar_hor_noagg(
    list(reversed(list(statesdf['state'][:10]))),
    list(reversed(list(statesdf['counts'][:10]))),
    "Principales Estados con la Donación Individual Más Alta",
    '#a8a1a3',
    600,
    400,
    200,
    limit=10,
    rt=True
)

trace2 = bar_hor_noagg(
    list(reversed(list(citydf['state'][:10]))),
    list(reversed(list(citydf['counts'][:10]))),
    "Principales Ciudades con la Donación Individual Más Alta",
    '#a8a1a3',
    600,
    400,
    200,
    limit=10,
    rt=True
)

fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        'Principales Estados con la Donación Individual Más Alta',
        'Principales Ciudades con la Donación Individual Más Alta'
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

fig['layout'].update(height=400, showlegend=False)

iplot(fig)

# %% [markdown]
# > - Hawái y Colorado son los estados con menor número de donaciones, pero de ellos provienen los importes de donación más elevados.
# > - Ciudades: Anahola, Lafayette y Palo Alto han contribuido con las mayores cantidades: 60.000, 31.000 y 26.000.
#
# ## <a id="3.7"> 3.7 ¿Qué estado recibe los importes promedio de donación más elevados?</a>

# %% [markdown]
# > - Hawái y Massachusetts tienen los importes promedio de donación más elevados.
# > - Clarks Point, Swiftwater y North English son las ciudades desde las que se reciben los importes promedio de donación más elevados.
#
# ## <a id="3.8"> 3.8 Importes totales donados por cada estado </a>

# %% [markdown]
# > - Hawái y Massachusetts tienen los importes promedio de donación más elevados.
# > - Clarks Point, Swiftwater y North English son las ciudades desde las que se reciben los importes promedio de donación más elevados.
#
# ## <a id="3.8"> 3.8 Importes totales donados por cada estado </a>

# %%
# Mean Donation Amounts 
tempdf = combined_df.groupby(['Donor State']).agg({'Donation Amount':'mean'}).reset_index()
t1 = tempdf.sort_values('Donation Amount', ascending=False)

tempdf = combined_df.groupby(['Donor City']).agg({'Donation Amount':'mean'}).reset_index()
t2 = tempdf.sort_values('Donation Amount', ascending=False)

statesdf = pd.DataFrame()
statesdf['state'] = t1['Donor State']
statesdf['counts'] = t1['Donation Amount']
statesdf

citydf = pd.DataFrame()
citydf['state'] = t2['Donor City']
citydf['counts'] = t2['Donation Amount']
citydf

scl = [
    [0.0, 'rgb(248,255,206)'],
    [0.2, 'rgb(203,255,205)'],
    [0.4, 'rgb(155,255,164)'],
    [0.6, 'rgb(79,255,178)'],
    [0.8, 'rgb(15,183,132)'],
    [1, '#008059']
]

# scl = [[0.0, 'rgb(240,240,240)'],[0.2, 'rgb(220,220,220)'],[0.4, 'rgb(180,180,180)'], [0.6, 'rgb(154,154,154)'],[0.8, 'rgb(117,117,117)'],[1.0, 'rgb(84,84,84)']]

mapp(statesdf, scl, 'Monto Promedio de Donaciones por Estado')

trace1 = bar_hor_noagg(
    list(reversed(list(statesdf['state'][:10]))),
    list(reversed(list(statesdf['counts'][:10]))),
    "Principales Estados por Monto Promedio Donado",
    '#a8a1a3',
    600,
    400,
    200,
    limit=10,
    rt=True
)

trace2 = bar_hor_noagg(
    list(reversed(list(citydf['state'][:10]))),
    list(reversed(list(citydf['counts'][:10]))),
    "Principales Ciudades por Monto Promedio Donado",
    '#a8a1a3',
    600,
    400,
    200,
    limit=10,
    rt=True
)

fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        'Estados con Mayor Monto Promedio Donado',
        'Ciudades con Mayor Monto Promedio Donado'
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

fig['layout'].update(height=400, showlegend=False)

iplot(fig)

# %%
statesll=StringIO("""State,Latitude,Longitude
Alabama,32.806671,-86.791130
Alaska,61.370716,-152.404419
Arizona,33.729759,-111.431221
Arkansas,34.969704,-92.373123
California,36.116203,-119.681564
Colorado,39.059811,-105.311104
Connecticut,41.597782,-72.755371
Delaware,39.318523,-75.507141
District of Columbia,38.897438,-77.026817
Florida,27.766279,-81.686783
Georgia,33.040619,-83.643074
Hawaii,21.094318,-157.498337
Idaho,44.240459,-114.478828
Illinois,40.349457,-88.986137
Indiana,39.849426,-86.258278
Iowa,42.011539,-93.210526
Kansas,38.526600,-96.726486
Kentucky,37.668140,-84.670067
Louisiana,31.169546,-91.867805
Maine,44.693947,-69.381927
Maryland,39.063946,-76.802101
Massachusetts,42.230171,-71.530106
Michigan,43.326618,-84.536095
Minnesota,45.694454,-93.900192
Mississippi,32.741646,-89.678696
Missouri,38.456085,-92.288368
Montana,46.921925,-110.454353
Nebraska,41.125370,-98.268082
Nevada,38.313515,-117.055374
New Hampshire,43.452492,-71.563896
New Jersey,40.298904,-74.521011
New Mexico,34.840515,-106.248482
New York,42.165726,-74.948051
North Carolina,35.630066,-79.806419
North Dakota,47.528912,-99.784012
Ohio,40.388783,-82.764915
Oklahoma,35.565342,-96.928917
Oregon,44.572021,-122.070938
Pennsylvania,40.590752,-77.209755
Rhode Island,41.680893,-71.511780
South Carolina,33.856892,-80.945007
South Dakota,44.299782,-99.438828
Tennessee,35.747845,-86.692345
Texas,31.054487,-97.563461
Utah,40.150032,-111.862434
Vermont,44.045876,-72.710686
Virginia,37.769337,-78.169968
Washington,47.400902,-121.490494
West Virginia,38.491226,-80.954453
Wisconsin,44.268543,-89.616508
Wyoming,42.755966,-107.302490""")

tempdf = combined_df.groupby(['Donor State']).agg({'Donation Amount':'sum'}).reset_index()
t1 = tempdf.sort_values('Donation Amount', ascending=False)

sdf = pd.read_csv(statesll).rename(columns={'State':'Donor State'})
sdf = sdf.merge(t1, on='Donor State', how='inner')

map4 = folium.Map(location=[39.50, -98.35], tiles='CartoDB dark_matter', zoom_start=3.5)
for j, rown in sdf.iterrows():
    rown = list(rown)
    folium.CircleMarker([float(rown[1]), float(rown[2])], popup=rown[0]+": $"+str(int(rown[3])), radius=float(rown[3])*0.000001, color='blue', fill=True).add_to(map4)
map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb93e8c13e2c83b1720eefe29abb7a35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb93e8c13e2c83b1720eefe29abb7a35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb93e8c13e2c83b1720eefe29abb7a35 = L.map(
#                 &quot;map_cb93e8c13e2c83b1720eefe29abb7a35&quot;,
#                 {
#                     center: [39.5, -98.35],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96d6b6a34f63662b4c3bdd4e8e8d0378 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_96d6b6a34f63662b4c3bdd4e8e8d0378.addTo(map_cb93e8c13e2c83b1720eefe29abb7a35);
#
#
#             var circle_marker_b49d7693f449075e5d00ccb06da8cbf6 = L.circleMarker(
#                 [36.116203, -119.681564],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.0008807299999999999, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cb93e8c13e2c83b1720eefe29abb7a35);
#
#
#         var popup_c096811f3aec1b21489fb7cb8c290290 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_065eaedc23767f84b8a916dccda18d7d = $(`&lt;div id=&quot;html_065eaedc23767f84b8a916dccda18d7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;California: $880&lt;/div&gt;`)[0];
#                 popup_c096811f3aec1b21489fb7cb8c290290.setContent(html_065eaedc23767f84b8a916dccda18d7d);
#
#
#
#         circle_marker_b49d7693f449075e5d00ccb06da8cbf6.bindPopup(popup_c096811f3aec1b21489fb7cb8c290290)
#         ;
#
#
#
#
#             var circle_marker_6fdf8a8608d1c79715cc368cb777c46b = L.circleMarker(
#                 [42.165726, -74.948051],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.00019821999999999996, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cb93e8c13e2c83b1720eefe29abb7a35);
#
#
#         var popup_555cf822a628277bc7dc79c4e2944569 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e02b6569b39bb12974d0c93eea17f664 = $(`&lt;div id=&quot;html_e02b6569b39bb12974d0c93eea17f664&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York: $198&lt;/div&gt;`)[0];
#                 popup_555cf822a628277bc7dc79c4e2944569.setContent(html_e02b6569b39bb12974d0c93eea17f664);
#
#
#
#         circle_marker_6fdf8a8608d1c79715cc368cb777c46b.bindPopup(popup_555cf822a628277bc7dc79c4e2944569)
#         ;
#
#
#
#
#             var circle_marker_49a8ce73393e6d00edce7580a24c3fed = L.circleMarker(
#                 [31.054487, -97.563461],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.00234783, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cb93e8c13e2c83b1720eefe29abb7a35);
#
#
#         var popup_7e0bc5f61f4d2a94e84d5092cadb2c62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_692406015c403e74321b96e516253bec = $(`&lt;div id=&quot;html_692406015c403e74321b96e516253bec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Texas: $2347&lt;/div&gt;`)[0];
#                 popup_7e0bc5f61f4d2a94e84d5092cadb2c62.setContent(html_692406015c403e74321b96e516253bec);
#
#
#
#         circle_marker_49a8ce73393e6d00edce7580a24c3

# %% [markdown]
# ## <a id="3.9"> 3.9 Donaciones de California a lo largo del tiempo</a>
#
# Veamos la tendencia de las donaciones provenientes de California a lo largo de los años.

# %%
combined_df['Fecha de Donación'] = combined_df['Donation Received Date'].apply(lambda x : str(x).split()[0])
cali = combined_df[combined_df['Donor State'] == 'California']
cali = cali.groupby('Fecha de Donación').agg({'Donation Amount' : 'count'}).reset_index()
cali1 = pd.DataFrame()
cali1['Fecha'] = pd.to_datetime(cali['Fecha de Donación']) 
cali1['Donation Amount'] = cali['Donation Amount']


trace1 = go.Scatter(x=cali1['Fecha'], y=cali1['Donation Amount'], name = "California", line = dict(color = 'red'), opacity = 0.8)

data = [trace1]
layout = dict(title="Donaciones de California a lo largo del tiempo", height=400, showlegend=False, yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    ))
fig = dict(data=data, layout=layout)
iplot(fig)

# %% [markdown]
# > El mayor número de donaciones provenientes de California se registró el **25 de enero de 2018**, con casi 5000 donaciones, seguido por el **28 de noviembre de 2017**, con 4699 donaciones.
#
# ## <a id="4"> 4. Exploración de los datos de los docentes </a>
# ## <a id="4.1"> 4.1 Panorama general de los datos de los docentes </a>

# %%
teachers_df.head(3)
# len(teachers_df)
# Out:
#                          Teacher ID Teacher Prefix  \
# 0  bdd640fb06671ad11c80317fa3b1799d           Mrs.
# 1  ad3c2d6d1a3d1fa7bc8960a923b8c1e9            Ms.
# 2  0822e8f36c031199972a846916419f82           Mrs.
#
#   Teacher First Project Posted Date
# 0                        2007-01-03
# 1                        2014-03-26
# 2                        2006-11-27

# %% [markdown]
# Un total de 402.900 docentes han publicado al menos un proyecto en DonorsChoose desde 2002. La gran mayoría son mujeres; veamos quiénes fueron los primeros docentes en publicar proyectos en DonorsChoose.
#
# ## <a id="4.2"> 4.2 ¿Quiénes fueron los primeros docentes en DonorsChoose.org? </a>

# %%
teachers_df['Posted Date'] = pd.to_datetime(teachers_df['Teacher First Project Posted Date'])
teachers_df['Posted Year'] = teachers_df['Posted Date'].dt.year

# Lets Find out who were the first donors on DonorsChooseSome of the Earliest Teachers 
teachers_df[['Teacher ID', 'Posted Date']].sort_values(['Posted Date'])[:10]
# Out:
#                            Teacher ID Posted Date
# 29   6f4cc69a4b22d3081c8eaee95715bd6f  2002-01-27
# 78   d450281c6c6f7633a260772317a0df49  2002-01-30
# 114  25c73c443e75c3b4664fa6637e8f8095  2002-02-15
# 68   c07a30f2edd4253b50f0fd0a750cab75  2002-03-18
# 80   b4a69f3c8d3aed99711c21c9bdc14f1f  2002-03-21
# 54   ffd0f9d5a6f2f7b80cf35b5819108be5  2002-05-01
# 162  b63b4dc3a559e46379e13ceab0cbc61f  2002-05-22
# 42   3985c3cf3f76be1d1efa21977394988f  2002-06-22
# 87   2d534dd0cf8ebc5accc56569f9e8a369  2002-07-23
# 95   89456f27d7fa2d8dfb2ca025adf4e62d  2002-08-15

# %% [markdown]
# > Los primeros docentes en DonorsChoose se registraron el 17 de septiembre de 2002; ese día se inscribieron dos docentes, ambas mujeres. En el mes de septiembre de 2002 se registró un total de ocho docentes, quienes constituyeron esencialmente el primer grupo de maestros en DonorsChoose.
#
# ## <a id="4.3"> 4.3 Crecimiento del número de docentes a lo largo de los años </a>

# %%
temp = teachers_df.groupby('Posted Year').agg({'Teacher ID' : 'count'}).reset_index()
temp = temp.sort_values('Posted Year')

trace = go.Scatter(
        x=list(temp['Posted Year'])[:-1],
        y=list(temp['Teacher ID'])[:-1],
        mode='lines+markers',
        line=dict(color="#42e5f4", width=8),
        connectgaps=True,
    fillcolor='rgba(0,100,80,0.2)',
    )

layout = go.Layout(
    xaxis=dict(
        showline=True,
        showgrid=False,
        showticklabels=True,
        linecolor='rgb(204, 204, 204)',
        linewidth=2,
        ticks='outside',
        tickcolor='rgb(204, 204, 204)',
        tickwidth=2,
        ticklen=5,
        tickfont=dict(
            family='Arial',
            size=12,
            color='rgb(82, 82, 82)',
        ),
    ),
    title = 'Número de profesores que comenzaron a publicar sus proyectos por año')


fig = go.Figure(data=[trace], layout=layout)
iplot(fig, filename='news-source')

# %% [markdown]
# > - Algunos maestros comenzaron a publicar en DonorsChoose cuando se lanzó en 2002, pero durante los primeros cinco años el número de docentes que publicaban proyectos fue muy bajo.
# > - Hacia 2008 comenzó a surgir una tendencia al alza, y el periodo **2012-2013** registró un aumento masivo en el número de maestros que publicaban proyectos.
# > - La tendencia alcanzó su punto máximo en 2016, con 80.000 nuevos maestros publicando proyectos, aunque la cifra **descendió a 75.000 en 2017**. No solo es necesario motivar a los donantes, sino también incentivar a los maestros para que publiquen más proyectos; al observar el crecimiento de nuevos docentes a lo largo de los años, parece que DonorsChoose está realizando un buen trabajo.
#
# ## <a id="4.4"> 4.4 ¿Cuál es la distribución de los títulos (prefijos) de los maestros? </a>

# %%
t = teachers_df['Teacher Prefix'].value_counts()

labels = t.index
values2 = t.values
trace2 = go.Pie(labels=labels, values=values2, marker=dict(colors=['#75e575', '#ea7c96',]))

layout = go.Layout(title='Número de donaciones con donaciones opcionales', width=800, height=500)
fig = go.Figure(data=[trace2], layout=layout)
iplot(fig)

# %% [markdown]
# ## <a id="4.5"> 4.5 Serie temporal de docentes que publican sus primeros proyectos </a>

# %%
t = teachers_df['Posted Date'].value_counts()#[:10]
x = t.index
y = t.values
bar_ver_noagg(x, y, 'Fecha y primeros proyectos de profesores', 'orange')

# %% [markdown]
# > - El mayor número de proyectos nuevos se registró el **13 de septiembre de 2015, con un total de 2067 proyectos**.
# > - Cabe destacar que se observan picos cada mes de agosto entre 2014 y 2017.
#
# ## <a id="5"> 5. Exploración de datos de escuelas </a>
# ## <a id="5.1"> 5.1 Resumen de los datos de las escuelas </a>

# %%
schools_df = pd.read_csv(path+"Schools.csv", on_bad_lines='skip')
schools_df.head(3)

# len(schools_df)
# Out:
#                           School ID                  School Name  \
# 0  bdd640fb06671ad11c80317fa3b1799d      Miami Elementary School
# 1  07a0ca6e0822e8f36c031199972a8469    Houston Elementary School
# 2  a65ed389b74d0fb132e706298fadc1a6  Sammamish Elementary School
#
#   School Metro Type  School Percentage Free Lunch School State  School Zip  \
# 0             urban                          17.0      Florida       23434
# 1             urban                          64.0        Texas       88907
# 2              town                          75.0   Washington       46463
#
#   School City     School County            School District
# 0       Miami      Miami County      Miami School District
# 1     Houston    Houston County    Houston School District
# 2   Sammamish  Sammamish County  Sammamish School District

# %% [markdown]
# > Hasta abril de 2018, se habían publicado proyectos de un total de 72.993 escuelas diferentes en DonorsChoose.
#
# ## <a id="5.2"> 5.2 ¿Qué tipo de escuelas (según su entorno) publican proyectos? (y principales estados y ciudades) </a>

# %%
t1 = schools_df['School Metro Type'].value_counts()
t2 = schools_df['School State'].value_counts()
t3 = schools_df['School City'].value_counts()


trace1 = bar_ver_noagg(t1.index[:10], t1.values[:10], "Tipo de zona escolar", '#e56eb5', None, None, 0,  rt=True)
trace2 = bar_ver_noagg(t2.index[:10], t2.values[:10], "Estados con mayor cantidad de escuelas", '#e88de8', None, None, 0,  rt=True)
trace3 = bar_ver_noagg(t3.index[:10], t3.values[:10], "Ciudades con mayor cantidad de escuelas", '#efc4ef', None, None, 0,  rt=True)

fig = tools.make_subplots(rows=1, cols=3, print_grid=False, subplot_titles = ['Tipo de zona escolar', 'Estados con mayor cantidad de escuelas', 'Ciudades con mayor cantidad de escuelas'])
fig.append_trace(trace1, 1, 1);
fig.append_trace(trace2, 1, 2);
fig.append_trace(trace3, 1, 3);
fig['layout'].update(height=400, showlegend=False);
iplot(fig);

# %% [markdown]
# > - La mayoría de las escuelas se encuentran en zonas suburbanas y urbanas
# > - Nueva York, Houston y Chicago son las tres ciudades principales donde se ubican las escuelas
#
# ## <a id="5.3"> 5.3 Distribución del porcentaje de escuelas con almuerzo gratuito </a>

# %%
# extraer tipos de escuelas 
plt.figure(figsize=(15,5))
sns.distplot(schools_df['School Percentage Free Lunch'].dropna(), bins=120, color="#ff002e")
plt.xlabel('Porcentaje de almuerzo gratis en escuelas', fontsize=14);
plt.title("Distribución del porcentaje de almuerzo gratis en escuelas", fontsize=14);
plt.show();

# %% [markdown]
# ## <a id="5.4"> 5.4 ¿Qué tipos de escuela están registrados mayoritariamente? </a>

# %%
words = " ".join(schools_df['School Name']).split()
from collections import Counter

school_types = Counter(words).most_common(30)[1:9]
school_types = [list(x) for x in school_types]
labels = [x[0]+" School" for x in school_types]
values = [x[1] for x in school_types]

trace2 = go.Bar(
    x=labels,
    y=values,
    name='Donors to Population',
    marker=dict(color='#ff00bb'),
    opacity=0.3
)

data = [trace2]
layout = go.Layout(
    barmode='group',
    legend=dict(dict(x=-.1, y=1.2)),
    title = 'School Types Distribution',
)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')

# %%
words = " ".join(schools_df['School Name']).split()
from collections import Counter

school_types = Counter(words).most_common(30)[1:9]
school_types = [list(x) for x in school_types]
labels = [x[0]+" School" for x in school_types]
values = [x[1] for x in school_types]

trace2 = go.Bar(
    x=labels,
    y=values,
    name='Donantes a población',
    marker=dict(color='#ff00bb'),
    opacity=0.3
)

data = [trace2]
layout = go.Layout(
    barmode='group',
    legend=dict(dict(x=-.1, y=1.2)),
    title = 'Distribución de tipos de escuelas',
)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')

# %% [markdown]
# > La gran mayoría de los centros educativos son escuelas de educación primaria (unas 35.000), una cifra muy superior a la de las escuelas de educación secundaria superior (unas 12.000), las de educación secundaria intermedia (unas 9.000) o las academias (unas 4.000).
#
# ## <a id="6"> 6. Exploración de recursos </a>
#
# Los datos sobre recursos comprenden los artículos solicitados en el marco de distintos proyectos e incluyen el nombre del artículo, la cantidad, el precio unitario y el nombre del proveedor.
#
# ## <a id="6.1"> 6.1 Panorama general de los recursos </a>

# %%
resources_df = pd.read_csv(path+"Resources.csv")
resources_df.head(5)

# len(resources_df)
# Out:
#                          Project ID  \
# 0  bdd640fb06671ad11c80317fa3b1799d
# 1  f143262fdc5c0eed8da0365bf89897b9
# 2  451b4cf36123fdf77656af7229d4beef
# 3  0e51f30dc6a7ee39c4b032ccd7c524a5
# 4  0e51f30dc6a7ee39c4b032ccd7c524a5
#
#                           Resource Item Name  Resource Quantity  \
# 0  gaiam kids stay-n-play balance ball, grey               44.0
# 1                      apple ipad wi-fi 32gb                8.0
# 2              sony mdr zx100 blk headphones               17.0
# 3  gaiam kids stay-n-play balance ball, grey               41.0
# 4              serta lounger, mini, sky blue               10.0
#
#    Resource Unit Price          Resource Vendor Name
# 0               398.73  Lakeshore Learning Materials
# 1               135.61               Amazon Business
# 2               437.49               Amazon Business
# 3               137.81                           NaN
# 4               171.39               Amazon Business

# %% [markdown]
# > A fecha de abril de 2018, los docentes habían realizado un total de 7 210 448 solicitudes de recursos en diversos proyectos.
#
# ## <a id="6.2"> 6.2 Elementos más populares </a>
#
# Identifiquemos los elementos más populares a partir de los datos sobre recursos. Los elementos más solicitados son aquellos que aparecen en un gran número de proyectos; por su parte, los elementos solicitados en grandes cantidades son aquellos que se pidieron en volúmenes elevados.
#
# - 6.2.1 Elementos más solicitados de todos los tiempos
# - 6.2.2 Elementos solicitados en grandes cantidades

# %%
tdf = resources_df['Resource Item Name'].value_counts()[:15]
t = pd.DataFrame()
t['item'] = tdf.index 
t['count'] = tdf.values
t['standardized'] = list(reversed("""Kids Stay N Play Ball, Apple Ipad, HP 11'6 Chromebook, Black write and wipe markers , Kids Stay N Play Ball, Soft Seats, Privacy Partition, Apple Ipad, Commercial Furniture, Apple Ipad, Apple Ipad, Noise, Apple Ipad, Noise, Trip""".split(",")))
t1 = t.groupby('standardized').agg({'count' : 'sum'}).reset_index()
t1 = t1.sort_values('count', ascending = True)
t1 = t1[t1['standardized'] != " Noise"]
trace1 = bar_ver_noagg(list(reversed(list(t1['standardized']))), list(reversed(list(t1['count']))), "Most Requested Resource Items", "#ff5479", 400, 400, 0, rt=True)

t = resources_df.sort_values('Resource Quantity', ascending=False).head(10)
trace2 = bar_ver_noagg(t['Resource Item Name'], t['Resource Quantity'], "Most Expensive Resource Items", "#fc839d", 600, 400, 0, rt=True)

fig = tools.make_subplots(rows=1, cols=2, print_grid=False, subplot_titles = ['Most Requested Items' , 'Items Requested in Bulk'])
fig.append_trace(trace1, 1, 1);
fig.append_trace(trace2, 1, 2);
fig['layout'].update(height=400, showlegend=False, margin=dict(b=120));
iplot(fig);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 5
#       3 t['item'] = tdf.index
#       4 t['count'] = tdf.values
# ----> 5 t['standardized'] = list(reversed("""Kids Stay N Play Ball, Apple Ipad, HP 11'6 Chromebook, Black write and wipe markers , Kids Stay N Play Ball, Soft Seats, Privacy Partition, Apple Ipad, Commercial Furniture, Apple Ipad, Apple Ipad, Noise, Apple Ipad, Noise, Trip""".split(",")))
#       6 t1 = t.groupby('standardized').agg({'count' : 'sum'}).reset_index()
#       7 t1 = t1.sort_values('count', ascending = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
#    4528
#    (...)   4533     ensure homogeneity.
#    4534     """
# -> 4535     value, refs = self._sanitize_column(value)
#    4537     if (
#    4538         key in self.columns
#    4539         and value.ndim == 1
#    4540         and not isinstance(value.dtype, ExtensionDtype)
#    4541     ):
#    4542         # broadcast across multiple columns if necessary
#    4543         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5288, in DataFrame._sanitize_column(self, value)
#    5285     return _reindex_for_setitem(value, self.index)
#    5287 if is_list_like(value):
# -> 5288     com.require_length_match(value, self.index)
#    5289 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5290 if (
#    5291     isinstance(value, Index)
#    5292     and value.dtype == "object"
#    (...)   5295     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5296     # this deprecation
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (15) does not match length of index (9)
