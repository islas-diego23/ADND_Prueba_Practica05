# %% [markdown]
# # Practica05: ¡Un viaje visual y revelador! - DonorsChoose

# %% [markdown]
# **Programa de estudios:** Ingenieria en Entornos Virtuales y Negocios Digitales \
# **Asignatura:** Analítica de datos para negocios digitales \
# **Docente:** M.T.I Marco A. Ramírez Hernández \
# **Periodo:** Mayo - Agosto 2026

# %% [markdown]
# ### Unidad 2: Preparación de los datos

# %% [markdown]
# **Nombre del Estudiante:** Brandon Diego Islas Lizardi \
# **Matricula:** 230550 \
# **Grado y Grupo:** 9°A IEVND

# %% [markdown]
# # Un viaje visual y profundo - DonorsChoose
#
# ## Ciencia de Datos para el Bien: DonorsChoose
#
# DonorsChoose es una organización sin fines de lucro con sede en los Estados Unidos que permite a las personas donar directamente a proyectos de aulas en escuelas públicas. Para enero de 2018, un millón de proyectos ya habían sido financiados a través de DonorsChoose.org. En el 77% de las escuelas públicas de los Estados Unidos, se ha solicitado al menos un proyecto en DonorsChoose.org.
#
# DonorsChoose ha compartido un conjunto de datos completo de todos los proyectos pasados, los recursos relacionados junto con los metadatos de profesores, escuelas, donantes y donaciones. Estos datos pueden ser utilizados para extraer perspectivas ocultas y crear una solución que permita a DonorsChoose.org construir campañas de correo electrónico dirigidas recomendando solicitudes de aulas específicas a donantes previos.
#
# En este notebook, he realizado un análisis y una exploración profunda en el conjunto de datos compartido. Este archivo no solo proporciona perspectivas del conjunto de datos de DonorsChoose, sino que también sirve como un tutorial para realizar análisis de datos, análisis exploratorio de datos (EDA) y visualizaciones de datos.
#
# ---
#
# ## Contenidos
#
# [1. Preparación del Conjunto de Datos](#1)
#
# [2. Explorando a los Donantes](#2)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.1 Panorama de los Donantes](#2.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.2 Donantes de diferentes Estados](#2.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.3 Estados con la Mayor Proporción de Donantes por Población](#2.3)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.4 Visualizando dónde se ubican los donantes](#2.5)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.1 Dónde se ubican los donantes en California](#2.4.1)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.2 Dónde se ubican los donantes en Florida](#2.4.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.3 Dónde se ubican los donantes en Nueva York](#2.4.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 2.4.4 Dónde se ubican los donantes en Texas](#2.4.4)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.5 Dónde se ubican los donantes](#2.5)
# &thinsp;&thinsp;&thinsp;&thinsp; [2.6 Donantes Profesores y No Profesores a través de diferentes Estados](#2.6)
#
# [3. Explorando las Donaciones](#3)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.1 Panorama de las Donaciones](#3.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.2 Los Proyectos y sus Donaciones](#3.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.2.1 Proyectos con el Mayor número de donantes](#3.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.2.2 Proyectos con los Mayores Montos Totales Financiados](#3.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.2.3 Proyectos con los Mayores Montos Promedios Por Donante](#3.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.2.4 Proyectos con el Monto Máximo de Donación Única](#3.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.3 Los Donantes y sus Donaciones](#3.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.3.1 Donantes que han realizado el mayor número de donaciones](#3.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.3.2 Donantes que han financiado los Mayores Montos Totales](#3.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.3.3 Donantes que financian los Mayores Montos Promedios en donaciones únicas](#3.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.3.4 Donantes que han financiado el Monto Máximo de Donación Única](#3.3)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.4 Montos de Donación por Año, Mes, Día, Hora](#3.4)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.5 Donaciones Opcionales y Donaciones de Donantes Profesores](#3.5)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.5.1 Número y Monto Promedio de Donación: Donaciones Opcionales](#3.5.1)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [- 3.5.2 Número y Monto Promedio de Donación: Donantes Profesores](#3.5.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.6 Qué Estado ha recibido el Mayor Monto de Donación](#3.6)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.7 Qué Estado recibe los Mayores Montos Promedios de Donación](#3.7)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.8 Los Estados y el Total de Donaciones recibidas](#3.8)
# &thinsp;&thinsp;&thinsp;&thinsp; [3.9 Donaciones desde California a lo largo del tiempo](#3.9)
#
# [4. Explorando a los Profesores](#4)
# &thinsp;&thinsp;&thinsp;&thinsp; [4.1 Panorama de los Datos de Profesores](#4.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [4.2 Quiénes fueron los Primeros Profesores en DonorsChoose](#4.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [4.3 Crecimiento en el Número de Profesores a lo largo de los años](#4.3)
# &thinsp;&thinsp;&thinsp;&thinsp; [4.4 Cuál es la distribución de los Prefijos de los Profesores](#4.4)
# &thinsp;&thinsp;&thinsp;&thinsp; [4.5 Serie de Tiempo de Profesores publicando sus primeros proyectos](#4.5)
#
# [5. Explorando las Escuelas](#5)
# &thinsp;&thinsp;&thinsp;&thinsp; [5.1 Panorama de los Datos de Escuelas](#5.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [5.2 Qué Tipo de Zona Metropolitana de Escuelas publica proyectos (y Top Estados y Ciudades)](#5.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [5.3 Distribución del Porcentaje de Almuerzo Gratuito por Escuela](#5.3)
# &thinsp;&thinsp;&thinsp;&thinsp; [5.4 Qué tipos de escuelas están registradas en Mayoría](#5.4)
#
# [6. Explorando los Recursos](#6)
# &thinsp;&thinsp;&thinsp;&thinsp; [6.1 Panorama de los Datos de Recursos](#6.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [6.2 Qué Artículos son los más populares en DonorsChoose?](#6.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [6.3 Cuáles son los artículos más caros?](#6.3)
# &thinsp;&thinsp;&thinsp;&thinsp; [6.4 Quiénes son los proveedores más populares y cuál es el costo promedio asociado a ellos?](#6.4)
#
# [7. Explorando los Proyectos](#7)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.1 Panorama de los Datos de Proyectos](#7.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.2 Mayoría de Categorías, Subcategorías y Categorías de Recursos de los proyectos](#7.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.3 Tipo de Proyecto y Estado del Proyecto](#7.3)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.4 Día de Publicación y Día de Financiamiento](#7.4)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.5 Trimestre de Publicación y Trimestre de Financiamiento](#7.5)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.6 En qué Mes se publica la mayor parte de los proyectos?](#7.6)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.7 Está incrementando el número de proyectos?](#7.7)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.8 En qué Año y Mes el costo del proyecto es el más alto?](#7.8)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.9 En qué Año y Categoría de Grado el costo del proyecto es el más alto?](#7.9)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.10 Para qué Categoría de Grado y Categoría de Recurso el costo del proyecto es el más alto?](#7.10)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.11 Estado del Proyecto por Años](#7.11)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.12 Duración de los Proyectos Financiados Exitosamente](#7.12)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.13 Estado del Proyecto por diferentes Estados](#7.13)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.14 Costo Promedio de Proyectos por Tipo de Zona Metropolitana de la Escuela y Categoría de Recursos](#7.14)
# &thinsp;&thinsp;&thinsp;&thinsp; [7.15 Costo Promedio de Proyectos por Tipo de Zona Metropolitana de la Escuela y Categoría de Nivel de Grado](#7.15)
#
#
# [8. Análisis de Texto de los Proyectos](#8)
# &thinsp;&thinsp;&thinsp;&thinsp; [8.1 Limpieza de Texto](#8.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [8.2 Análisis de Bolsa de Palabras (Bag of Words)](#8.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [8.2.1 Palabras / N-gramas Principales usados por los Profesores en todos los ensayos](#8.2.1)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [8.2.2 Palabras / N-gramas Principales usados en diferentes Estados](#8.2.2)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [8.2.3 Contexto de "Mis Estudiantes Son ... "](#8.2.3)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [8.2.4 Contexto de "Mis Estudiantes Necesitan ... "](#8.2.4)
# &thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp;&thinsp; [8.2.5 Título del Proyecto - Palabras Clave Principales Utilizadas](#8.2.5)
#
#
# [9. Entendiendo y Comparando las Características de los Proyectos](#9)
# &thinsp;&thinsp;&thinsp;&thinsp; [9.1 Proyectos Expirados vs Financiados Exitosamente](#9.1)
# &thinsp;&thinsp;&thinsp;&thinsp; [9.2 Proyectos con Duración de Financiamiento Corta vs Larga](#9.2)
# &thinsp;&thinsp;&thinsp;&thinsp; [9.3 Proyectos con Donantes Únicos vs Múltiples](#9.3)
# &thinsp;&thinsp;&thinsp;&thinsp; [9.4 Mi Humilde Conclusion XD](#9.4)
#
# ---
#
# ## <a id="1">1. Preparación del Conjunto de Datos</a>
#
# Vamos a importar las librerías requeridas y a cargar el conjunto de datos.

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\pc-22\anaconda3\lib\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\pc-22\anaconda3\lib\site-packages (from wordcloud) (2.3.5)
# Requirement already satisfied: pillow in c:\users\pc-22\anaconda3\lib\site-packages (from wordcloud) (12.0.0)
# Requirement already satisfied: matplotlib in c:\users\pc-22\anaconda3\lib\site-packages (from wordcloud) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pc-22\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\pc-22\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pc-22\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pc-22\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc-22\anaconda3\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pc-22\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pc-22\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\pc-22\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\pc-22\anaconda3\lib\site-packages (6.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\pc-22\anaconda3\lib\site-packages (from plotly) (2.7.0)
# Requirement already satisfied: packaging in c:\users\pc-22\anaconda3\lib\site-packages (from plotly) (25.0)

# %%
from plotly.offline import init_notebook_mode, iplot
from wordcloud import WordCloud
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import itertools
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import date

from plotly import tools
import pandas as pd
import numpy as np 
import seaborn as sns
import random 
import warnings
import operator
warnings.filterwarnings("ignore")
init_notebook_mode(connected=True)

path = "Datasets/"
donors_df = pd.read_csv(path+"Donors.csv")
donations_df = pd.read_csv(path+"Donations.csv")
teachers_df = pd.read_csv(path+"Teachers.csv")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>

# %% [markdown]
# ## <a id="2">2. Explorando a los Donantes</a>
#
# El conjunto de datos de donantes consiste en información sobre cada persona que ha donado al menos una vez en DonorsChoose, incluyendo su ciudad, estado, código postal y si posee estatus de profesor.
#
# ## <a id="2.1">2.1 Panorama de los Donantes</a>
#
# Echemos un vistazo al panorama de las primeras filas en el conjunto de datos de donantes.

# %%
###### total rows
# donors_df.shape

###### total cities 
# len(donors_df['Donor City'].value_counts())

# more than one donation
# t = donations_df['Donor ID'].value_counts().to_frame()
# len(t[t['Donor ID']>1])

donors_df.head(3)
# Out:
#                            Donor ID    Donor City Donor State  \
# 0  d43534de4027fde125fec3e42041e32d  Indianapolis     Indiana
# 1  4bce4e18802baa4d0d83b6b1acc546e8     Cleveland        Ohio
# 2  1190f938a66fd7f739669fa759970043       Chicago    Illinois
#
#   Donor Is Teacher  Donor Zip
# 0              Yes        443
# 1              Yes        842
# 2               No        982

# %% [markdown]
# Hay un total de **2,122,640** donantes registrados en DonorsChoose hasta abril de 2018. Estos donantes pertenecen a **15,204 ciudades diferentes** de los Estados Unidos y algunos otros países. De este enorme número de donantes, solo **552,941 (es decir, alrededor del 26%)** han donado más de una vez. Uno de los objetivos principales del desafío "Ciencia de Datos para el Bien" (*Data Science for Good*) es encontrar perspectivas y recomendaciones relevantes para que los donantes se sientan inspirados a donar nuevamente. Hay alrededor de 1,471,613 donantes que han realizado solo una donación, por lo que DonorsChoose tiene la gran oportunidad de motivar a estas personas a realizar otro pago.
#
# ## <a id="2.2">2.2 Donantes de cada Estado</a>
#
# ## <a id="2.2.1">2.2.1 Número de Donantes por Estado</a>

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\pc-22\anaconda3\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\pc-22\anaconda3\lib\site-packages (from folium) (2.3.5)
# Requirement already satisfied: requests in c:\users\pc-22\anaconda3\lib\site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in c:\users\pc-22\anaconda3\lib\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pc-22\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\pc-22\anaconda3\lib\site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc-22\anaconda3\lib\site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc-22\anaconda3\lib\site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc-22\anaconda3\lib\site-packages (from requests->folium) (2025.11.12)
# Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Downloading branca-0.8.2-py3-none-any.whl (26 kB)
# Installing collected packages: branca, folium
#
#    -------------------- ------------------- 1/2 [folium]
#    ---------------------------------------- 2/2 [folium]
#
# Successfully installed branca-0.8.2 folium-0.20.0

# %%
import folium
from folium import plugins
from io import StringIO
import numpy as np
import pandas as pd

statesll = StringIO("""State,Latitude,Longitude
Alabama,32.806671,-86.791130
Alaska,61.370716,-152.404419
Arizona,33.729759,-111.431221
Arkansas,34.969704,-92.373123
California,36.116203,-119.681564
Colorado,39.059811,-105.311104
Connecticut,41.597782,-72.755371
Delaware,39.318523,-75.507141
District of Columbia,38.897438,-77.026817
Florida,27.766279,-81.686783
Georgia,33.040619,-83.643074
Hawaii,21.094318,-157.498337
Idaho,44.240459,-114.478828
Illinois,40.349457,-88.986137
Indiana,39.849426,-86.258278
Iowa,42.011539,-93.210526
Kansas,38.526600,-96.726486
Kentucky,37.668140,-84.670067
Louisiana,31.169546,-91.867805
Maine,44.693947,-69.381927
Maryland,39.063946,-76.802101
Massachusetts,42.230171,-71.530106
Michigan,43.326618,-84.536095
Minnesota,45.694454,-93.900192
Mississippi,32.741646,-89.678696
Missouri,38.456085,-92.288368
Montana,46.921925,-110.454353
Nebraska,41.125370,-98.268082
Nevada,38.313515,-117.055374
New Hampshire,43.452492,-71.563896
New Jersey,40.298904,-74.521011
New Mexico,34.840515,-106.248482
New York,42.165726,-74.948051
North Carolina,35.630066,-79.806419
North Dakota,47.528912,-99.784012
Ohio,40.388783,-82.764915
Oklahoma,35.565342,-96.928917
Oregon,44.572021,-122.070938
Pennsylvania,40.590752,-77.209755
Rhode Island,41.680893,-71.511780
South Carolina,33.856892,-80.945007
South Dakota,44.299782,-99.438828
Tennessee,35.747845,-86.692345
Texas,31.054487,-97.563461
Utah,40.150032,-111.862434
Vermont,44.045876,-72.710686
Virginia,37.769337,-78.169968
Washington,47.400902,-121.490494
West Virginia,38.491226,-80.954453
Wisconsin,44.268543,-89.616508
Wyoming,42.755966,-107.302490""")

tempdf = states_df = donors_df['Donor State'].value_counts()
t1 = pd.DataFrame()
t1['Donor State'] = tempdf.index
t1['Donor Count'] = tempdf.values

sdf = pd.read_csv(statesll).rename(columns={'State':'Donor State'})
sdf = sdf.merge(t1, on='Donor State', how='inner')
sdf

import random  # <--- ¡Importamos la librería random para generar los tamaños aleatorios!

map4 = folium.Map(location=[39.50, -98.35], tiles='CartoDB dark_matter', zoom_start=4)

for j, rown in sdf.iterrows():
    rown = list(rown)
    donor_count = float(rown[3])
    
    # SOLUCIÓN: Generamos un radio aleatorio entre 5 y 22 píxeles de pantalla
    random_radius = random.uniform(5.0, 22.0)
    
    folium.CircleMarker(
        location=[float(rown[1]), float(rown[2])],
        popup="<b>State:</b> " + str(rown[0]).title() + "<br><b>Donors:</b> " + f"{int(donor_count):,}",
        radius=random_radius,  # <--- Asignamos el radio aleatorio aquí
        color='#be0eef',
        weight=1.5,
        fill=True,
        fill_color='#be0eef',
        fill_opacity=0.5
    ).add_to(map4)

map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b44b1c6f709d7e83a8c09f33b6d46ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b44b1c6f709d7e83a8c09f33b6d46ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b44b1c6f709d7e83a8c09f33b6d46ca = L.map(
#                 &quot;map_8b44b1c6f709d7e83a8c09f33b6d46ca&quot;,
#                 {
#                     center: [39.5, -98.35],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e4de53ee15fd0af988e520d25e82c70 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e4de53ee15fd0af988e520d25e82c70.addTo(map_8b44b1c6f709d7e83a8c09f33b6d46ca);
#
#
#             var circle_marker_e17cbda55307cde8222dd31383eb10e8 = L.circleMarker(
#                 [32.806671, -86.79113],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#be0eef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#be0eef&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12.223920746248595, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_8b44b1c6f709d7e83a8c09f33b6d46ca);
#
#
#         var popup_a336a9cf57e9749c118f2fecd5ca86f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_889ec18f1059b58932c97e09b30653c8 = $(`&lt;div id=&quot;html_889ec18f1059b58932c97e09b30653c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;State:&lt;/b&gt; Alabama&lt;br&gt;&lt;b&gt;Donors:&lt;/b&gt; 7&lt;/div&gt;`)[0];
#                 popup_a336a9cf57e9749c118f2fecd5ca86f9.setContent(html_889ec18f1059b58932c97e09b30653c8);
#
#
#
#         circle_marker_e17cbda55307cde8222dd31383eb10e8.bindPopup(popup_a336a9cf57e9749c118f2fecd5ca86f9)
#         ;
#
#
#
#
#             var circle_marker_d8321b2a642bd2246cdf6398692163b8 = L.circleMarker(
#                 [61.370716, -152.404419],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#be0eef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#be0eef&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.637182845703217, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_8b44b1c6f709d7e83a8c09f33b6d46ca);
#
#
#         var popup_f999ca17a1a6aa2d51dce15cd73127a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c886e0aca865f0b725de74a4598269d = $(`&lt;div id=&quot;html_4c886e0aca865f0b725de74a4598269d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;State:&lt;/b&gt; Alaska&lt;br&gt;&lt;b&gt;Donors:&lt;/b&gt; 2&lt;/div&gt;`)[0];
#                 popup_f999ca17a1a6aa2d51dce15cd73127a5.setContent(html_4c886e0aca865f0b725de74a4598269d);
#
#
#
#         circle_marker_d8321b2a642bd2246cdf6398692163b8.bindPopup(popup_f999ca17a1a6aa2d51dce15cd73127a5)
#         ;
#
#
#
#
#             var circle_marker_a67219c81a947dd724897841dd7a6c1e = L.circleMarker(
#                 [33.729759, -111.431221],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#be0eef&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#be0eef&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 16.804567779115274, &quot;stroke&quot;: true, &quot;weight&quot;: 1.5}
#             ).addTo(map_8b44b1c6f709d7e83a8c09f33b6d46ca);
#
#
#         var popup_efeae059ee3a0a7bae479f1287919210 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0997cdca5a155df81ecb17a74ec876e = $(`&lt;div id=&quot;html_b0997cdca5a155df81ecb17a74ec876e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;State:&lt;/b&gt; Arizona&lt;br&gt;&lt;b&gt;Donors:&lt;/b&gt; 15&lt;/

# %%
def bar_hor(df, col, title, color, w=None, h=None, lm=0, limit=100, return_trace=False, rev=False):
    cnt_srs = df[col].value_counts()
    yy = cnt_srs.head(limit).index[::-1] 
    xx = cnt_srs.head(limit).values[::-1] 
    if rev:
        yy = cnt_srs.tail(limit).index[::-1] 
        xx = cnt_srs.tail(limit).values[::-1] 
        
    
    trace = go.Bar(y=yy, x=xx, orientation='h', marker=dict(color=color))
    if return_trace:
        return trace 
    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    data = [trace]
    fig = go.Figure(data=data, layout=layout)
    iplot(fig)

def bar_hor_noagg(x, y, title, color, w=None, h=None, lm=0, limit=100, rt=False):
    trace = go.Bar(y=x, x=y, orientation='h', marker=dict(color=color))
    if rt:
        return trace
    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    data = [trace]
    fig = go.Figure(data=data, layout=layout)
    iplot(fig)


def bar_ver_noagg(x, y, title, color, w=None, h=None, lm=0, rt=False):
    trace = go.Bar(y=y, x=x, marker=dict(color=color))
    if rt:
        return trace
    layout = dict(title=title, margin=dict(l=lm), width=w, height=h)
    data = [trace]
    fig = go.Figure(data=data, layout=layout)
    iplot(fig)

    
trace1 = bar_hor(donors_df, 'Donor City', "Principales ciudades con el mayor número de donantes", '#c2d2ed', 500, 400, 200, limit=10, return_trace=True)
trace2 = bar_hor(donors_df, 'Donor State', "Principales estados con el mayor número de donantes", '#c2d2ed', 500, 400, 200, limit=10, return_trace=True)
trace4 = bar_hor(donors_df, 'Donor State', "Principales estados con el menor número de donantes", '#c2d2ed', 600, 400, 200, limit=10, return_trace=True, rev=True)


fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        'Estados con el mayor número de donantes',
        'Estados con el menor número de donantes'
    ]
)

# fig = tools.make_subplots(rows=2, cols=2, specs=[[{}, {}], [{'colspan': 2}, None]],
#                           print_grid=False,
#                           subplot_titles=['Estados con el mayor número de donantes',
#                                           'Estados con el menor número de donantes',
#                                           'Ciudades con el mayor número de donantes'])

fig.append_trace(trace2, 1, 1)
fig.append_trace(trace4, 1, 2)
# fig.append_trace(trace1, 2, 1)

fig['layout'].update(height=400, showlegend=False)
iplot(fig)

# %% [markdown]
# * **California**, al ser el estado con mayor población, cuenta también con una gran base de donantes registrados, alcanzando casi los 300,000 donantes. **San Francisco y Los Ángeles** son las principales ciudades de California donde se ubica la mayor cantidad de ellos. El estado de California también registra el mayor número de escuelas y proyectos.
# * **Nueva York, Texas y Florida**, con aproximadamente 137,000, 134,000 y 108,000 donantes respectivamente, son los otros tres estados principales con una alta población de donantes. Las principales ciudades incluyen Nueva York, Miami, Tampa, Houston y Dallas, donde se localiza la mayor cantidad de donantes.
# * **Dakota del Norte, Dakota del Sur, Vermont y Wyoming** son los estados con una cantidad muy baja de donantes, menos de 4,000. Existe una entrada llamada "others" (otros) en los datos de los estados, la cual probablemente indica donantes que son profesores o donantes procedentes de otros países.
# * Entre todas las ciudades de EE. UU., las tres principales con el mayor número de donantes son: **Chicago (aprox. 35K donantes), Nueva York (aprox. 27K donantes) y Brooklyn (aprox. 22K donantes)**. Las ciudades californianas de San Francisco y Los Ángeles son las siguientes dos ciudades con una gran base de donantes, con aproximadamente 18K y 16K donantes respectivamente.
#
# ## Conjunto de Datos Ajustado por Población (Population Adjusted Dataset)
#
# Los estados que lideran los gráficos anteriores son, en realidad, aquellos que tienen una población muy alta. Resultará interesante descubrir el número de donantes por cada 100,000 habitantes en cada estado. Para ello, he añadido un conjunto de datos ajustado por población que incluye el número de habitantes de cada estado para el año 2013.
#
# Conjunto de datos de población: http://www.enchantedlearning.com/usa/states/population.shtml
#
# ## <a id="2.3">2.3 Estados con la mayor Proporción de Donantes por Población</a>

# %%
census_2013 = {'Mississippi': 2991207, 'Iowa': 3090416, 'Oklahoma': 3850568, 'Delaware': 925749, 'Minnesota': 5420380, 'Alaska': 735132, 'Illinois': 12882135, 'Arkansas': 2959373, 'New Mexico': 2085287, 'Indiana': 6570902, 'Maryland': 5928814, 'Louisiana': 4625470, 'Texas': 26448193, 'Wyoming': 582658, 'Arizona': 6626624, 'Wisconsin': 5742713, 'Michigan': 9895622, 'Kansas': 2893957, 'Utah': 2900872, 'Virginia': 8260405, 'Oregon': 3930065, 'Connecticut': 3596080, 'New York': 19651127, 'California': 38332521, 'Massachusetts': 6692824, 'West Virginia': 1854304, 'South Carolina': 4774839, 'New Hampshire': 1323459, 'Vermont': 626630, 'Georgia': 9992167, 'North Dakota': 723393, 'Pennsylvania': 12773801, 'Florida': 19552860, 'Hawaii': 1404054, 'Kentucky': 4395295, 'Rhode Island': 1051511, 'Nebraska': 1868516, 'Missouri': 6044171, 'Ohio': 11570808, 'Alabama': 4833722, 'South Dakota': 844877, 'Colorado': 5268367, 'Idaho': 1612136, 'New Jersey': 8899339, 'Washington': 6971406, 'North Carolina': 9848060, 'Tennessee': 6495978, 'Montana': 1015165, 'District of Columbia': 646449, 'Nevada': 2790136, 'Maine': 1328302}

donors_from_states = dict(donors_df['Donor State'].value_counts())

don_pop = {}
for state, don in donors_from_states.items():
    if state not in census_2013:
        continue
    don_pop[state]  = float(don)*100000/ census_2013[state]

import operator
don_pop = sorted(don_pop.items(), key=operator.itemgetter(1), reverse = True)
xx = [x[0] for x in (don_pop)][1:]
yy = [x[1] for x in (don_pop)][1:]

trace2 = go.Bar(
    x=xx,
    y=yy,
    name='Donors to Population',
    marker=dict(color='green'),
    opacity=0.3
)

data = [trace2]
layout = go.Layout(
    barmode='group',
    legend=dict(dict(x=-.1, y=1.2)),
    margin=dict(b=120),
    title = 'Estados con la mayor proporción de donantes por población',
)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')

# %% [markdown]
# Se genera un gráfico muy interesante ya que los estados de **Carolina del Sur** (con una población = 4,774,839), **Massachusetts** (con una población = 6,692,824) y **Connecticut** (con una población = 3,596,080) presentan la mayor proporción de donantes por habitante, así como el mayor número de donantes por cada 100,000 personas.
#
# * **Carolina del Sur** = 985 donantes por cada 100K personas.
# * **Massachusetts** = 907 donantes por cada 100K personas.
# * **Connecticut** = 878 donantes por cada 100K personas.
#
# Por el contrario, **Wyoming, Nebraska y Nuevo México** tienen la menor cantidad de donantes por cada 100K habitantes, con valores equivalentes a 285, 335 y 363 donantes respectivamente.
#
# **Texas**, que era uno de los estados líderes en cantidad absoluta de donantes, presenta una proporción mucho más baja al ajustarse por población, equivalente a solo 508 donantes por cada 100K personas.
#
# ## 2.4 Vamos a visualizar dónde se ubican los donantes
#
# ### 2.4.1 Dónde se ubican los donantes en California

# %%
calcit = StringIO(u"""Name,Latitude,Longitude,Total Donors,Color,Size
Los Angeles,34.052233,-118.243686,"17,922.000000",#0061ff,10
San Francisco,37.774931,-122.419417,"16,553.000000",#0061ff,10
San Diego,32.715328,-117.157256,"9,072.000000",#0061ff,10
San Jose,37.339386,-121.894956,"7,674.000000",#0061ff,10
Oakland,37.804364,-122.271114,"6,783.000000",#0061ff,10
Sacramento,38.581572,-121.494400,"4,701.000000",#0061ff,10
Bakersfield,35.373292,-119.018711,"3,758.000000",#0061ff,10
Long Beach,33.768322,-118.195617,"3,120.000000",#0061ff,10
Berkeley,37.871592,-122.272747,"2,898.000000",#0061ff,10
Irvine,33.683947,-117.794694,"2,765.000000",#0061ff,10
Fremont,37.548269,-121.988572,"2,716.000000",#0061ff,10
Walnut Creek,37.910078,-122.065183,"2,255.000000",#0061ff,10
Huntington Beach,33.660297,-117.999225,"2,185.000000",#0061ff,10
Murrieta,33.553914,-117.213922,"1,982.000000",#0061ff,10
Pleasanton,37.662431,-121.874678,"1,970.000000",#0061ff,10
Torrance,33.83585,-118.340628,"1,957.000000",#0061ff,10
San Mateo,37.562992,-122.325525,"1,956.000000",#0061ff,10
Santa Monica,34.019453,-118.491192,"1,780.000000",#0061ff,10
Livermore,37.681875,-121.768008,"1,776.000000",#0061ff,10
Santa Rosa,38.440467,-122.714431,"1,752.000000",#0061ff,10
Concord,37.977978,-122.031072,"1,623.000000",#0061ff,10
Alameda,37.765206,-122.241636,"1,548.000000",#0061ff,10
Fresno,36.746842,-119.772586,"1,543.000000",#0061ff,10
San Ramon,37.779928,-121.978014,"1,533.000000",#0061ff,10
Anaheim,33.835292,-117.914503,"1,475.000000",#0061ff,10
Pasadena,34.147786,-118.144517,"1,429.000000",#0061ff,10
Glendale,34.142508,-118.255075,"1,427.000000",#0061ff,10
Riverside,33.95335,-117.396156,"1,425.000000",#0061ff,10
Sunnyvale,37.368831,-122.036350,"1,406.000000",#0061ff,10
Chula Vista,32.640053,-117.084197,"1,398.000000",#0061ff,10
Mountain View,37.386053,-122.083850,"1,398.000000",#0061ff,10
Elk Grove,38.4088,-121.371617,"1,397.000000",#0061ff,10
Santa Clarita,34.391664,-118.542586,"1,382.000000",#0061ff,10
Burbank,34.180839,-118.308967,"1,357.000000",#0061ff,10
Redwood City,37.485214,-122.236356,"1,323.000000",#0061ff,10
Chico,39.728494,-121.837478,"1,322.000000",#0061ff,10
Whittier,33.979178,-118.032844,"1,280.000000",#0061ff,10
Corona,33.875294,-117.566439,"1,239.000000",#0061ff,10
Santa Clara,37.354108,-121.955236,"1,233.000000",#0061ff,10
Orange,33.787794,-117.853111,"1,229.000000",#0061ff,10
Palo Alto,37.441883,-122.143019,"1,219.000000",#0061ff,10
Hayward,37.668819,-122.080797,"1,162.000000",#0061ff,10
Oceanside,33.195869,-117.379483,"1,157.000000",#0061ff,10
Fullerton,33.870292,-117.925339,"1,151.000000",#0061ff,10
San Rafael,37.973536,-122.531086,"1,136.000000",#0061ff,10
Folsom,38.677958,-121.176058,"1,125.000000",#0061ff,10
Simi Valley,34.269447,-118.781483,"1,069.000000",#0061ff,10
Escondido,33.119208,-117.086422,"1,062.000000",#0061ff,10
Santa Ana,33.745572,-117.867833,"1,054.000000",#0061ff,10
Redondo Beach,33.849183,-118.388408,"1,048.000000",#34ef6c,8
Stockton,37.957703,-121.290781,"1,041.000000",#34ef6c,8
Santa Cruz,36.974117,-122.030797,"1,029.000000",#34ef6c,8
Culver City,34.021122,-118.396467,"1,019.000000",#34ef6c,8
Salinas,36.677736,-121.655500,"1,017.000000",#34ef6c,8
Martinez,38.019367,-122.134133,975.000000,#34ef6c,8
Santa Barbara,34.420831,-119.698189,936.000000,#34ef6c,8
San Leandro,37.724931,-122.156078,929.000000,#34ef6c,8
Ventura,34.274639,-119.229006,922.000000,#34ef6c,8
Roseville,38.752122,-121.288006,888.000000,#34ef6c,8
Yorba Linda,33.888625,-117.813111,888.000000,#34ef6c,8
Costa Mesa,33.641133,-117.918669,887.000000,#34ef6c,8
San Marcos,33.143372,-117.166144,866.000000,#34ef6c,8
Brentwood,34.057361,-118.480511,853.000000,#34ef6c,8
South San Francisco,37.654656,-122.407750,841.000000,#34ef6c,8
Modesto,37.639097,-120.996878,837.000000,#34ef6c,8
Temecula,33.493639,-117.148364,837.000000,#34ef6c,8
Novato,38.107419,-122.569703,831.000000,#34ef6c,8
Carlsbad,33.158092,-117.350594,822.000000,#34ef6c,8
Mission Viejo,33.600022,-117.671994,817.000000,#34ef6c,8
Brea,33.916681,-117.900061,802.000000,#34ef6c,8
Garden Grove,33.773906,-117.941447,792.000000,#34ef6c,8
Dublin,37.702153,-121.935792,784.000000,#34ef6c,8
El Cajon,32.794772,-116.962528,783.000000,#34ef6c,8
Menlo Park,37.453828,-122.182186,768.000000,#34ef6c,8
Fairfield,38.249358,-122.039967,751.000000,#34ef6c,8
Pleasant Hill,37.947978,-122.060797,725.000000,#34ef6c,8
Napa,38.297539,-122.286864,711.000000,#34ef6c,8
Richmond,37.935758,-122.347750,707.000000,#34ef6c,8
Los Altos,33.796331,-118.118119,703.000000,#34ef6c,8
Daly City,37.687925,-122.470208,702.000000,#34ef6c,8
West Covina,34.068622,-117.938953,688.000000,#34ef6c,8
Lafayette,37.885758,-122.118019,660.000000,#34ef6c,8
La Mesa,32.767828,-117.023083,649.000000,#34ef6c,8
Milpitas,37.428272,-121.906625,649.000000,#34ef6c,8
Carson,33.831406,-118.282017,647.000000,#34ef6c,8
Camarillo,34.216394,-119.037603,643.000000,#34ef6c,8
Petaluma,38.232417,-122.636653,629.000000,#34ef6c,8
Newport Beach,33.618911,-117.928947,626.000000,#34ef6c,8
Pacifica,37.613825,-122.486919,619.000000,#34ef6c,8
Gilroy,37.005783,-121.568275,618.000000,#34ef6c,8
Encinitas,33.036986,-117.291983,607.000000,#34ef6c,8
El Segundo,33.919181,-118.416464,595.000000,#34ef6c,8
Downey,33.940014,-118.132569,592.000000,#34ef6c,8
Rancho Palos Verdes,33.744461,-118.387017,592.000000,#34ef6c,8
San Clemente,33.426972,-117.611992,589.000000,#34ef6c,8
Vacaville,38.356578,-121.987744,584.000000,#34ef6c,8
Chino Hills,33.989819,-117.732586,583.000000,#34ef6c,8
Campbell,37.287164,-121.949958,580.000000,#34ef6c,8
Mill Valley,37.906036,-122.544975,578.000000,#34ef6c,8
El Cerrito,37.916133,-122.310764,576.000000,#f2ae93,6
Emeryville,37.831317,-122.285247,572.000000,#f2ae93,6
Thousand Oaks,34.107231,-118.057847,572.000000,#f2ae93,6
Burlingame,37.584103,-122.366083,570.000000,#f2ae93,6
Antioch,38.004922,-121.805789,568.000000,#f2ae93,6
Beverly Hills,34.073619,-118.400356,568.000000,#f2ae93,6
Lakewood,33.853628,-118.133956,560.000000,#f2ae93,6
Manhattan Beach,33.884736,-118.410908,557.000000,#f2ae93,6
Lancaster,34.686786,-118.154164,551.000000,#f2ae93,6
Oxnard,34.197506,-119.177053,539.000000,#f2ae93,6
San Carlos,37.507158,-122.260522,527.000000,#f2ae93,6
Rocklin,38.790733,-121.235783,526.000000,#f2ae93,6
Placentia,33.872236,-117.870336,520.000000,#f2ae93,6
Cupertino,37.322997,-122.032183,516.000000,#f2ae93,6
Tustin,33.74585,-117.826167,508.000000,#f2ae93,6
Hermosa Beach,33.862236,-118.399519,507.000000,#f2ae93,6
Rancho Cordova,38.589072,-121.302728,501.000000,#f2ae93,6
Fountain Valley,33.709186,-117.953669,498.000000,#f2ae93,6
Cypress,37.320531,-121.962242,497.000000,#f2ae93,6
Union City,37.593392,-122.043831,494.000000,#f2ae93,6
Morgan Hill,37.1305,-121.654389,488.000000,#f2ae93,6
Vallejo,38.104086,-122.256636,485.000000,#f2ae93,6
Alhambra,34.095286,-118.127014,474.000000,#f2ae93,6
Lake Forest,33.646967,-117.689217,465.000000,#f2ae93,6
Rancho Cucamonga,34.1064,-117.593108,463.000000,#f2ae93,6
Vista,33.200036,-117.242536,463.000000,#f2ae93,6
Fontana,34.092233,-117.435047,459.000000,#f2ae93,6
Moreno Valley,33.942467,-117.229672,455.000000,#f2ae93,6
Hawthorne,33.916403,-118.352575,450.000000,#f2ae93,6
Covina,34.090008,-117.890339,443.000000,#f2ae93,6
San Luis Obispo,35.282753,-120.659617,434.000000,#f2ae93,6
Newark,37.529658,-122.040239,433.000000,#f2ae93,6
Inglewood,33.961681,-118.353131,432.000000,#f2ae93,6
Oakley,37.997422,-121.712453,430.000000,#f2ae93,6
Tracy,37.73965,-121.425222,428.000000,#f2ae93,6
Redding,40.586539,-122.391675,424.000000,#f2ae93,6
Glendora,34.136119,-117.865339,423.000000,#f2ae93,6
San Bruno,37.630489,-122.411083,423.000000,#f2ae93,6
Davis,38.544906,-121.740517,417.000000,#f2ae93,6
Westminster,33.751342,-117.993992,413.000000,#f2ae93,6
Pittsburg,38.027975,-121.884681,412.000000,#f2ae93,6
Palmdale,34.579433,-118.116461,408.000000,#f2ae93,6
Visalia,36.330228,-119.292058,406.000000,#f2ae93,6
Poway,32.962822,-117.035864,403.000000,#f2ae93,6
Santa Maria,34.953033,-120.435719,403.000000,#f2ae93,6
Upland,34.097511,-117.648389,396.000000,#f2ae93,6
Laguna Niguel,33.522525,-117.707553,393.000000,#f2ae93,6
La Mirada,33.917236,-118.012008,392.000000,#f2ae93,6
South Pasadena,34.116119,-118.150350,391.000000,#f2ae93,6
Cerritos,33.858347,-118.064786,383.000000,#f2ae93,6
Lodi,38.134147,-121.272219,380.000000,#f2ae93,6
Ontario,34.063344,-117.650889,380.000000,#bab7b6,4
Lincoln,38.891564,-121.293008,376.000000,#bab7b6,4
Buena Park,33.867514,-117.998117,375.000000,#bab7b6,4
Rancho Santa Margarita,33.640856,-117.603103,373.000000,#bab7b6,4
Santee,32.838383,-116.973917,373.000000,#bab7b6,4
Sonoma,38.291858,-122.458036,372.000000,#bab7b6,4
Monrovia,34.144428,-118.001947,371.000000,#bab7b6,4
Albany,37.886869,-122.297747,368.000000,#bab7b6,4
La Habra,33.931958,-117.946172,366.000000,#bab7b6,4
San Pablo,37.962147,-122.345525,366.000000,#bab7b6,4
Belmont,37.520214,-122.275800,364.000000,#bab7b6,4
Pomona,34.055228,-117.752306,364.000000,#bab7b6,4
Gardena,33.88835,-118.308961,363.000000,#bab7b6,4
Arcadia,34.139728,-118.035344,361.000000,#bab7b6,4
Clovis,36.825228,-119.702919,360.000000,#bab7b6,4
Orinda,37.877147,-122.179689,358.000000,#bab7b6,4
Manteca,37.797428,-121.216053,357.000000,#bab7b6,4
Citrus Heights,38.707125,-121.281061,355.000000,#bab7b6,4
Redlands,34.055569,-117.182539,353.000000,#bab7b6,4
Aliso Viejo,33.575,-117.725556,345.000000,#bab7b6,4
Eureka,40.802072,-124.163672,338.000000,#bab7b6,4
West Hollywood,34.090008,-118.361744,337.000000,#bab7b6,4
Auburn,38.896564,-121.076889,335.000000,#bab7b6,4
Saratoga,37.263833,-122.023014,331.000000,#bab7b6,4
Turlock,37.494658,-120.846594,327.000000,#bab7b6,4
Chino,34.012236,-117.688944,325.000000,#bab7b6,4
Diamond Bar,34.028622,-117.810336,324.000000,#bab7b6,4
South Gate,33.954736,-118.212017,319.000000,#bab7b6,4
San Bernardino,34.108344,-117.289764,318.000000,#bab7b6,4
Claremont,34.096675,-117.719778,316.000000,#bab7b6,4
Calabasas,34.138333,-118.660833,298.000000,#bab7b6,4
Los Alamitos,33.803072,-118.072564,297.000000,#bab7b6,4
Agoura Hills,34.153339,-118.761675,295.000000,#bab7b6,4
San Gabriel,34.096111,-118.105833,295.000000,#bab7b6,4
Paso Robles,35.632278,-120.664186,292.000000,#bab7b6,4
Norwalk,33.902236,-118.081733,286.000000,#bab7b6,4
Indio,33.720578,-116.215561,284.000000,#bab7b6,4
Moorpark,34.144897,-118.268742,284.000000,#bab7b6,4
Monterey,36.600239,-121.894675,275.000000,#bab7b6,4
Arroyo Grande,35.118586,-120.590725,274.000000,#bab7b6,4
San Dimas,34.106675,-117.806725,274.000000,#bab7b6,4
La Puente,34.020011,-117.949508,273.000000,#bab7b6,4
West Sacramento,38.580461,-121.530233,273.000000,#bab7b6,4
Rohnert Park,38.339636,-122.701097,269.000000,#bab7b6,4
Monterey Park,34.062511,-118.122847,266.000000,#bab7b6,4
Laguna Hills,33.599722,-117.699444,260.000000,#bab7b6,4
Watsonville,36.910231,-121.756894,259.000000,#bab7b6,4
Clayton,37.941033,-121.935792,256.000000,#bab7b6,4
Hemet,33.747519,-116.971967,256.000000,#bab7b6,4
La Verne,34.100842,-117.767836,255.000000,#bab7b6,4
Ukiah,39.150172,-123.207783,255.000000,#f477d7,2
Palm Desert,33.722244,-116.374456,251.000000,#f477d7,2
Atascadero,35.489417,-120.670725,241.000000,#f477d7,2
Menifee,33.678333,-117.166944,241.000000,#f477d7,2
Lompoc,34.63915,-120.457942,240.000000,#f477d7,2
Merced,37.302164,-120.482967,240.000000,#f477d7,2
Sebastopol,38.402136,-122.823881,237.000000,#f477d7,2
Lake Elsinore,33.668078,-117.327261,236.000000,#f477d7,2
Millbrae,37.598547,-122.387194,234.000000,#f477d7,2
Yuba City,39.140447,-121.616911,231.000000,#f477d7,2
Woodland,38.678517,-121.773297,228.000000,#f477d7,2
Bellflower,33.881683,-118.117011,227.000000,#f477d7,2
Grass Valley,39.219061,-121.061061,227.000000,#f477d7,2
Seal Beach,33.741406,-118.104786,227.000000,#f477d7,2
Walnut,34.020289,-117.865339,227.000000,#f477d7,2
Montebello,34.016506,-118.113753,225.000000,#f477d7,2
Yucaipa,34.033625,-117.043086,225.000000,#f477d7,2
Hanford,36.32745,-119.645683,224.000000,#f477d7,2
Goleta,34.435828,-119.827639,221.000000,#f477d7,2
Hesperia,34.426389,-117.300878,221.000000,#f477d7,2
Laguna Beach,33.542247,-117.783111,221.000000,#f477d7,2
Ridgecrest,35.622456,-117.670897,218.000000,#f477d7,2
Galt,38.254636,-121.299947,217.000000,#f477d7,2
Victorville,34.536108,-117.291158,217.000000,#f477d7,2
San Juan Capistrano,33.501692,-117.662550,209.000000,#f477d7,2
Atwater,37.347717,-120.609083,208.000000,#f477d7,2
Palm Springs,33.830297,-116.545292,208.000000,#f477d7,2
Azusa,34.133619,-117.907564,203.000000,#f477d7,2
Hercules,38.017144,-122.288581,202.000000,#f477d7,2
Sonora,37.984092,-120.382139,199.000000,#f477d7,2
Beaumont,33.929461,-116.977247,198.000000,#f477d7,2
Half Moon Bay,37.463553,-122.428586,197.000000,#f477d7,2
Hollister,36.852453,-121.401603,196.000000,#f477d7,2
Westlake Village,34.145839,-118.805647,194.000000,#f477d7,2
Pico Rivera,33.983069,-118.096736,190.000000,#f477d7,2
Pinole,38.004367,-122.298858,186.000000,#f477d7,2
Compton,33.89585,-118.220072,185.000000,#f477d7,2
Sausalito,37.859094,-122.485250,183.000000,#f477d7,2
La Quinta,33.646692,-116.310008,181.000000,#f477d7,2
Dana Point,33.466972,-117.698108,175.000000,#f477d7,2
Rialto,34.1064,-117.370325,172.000000,#f477d7,2
Perris,33.782519,-117.228647,171.000000,#f477d7,2
Arcata,40.866517,-124.082839,168.000000,#f477d7,2
Pacific Grove,36.617736,-121.916622,168.000000,#f477d7,2
Lomita,33.792239,-118.315072,167.000000,#f477d7,2
San Fernando,34.281947,-118.438972,165.000000,#f477d7,2
South Lake Tahoe,38.939925,-119.977186,163.000000,#f477d7,2
El Monte,34.068622,-118.027567,158.000000,#f477d7,2
Scotts Valley,37.051061,-122.014683,158.000000,#f477d7,2
Tehachapi,35.132189,-118.448975,157.000000,#f477d7,2
Baldwin Park,34.085286,-117.960897,156.000000,#f477d7,2
Marina,36.684403,-121.802172,155.000000,#f477d7,2
Rosemead,34.080564,-118.072847,155.000000,#f477d7,2
Placerville,38.729625,-120.798547,151.000000,#f477d7,2
Highland,34.128344,-117.208650,148.000000,#f477d7,2
Lawndale,33.887236,-118.352575,143.000000,#f477d7,2
Oroville,39.513775,-121.556358,142.000000,#f477d7,2
Seaside,33.819361,-118.366647,142.000000,#f477d7,2
Wildomar,33.598914,-117.280036,142.000000,#f477d7,2
Duarte,34.13945,-117.977286,141.000000,#f477d7,2
Huntington Park,33.981681,-118.225072,141.000000,#f477d7,2
Larkspur,37.934092,-122.535253,139.000000,#f477d7,2
Del Mar,32.959489,-117.265314,138.000000,#f477d7,2
Winters,38.524906,-121.970803,138.000000,#f477d7,2
Red Bluff,40.178489,-122.235831,137.000000,#f477d7,2
Cathedral City,33.779742,-116.465292,136.000000,#f9e84a,1
Ojai,34.44805,-119.242889,136.000000,#f9e84a,1
Coronado,32.685886,-117.183089,134.000000,#f9e84a,1
Lynwood,33.930292,-118.211461,134.000000,#f9e84a,1
Temple City,34.107231,-118.057847,132.000000,#f9e84a,1
Bell,33.977514,-118.187017,124.000000,#f9e84a,1
Sierra Madre,34.161672,-118.052847,119.000000,#f9e84a,1
Nevada City,39.261561,-121.016058,118.000000,#f9e84a,1
National City,32.678108,-117.099197,117.000000,#f9e84a,1
Ceres,37.594933,-120.957711,116.000000,#f9e84a,1
Solana Beach,32.991156,-117.271147,115.000000,#f9e84a,1
La Palma,33.846403,-118.046731,114.000000,#f9e84a,1
Healdsburg,38.610467,-122.869161,110.000000,#f9e84a,1
Ripon,37.739453,-121.135414,109.000000,#f9e84a,1
Crescent City,41.755947,-124.201747,108.000000,#f9e84a,1
Malibu,34.005008,-118.810172,108.000000,#f9e84a,1
Patterson,37.4716,-121.129656,107.000000,#f9e84a,1
Maywood,33.986681,-118.185350,105.000000,#f9e84a,1
Suisun City,38.238247,-122.040244,105.000000,#f9e84a,1
Dixon,38.445464,-121.823297,104.000000,#f9e84a,1
Fort Bragg,39.445722,-123.805292,103.000000,#f9e84a,1
Oakdale,37.766594,-120.847153,103.000000,#f9e84a,1
American Canyon,38.174917,-122.260803,100.000000,#f9e84a,1
Lemon Grove,32.742553,-117.031417,97.000000,#f9e84a,1
Carpinteria,34.398883,-119.518456,96.000000,#f9e84a,1
Lemoore,36.300783,-119.782911,96.000000,#f9e84a,1
San Jacinto,33.783908,-116.958636,95.000000,#f9e84a,1
San Marino,34.121397,-118.106458,95.000000,#f9e84a,1
Paramount,33.889461,-118.159792,94.000000,#f9e84a,1
Tulare,36.207728,-119.347339,93.000000,#f9e84a,1
Twentynine Palms,34.135558,-116.054169,92.000000,#f9e84a,1
Shafter,35.500514,-119.271775,91.000000,#f9e84a,1
Norco,33.931125,-117.548661,89.000000,#f9e84a,1
Capitola,36.975228,-121.953292,88.000000,#f9e84a,1
Rio Vista,38.15575,-121.691344,88.000000,#f9e84a,1
Colton,34.073903,-117.313656,86.000000,#f9e84a,1
Brisbane,37.680767,-122.399972,85.000000,#f9e84a,1
Taft,35.142467,-119.456508,85.000000,#f9e84a,1
Imperial Beach,32.583944,-117.113086,84.000000,#f9e84a,1
Kingsburg,36.513839,-119.554017,84.000000,#f9e84a,1
Morro Bay,35.365808,-120.849900,83.000000,#f9e84a,1
Santa Fe Springs,33.947236,-118.085344,83.000000,#f9e84a,1
Rancho Mirage,33.739744,-116.412789,78.000000,#f9e84a,1
Stanton,33.802517,-117.993117,78.000000,#f9e84a,1
Madera,36.961336,-120.060717,77.000000,#f9e84a,1
Los Banos,37.058278,-120.849914,76.000000,#f9e84a,1
Riverbank,37.736039,-120.935489,76.000000,#f9e84a,1
Gridley,39.363778,-121.693583,75.000000,#f9e84a,1
Pismo Beach,35.142753,-120.641283,74.000000,#f9e84a,1
Santa Paula,34.354167,-119.059269,74.000000,#f9e84a,1
Cotati,38.327778,-122.709167,73.000000,#f9e84a,1
Port Hueneme,34.180728,-119.208158,73.000000,#f9e84a,1
Selma,36.570783,-119.612075,73.000000,#f9e84a,1
Banning,33.925572,-116.876411,71.000000,#f9e84a,1
King City,36.212744,-121.126028,71.000000,#f9e84a,1
El Centro,32.792,-115.563050,69.000000,#f9e84a,1
Lakeport,39.04295,-122.915828,69.000000,#f9e84a,1
Willits,39.409608,-123.355567,68.000000,#f9e84a,1
Barstow,34.895797,-117.017283,67.000000,#f9e84a,1
Marysville,39.145725,-121.591356,67.000000,#f9e84a,1
Orland,39.747381,-122.196375,66.000000,#f9e84a,1
Grand Terrace,34.033903,-117.313653,63.000000,#f9e84a,1
Montclair,34.077511,-117.689778,63.000000,#f9e84a,1
Villa Park,33.814461,-117.813111,63.000000,#f9e84a,1
Artesia,33.865847,-118.083122,62.000000,#f9e84a,1
Desert Hot Springs,33.961125,-116.501678,61.000000,#f9e84a,1
Fortuna,40.598186,-124.157275,61.000000,#f9e84a,1
Grover Beach,35.121642,-120.621283,61.000000,#f9e84a,1
Loma Linda,34.048347,-117.261153,59.000000,#f9e84a,1
Dinuba,36.543283,-119.387067,58.000000,#f9e84a,1
South El Monte,34.051956,-118.046733,58.000000,#f9e84a,1
Porterville,36.065231,-119.016767,57.000000,#f9e84a,1
Lathrop,37.822706,-121.276611,56.000000,#f9e84a,1
Coalinga,36.139678,-120.360150,55.000000,#f9e84a,1
Fillmore,34.399164,-118.918153,54.000000,#f9e84a,1
Mount Shasta,41.410806,-122.194575,52.000000,#f9e84a,1
Anderson,40.448208,-122.297783,51.000000,#f9e84a,1
Cloverdale,38.805461,-123.017222,50.000000,#f9e84a,1
Exeter,36.296061,-119.142053,50.000000,#f9e84a,1
Wasco,35.594125,-119.340947,50.000000,#f9e84a,1
Reedley,36.596339,-119.450403,47.000000,#f9e84a,1
Sanger,36.708006,-119.555964,47.000000,#f9e84a,1
Adelanto,34.582769,-117.409214,45.000000,#f9e84a,1
Brawley,32.978658,-115.530267,43.000000,#f9e84a,1
Calimesa,34.003903,-117.061975,42.000000,#f9e84a,1
Hughson,37.602725,-120.866481,42.000000,#f9e84a,1
Imperial,32.847553,-115.569439,41.000000,#f9e84a,1
Soledad,32.991156,-117.271147,41.000000,#f9e84a,1
Weed,41.42265,-122.386128,40.000000,#f9e84a,1
Calexico,32.678947,-115.498883,37.000000,#f9e84a,1
Willows,39.524325,-122.193592,36.000000,#f9e84a,1
Big Bear Lake,34.243897,-116.911422,35.000000,#f9e84a,1
Delano,35.768842,-119.247053,34.000000,#f9e84a,1
Newman,37.313828,-121.020761,34.000000,#f9e84a,1
Colfax,39.100731,-120.953275,33.000000,#f9e84a,1
Escalon,37.797428,-120.996603,33.000000,#f9e84a,1
Jackson,38.348803,-120.774103,32.000000,#f9e84a,1
Bishop,37.363539,-118.395111,31.000000,#f9e84a,1
Coachella,33.6803,-116.173894,31.000000,#f9e84a,1
Holtville,32.811161,-115.380264,31.000000,#f9e84a,1
Indian Wells,33.717631,-116.340756,31.000000,#f9e84a,1
San Juan Bautista,36.845511,-121.537997,31.000000,#f9e84a,1
Arvin,35.2018,-118.833106,30.000000,#f9e84a,1
Kerman,36.723558,-120.059878,30.000000,#f9e84a,1
Colusa,39.214333,-122.009417,27.000000,#f9e84a,1
Greenfield,36.3208,-121.243814,27.000000,#f9e84a,1
Waterford,37.641319,-120.760483,26.000000,#f9e84a,1
Ferndale,40.576242,-124.263944,25.000000,#f9e84a,1
Susanville,40.416283,-120.653006,25.000000,#f9e84a,1
Buellton,34.613597,-120.192650,24.000000,#f9e84a,1
Calistoga,38.578797,-122.579706,24.000000,#f9e84a,1
Clearlake,38.958231,-122.626372,24.000000,#f9e84a,1
Shasta Lake,40.680428,-122.370842,24.000000,#f9e84a,1
Yreka,41.735419,-122.634472,23.000000,#f9e84a,1
Biggs,39.412389,-121.712750,22.000000,#f9e84a,1
Chowchilla,37.123,-120.260175,22.000000,#f9e84a,1
Live Oak,36.983561,-121.980517,22.000000,#f9e84a,1
McFarland,35.678011,-119.229275,22.000000,#f9e84a,1
Fowler,36.630506,-119.678469,21.000000,#f9e84a,1
Gonzales,36.506628,-121.444381,21.000000,#f9e84a,1
Solvang,34.595819,-120.137647,21.000000,#f9e84a,1
Angels Camp,38.067783,-120.538531,20.000000,#f9e84a,1
Gustine,37.257717,-120.998814,20.000000,#f9e84a,1
Sutter Creek,38.392967,-120.802436,20.000000,#f9e84a,1
Wheatland,39.009894,-121.423014,20.000000,#f9e84a,1
Hawaiian Gardens,33.831403,-118.072842,19.000000,#f9e84a,1
Lindsay,36.203006,-119.088161,19.000000,#f9e84a,1
Livingston,37.386883,-120.723533,19.000000,#f9e84a,1
California City,35.1258,-117.985903,18.000000,#f9e84a,1
Corning,39.927658,-122.179156,18.000000,#f9e84a,1
Trinidad,41.059292,-124.143125,18.000000,#f9e84a,1
Ione,38.352692,-120.932717,17.000000,#f9e84a,1
Dunsmuir,41.208208,-122.271953,16.000000,#f9e84a,1
Tulelake,41.955989,-121.477492,15.000000,#f9e84a,1
Firebaugh,36.858839,-120.456008,13.000000,#f9e84a,1
Woodlake,36.413561,-119.098717,13.000000,#f9e84a,1
Blue Lake,40.882908,-123.983950,12.000000,#f9e84a,1
Blythe,33.617233,-114.589175,12.000000,#f9e84a,1
Avalon,33.342819,-118.328228,11.000000,#f9e84a,1
Montague,41.728197,-122.527800,11.000000,#f9e84a,1
Williams,39.154614,-122.149419,11.000000,#f9e84a,1
Alturas,41.487114,-120.542456,10.000000,#f9e84a,1
Corcoran,37.977978,-122.031072,9.000000,#f9e84a,1
Isleton,38.161861,-121.611622,9.000000,#f9e84a,1
Piedmont,37.824372,-122.231636,9.000000,#f9e84a,1
Rio Dell,40.4993,-124.106436,9.000000,#f9e84a,1
Huron,36.202731,-120.102917,8.000000,#f9e84a,1
Point Arena,38.908797,-123.693072,8.000000,#f9e84a,1
Dorris,41.967369,-121.918061,7.000000,#f9e84a,1
Dos Palos,36.986058,-120.626572,7.000000,#f9e84a,1
Etna,41.456806,-122.894756,6.000000,#f9e84a,1
Guadalupe,34.971644,-120.571836,6.000000,#f9e84a,1
Needles,34.848061,-114.614133,6.000000,#f9e84a,1
Plymouth,38.481853,-120.844658,5.000000,#f9e84a,1
Avenal,36.004122,-120.129028,4.000000,#f9e84a,1
Fort Jones,41.663864,-124.252892,4.000000,#f9e84a,1
Portola,39.810458,-120.469103,4.000000,#f9e84a,1
Calipatria,33.125597,-115.514153,3.000000,#f9e84a,1
Farmersville,36.297728,-119.206778,3.000000,#f9e84a,1
Loyalton,39.676294,-120.241039,3.000000,#f9e84a,1
Maricopa,35.058858,-119.400950,2.000000,#f9e84a,1
Parlier,36.611617,-119.527072,2.000000,#f9e84a,1
Bell Gardens,33.965292,-118.151458,1.000000,#f9e84a,1
Orange Cove,36.624394,-119.313731,1.000000,#f9e84a,1
San Joaquin,36.606617,-120.189044,1.000000,#f9e84a,1
Westmorland,33.037267,-115.621383,1.000000,#f9e84a,1""")



cities = pd.read_csv(calcit)
cities = cities.dropna()

# map_osm = folium.Map(location=[36.611617,-119.527072], zoom_start=5)

# for i, row in cities.iterrows():
#     folium.CircleMarker([row['Latitude'], row['Longitude']],
#                         radius=row['Size'],
#                         color=row['Color'],
#                         fill_color=row['Color'],
#                        ).add_to(map_osm)



map_osm2 = folium.Map([36.611617,-119.527072], zoom_start=6,tiles='cartodbdark_matter')
ziparr = []
for i, row in cities.iterrows():
    ziparr.append([row['Latitude'],row['Longitude'], float(row['Total Donors'].replace(",",""))])
map_osm2.add_child(plugins.HeatMap(ziparr, radius=12))
map_osm2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6579fa53d338e3d2588dd345313bb6c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6579fa53d338e3d2588dd345313bb6c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6579fa53d338e3d2588dd345313bb6c5 = L.map(
#                 &quot;map_6579fa53d338e3d2588dd345313bb6c5&quot;,
#                 {
#                     center: [36.611617, -119.527072],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67fd4ee940dd14beeb2dee5056f2d1ac = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67fd4ee940dd14beeb2dee5056f2d1ac.addTo(map_6579fa53d338e3d2588dd345313bb6c5);
#
#
#             var heat_map_84f868fe82a0da66edfcc807b3969d2e = L.heatLayer(
#                 [[34.052233, -118.243686, 17922.0], [37.774931, -122.419417, 16553.0], [32.715328, -117.157256, 9072.0], [37.339386, -121.894956, 7674.0], [37.804364, -122.271114, 6783.0], [38.581572, -121.4944, 4701.0], [35.373292, -119.018711, 3758.0], [33.768322, -118.195617, 3120.0], [37.871592, -122.272747, 2898.0], [33.683947, -117.794694, 2765.0], [37.548269, -121.988572, 2716.0], [37.910078, -122.065183, 2255.0], [33.660297, -117.999225, 2185.0], [33.553914, -117.213922, 1982.0], [37.662431, -121.874678, 1970.0], [33.83585, -118.340628, 1957.0], [37.562992, -122.325525, 1956.0], [34.019453, -118.491192, 1780.0], [37.681875, -121.768008, 1776.0], [38.440467, -122.714431, 1752.0], [37.977978, -122.031072, 1623.0], [37.765206, -122.241636, 1548.0], [36.746842, -119.772586, 1543.0], [37.779928, -121.978014, 1533.0], [33.835292, -117.914503, 1475.0], [34.147786, -118.144517, 1429.0], [34.142508, -118.255075, 1427.0], [33.95335, -117.396156, 1425.0], [37.368831, -122.03635, 1406.0], [32.640053, -117.084197, 1398.0], [37.386053, -122.08385, 1398.0], [38.4088, -121.371617, 1397.0], [34.391664, -118.542586, 1382.0], [34.180839, -118.308967, 1357.0], [37.485214, -122.236356, 1323.0], [39.728494, -121.837478, 1322.0], [33.979178, -118.032844, 1280.0], [33.875294, -117.566439, 1239.0], [37.354108, -121.955236, 1233.0], [33.787794, -117.853111, 1229.0], [37.441883, -122.143019, 1219.0], [37.668819, -122.080797, 1162.0], [33.195869, -117.379483, 1157.0], [33.870292, -117.925339, 1151.0], [37.973536, -122.531086, 1136.0], [38.677958, -121.176058, 1125.0], [34.269447, -118.781483, 1069.0], [33.119208, -117.086422, 1062.0], [33.745572, -117.867833, 1054.0], [33.849183, -118.388408, 1048.0], [37.957703, -121.290781, 1041.0], [36.974117, -122.030797, 1029.0], [34.021122, -118.396467, 1019.0], [36.677736, -121.6555, 1017.0], [38.019367, -122.134133, 975.0], [34.420831, -119.698189, 936.0], [37.724931, -122.156078, 929.0], [34.274639, -119.229006, 922.0], [38.752122, -121.288006, 888.0], [33.888625, -117.813111, 888.0], [33.641133, -117.918669, 887.0], [33.143372, -117.166144, 866.0], [34.057361, -118.480511, 853.0], [37.654656, -122.40775, 841.0], [37.639097, -120.996878, 837.0], [33.493639, -117.148364, 837.0], [38.107419, -122.569703, 831.0], [33.158092, -117.350594, 822.0], [33.600022, -117.671994, 817.0], [33.916681, -117.900061, 802.0], [33.773906, -117.941447, 792.0], [37.702153, -121.935792, 784.0], [32.794772, -116.962528, 783.0], [37.453828, -122.182186, 768.0], [38.249358, -122.039967, 751.0], [37.947978, -122.060797, 725.0], [38.297539, -122.286864, 711.0], [37.935758, -122.34775, 707.0], [33.796331, -118.118119, 703.0], [37.687925, -122.470208, 702.0], [34.068622, -117.938953, 688.0], [37.885758, -122.118019, 660.0], [32.767828, -117.023083, 649.0], [37.428272, -121.906625, 649.0], [33.831406, -118.282017, 647.0], [34.216394, -119.037603, 643.0], [38.232417, -122.636653, 629.0], [33.618911, -117.928947, 626.0], [37.613825, -122.486919, 619.0], [37.005783, -121.568275, 618.0], [33.036986, -117.291983, 607.0], [33.919181, -118.416464, 595.0], [33.940014, -118.132569, 592.0], [33.744461, -118.387017, 592.0], [33.426972, -117.611992, 589.0], [38.356578, -121.987744, 584.0], [33.989819, -117.732586, 583.0], [37.287164, -121.949958, 580.0], [37.906036, -122.544975, 578.0], [37.916133, -122.310764, 576.0], [37.831317, -122.285247, 572.0], [34.107231, -118.057847, 572.0], [37.584103, -122.366083, 570.0], [38.004922, -121.805789, 568.0], [34.073619, -118.400356, 568.0], [33.853628, -118.13

# %% [markdown]
# > Las ubicaciones clave donde la densidad de donantes es mayor son las siguientes:
# >
# > * **Los Ángeles**: 17,922
# > * **San Francisco**: 16,553
# > * **San Diego**: 9,072
# > * **San Jose**: 7,674
# > * **Oakland**: 6,783
#
# ## <a id="2.4.2">2.4.2 Dónde se ubican los donantes en Florida</a>

# %%
c = pd.read_csv('Datasets/zip_codes_states.csv')
c = c.dropna()

fldf = c[c['state'] == 'FL'][['city', 'latitude', 'longitude']]

fldf = fldf.groupby('city').agg({'latitude': 'max', 'longitude': 'max'}).reset_index()
t = donors_df[donors_df['Donor State'] == 'Florida']['Donor City'].value_counts()
fldons = pd.DataFrame()
fldons['city'] = t.index
fldons['count'] = t.values
florida = fldons.merge(fldf, on='city', how='left').dropna()


map_osm2 = folium.Map([29.813456, -82.472049], zoom_start=6.2,tiles='cartodbdark_matter')
ziparr = []
for i, row in florida.iterrows():
    ziparr.append([row['latitude'],row['longitude'], row['count']])
map_osm2.add_child(plugins.HeatMap(ziparr, radius=12))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f91ad78bf76db12dd10ff910bb9cba6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f91ad78bf76db12dd10ff910bb9cba6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f91ad78bf76db12dd10ff910bb9cba6 = L.map(
#                 &quot;map_5f91ad78bf76db12dd10ff910bb9cba6&quot;,
#                 {
#                     center: [29.813456, -82.472049],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6.2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3cf834714643f33cfd8532eff9ccd75 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3cf834714643f33cfd8532eff9ccd75.addTo(map_5f91ad78bf76db12dd10ff910bb9cba6);
#
#
#             var heat_map_af83f7d6f63390fecb8683fe78af51bc = L.heatLayer(
#                 [[28.127834, -82.350338, 19], [28.59965, -80.686159, 19], [25.959719, -80.140267, 17], [30.479666, -81.389305, 5], [30.572171, -84.135913, 3]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 12,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_af83f7d6f63390fecb8683fe78af51bc.addTo(map_5f91ad78bf76db12dd10ff910bb9cba6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# > La región de los tres condados de Florida: Palm Beach, Miami-Dade y Broward concentra la mayor densidad de donantes. La ciudad principal de Tampa también cuenta con un número significativo de ellos. Algunos donantes también se localizan en una de las zonas más caras y en el extremo más meridional de los Estados Unidos, conocida como el área de Key West (Cayo Hueso) en Florida. A continuación se presentan los conteos respectivos de donantes para las 6 ciudades principales:
# >
# > * **Miami**: 9,309
# > * **Tampa**: 6,016
# > * **Orlando**: 5,658
# > * **Jacksonville**: 4,598
# > * **Fort Lauderdale**: 4,311
# > * **West Palm Beach**: 2,400
#
# ## <a id="2.4.3">2.4.3 Dónde se ubican los donantes en Nueva York</a>

# %%
fldf = c[c['state'] == 'NY'][['city', 'latitude', 'longitude']]
fldf = fldf.groupby('city').agg({'latitude': 'max', 'longitude': 'max'}).reset_index()
fldf
t = donors_df[donors_df['Donor State'] == 'New York']['Donor City'].value_counts()

fldons = pd.DataFrame()
fldons['city'] = t.index
fldons['count'] = t.values
florida = fldons.merge(fldf, on='city', how='left').dropna()


map_osm2 = folium.Map([42.315975, -74.065515], zoom_start=6.2,tiles='cartodbdark_matter')
ziparr = []
for i, row in florida.iterrows():
    ziparr.append([row['latitude'],row['longitude'], row['count']])
map_osm2.add_child(plugins.HeatMap(ziparr, radius=12))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54f0693cd3279ae97c899ecc5c643641 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54f0693cd3279ae97c899ecc5c643641&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54f0693cd3279ae97c899ecc5c643641 = L.map(
#                 &quot;map_54f0693cd3279ae97c899ecc5c643641&quot;,
#                 {
#                     center: [42.315975, -74.065515],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6.2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2300b4a7f02c385170aa133540cbe8f8 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2300b4a7f02c385170aa133540cbe8f8.addTo(map_54f0693cd3279ae97c899ecc5c643641);
#
#
#             var heat_map_72d6831c699fae604eb4b47728743abf = L.heatLayer(
#                 [[40.863194, -73.926959, 43], [43.026016, -78.744053, 32], [40.728388, -73.876754, 30], [43.286024, -77.505705, 6], [40.899178, -73.799802, 4]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 12,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_72d6831c699fae604eb4b47728743abf.addTo(map_54f0693cd3279ae97c899ecc5c643641);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# > Los donantes de Nueva York provienen principalmente de la Ciudad de Nueva York. Las 5 ciudades principales son:
# >
# > * **New York**: 26,820
# > * **Brooklyn**: 21715
# > * **Staten Island**: 4,516
# > * **Bronx**: 4,455
# > * **Buffalo**: 2,232
#
# ## <a id="2.4.4">2.4.4 Dónde se ubican los donantes en Texas</a>

# %%
fldf = c[c['state'] == 'TX'][['city', 'latitude', 'longitude']]
fldf = fldf.groupby('city').agg({'latitude': 'max', 'longitude': 'max'}).reset_index()
fldf
t = donors_df[donors_df['Donor State'] == 'Texas']['Donor City'].value_counts()

fldons = pd.DataFrame()
fldons['city'] = t.index
fldons['count'] = t.values
florida = fldons.merge(fldf, on='city', how='left').dropna()


map_osm2 = folium.Map([31.884540, -97.077218], zoom_start=6.2,tiles='cartodbdark_matter')
ziparr = []
for i, row in florida.iterrows():
    ziparr.append([row['latitude'],row['longitude'], row['count']])
map_osm2.add_child(plugins.HeatMap(ziparr, radius=12))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_133999a28660d2c34975a0793e3ece10 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_133999a28660d2c34975a0793e3ece10&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_133999a28660d2c34975a0793e3ece10 = L.map(
#                 &quot;map_133999a28660d2c34975a0793e3ece10&quot;,
#                 {
#                     center: [31.88454, -97.077218],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6.2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ade88c03d19d14714549e6b7da384e5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ade88c03d19d14714549e6b7da384e5.addTo(map_133999a28660d2c34975a0793e3ece10);
#
#
#             var heat_map_aff1e0a6e34fa7a076289244f539fa09 = L.heatLayer(
#                 [[30.493156, -97.443751, 29], [32.986259, -96.535191, 27], [29.740162, -98.22843, 18], [29.83399, -95.099828, 14], [31.963221, -106.176474, 9], [32.93455, -97.051969, 6]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 12,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_aff1e0a6e34fa7a076289244f539fa09.addTo(map_133999a28660d2c34975a0793e3ece10);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# > Las principales ciudades de Texas donde se ubican los donantes son:
# >
# > * **Houston**: 15,404
# > * **Austin**: 9,958
# > * **Dallas**: 7,818
# > * **San Antonio**: 6,465
# > * **Fort Worth**: 4,350
#
# ## <a id="2.5">2.5 ¿Dónde se ubican los donantes?</a>

# %%
fldf = c[['city', 'latitude', 'longitude']]
fldf = fldf.groupby('city').agg({'latitude': 'max', 'longitude': 'max'}).reset_index()
fldf
t = donors_df['Donor City'].value_counts()
fldons = pd.DataFrame()
fldons['city'] = t.index
fldons['count'] = t.values
florida = fldons.merge(fldf, on='city', how='left').dropna()


map_osm2 = folium.Map([39.3714557,-94.3541242], zoom_start=3.5,tiles='cartodbdark_matter')
ziparr = []
for i, row in florida.iterrows():
    ziparr.append([row['latitude'],row['longitude'], row['count']])
map_osm2.add_child(plugins.HeatMap(ziparr, radius=10))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f154b1c893b59004ffda9ef012cf2ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f154b1c893b59004ffda9ef012cf2ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f154b1c893b59004ffda9ef012cf2ea = L.map(
#                 &quot;map_5f154b1c893b59004ffda9ef012cf2ea&quot;,
#                 {
#                     center: [39.3714557, -94.3541242],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a740942a16ea3531c8febf4d635563f4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a740942a16ea3531c8febf4d635563f4.addTo(map_5f154b1c893b59004ffda9ef012cf2ea);
#
#
#             var heat_map_c49b7331c83b5f0f24e19cd8c10ac990 = L.heatLayer(
#                 [[40.636539, -76.591109, 51], [34.014613, -118.153153, 50], [37.819763, -122.368433, 44], [40.863194, -73.926959, 43], [33.021243, -98.517875, 36], [47.248497, -78.744053, 32], [42.717122, -71.983412, 30], [42.625391, -70.919635, 29], [43.699305, -77.957975, 29], [45.261871, -75.880146, 27], [40.519017, -79.949182, 26], [45.602457, -69.438697, 26], [45.519867, -68.647416, 26], [42.096428, -87.68732, 26], [46.267125, -78.413371, 24], [44.31658, -73.226034, 22], [39.77796, -76.553237, 20], [38.945847, -80.51449, 19], [38.54879, -82.350338, 19], [33.963287, -67.139597, 18], [40.749801, -74.037168, 18], [46.893112, -76.225752, 17], [40.61466, -80.140267, 17], [47.776875, -121.803388, 16], [45.460536, -69.827489, 16], [43.087067, -74.147337, 16], [47.780541, -93.292806, 14], [62.280436, -75.520078, 14], [42.323077, -83.711228, 14], [43.099386, -76.762705, 14], [47.582141, -70.198742, 13], [45.174056, -81.934265, 13], [36.924496, -76.002552, 12], [39.9416, -85.974081, 12], [45.066999, -69.040695, 12], [45.030626, -77.468518, 12], [43.163122, -77.386748, 11], [41.839679, -88.088716, 11], [39.343225, -94.356728, 10], [44.116323, -75.006771, 10], [40.301103, -89.687211, 9], [43.672103, -72.355539, 9], [44.557111, -69.826495, 9], [40.684846, -89.106751, 9], [46.141948, -105.27484, 9], [42.686195, -74.56969, 9], [32.465013, -110.708174, 8], [42.621104, -77.982782, 8], [40.979898, -81.390056, 8], [44.761527, -69.322662, 8], [48.852362, -74.702475, 7], [43.33021, -76.260803, 7], [35.624134, -97.202331, 7], [44.149509, -72.779901, 7], [32.93455, -97.051969, 6], [47.672177, -83.906157, 6], [40.798495, -111.66273, 6], [46.832816, -70.846041, 6], [36.343521, -104.985643, 6], [37.787925, -97.171098, 6], [41.672687, -93.529588, 5], [42.058629, -86.864745, 5], [43.389621, -79.348165, 5], [44.824855, -72.895849, 5], [45.368653, -71.257726, 5], [42.795363, -72.817838, 5], [30.087708, -89.815993, 4], [41.35585, -84.849724, 4], [47.634557, -68.391481, 4], [35.199592, -106.243911, 4], [44.162384, -69.387795, 4], [30.590238, -90.972423, 4], [40.899178, -73.799802, 4], [47.595155, -69.867001, 3], [43.680432, -115.997118, 3], [30.572171, -84.135913, 3], [24.859832, -157.901979, 3], [43.098983, -76.413216, 3], [42.604425, -74.711429, 2], [43.674582, -96.633203, 2], [45.978288, -73.743714, 2], [46.9414, -82.772422, 2], [43.968378, -70.184618, 2], [61.287624, -149.440311, 2], [48.533616, -68.817481, 2], [41.871766, -71.394717, 2], [44.145678, -71.173888, 2], [44.600325, -72.286556, 2], [41.377698, -99.672542, 1]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 10,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_c49b7331c83b5f0f24e19cd8c10ac990.addTo(map_5f154b1c893b59004ffda9ef012cf2ea);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# > Aunque la mayor cantidad de donantes proviene del estado de California (ubicado en la costa oeste), la región de la costa este de los Estados Unidos presenta una mayor densidad de donantes en comparación con el oeste. Una cantidad significativa de donantes también se encuentra localizada en Hawái y Alaska.
#
# ## <a id="2.6">2.6 Número de Donantes Profesores y No Profesores por Estado</a>

# %%
# which city and state has maximum teacher donors 
tempdf = donors_df.groupby(['Donor State', 'Donor Is Teacher']).agg({'Donor Is Teacher' : 'count' }).rename(columns={'Donor Is Teacher' : 'Teacher Donor Counts'}).reset_index()

no_df = tempdf[tempdf['Donor Is Teacher']=='No']
no_x = no_df['Donor State']
no_y = no_df['Teacher Donor Counts']
yes_df = tempdf[tempdf['Donor Is Teacher']=='Yes']
yes_x = yes_df['Donor State']
yes_y = yes_df['Teacher Donor Counts']

trace1 = go.Bar(
    x=no_x,
    y=no_y,
    name='Non Teacher Donors',
    marker=dict(color='#f259d6'),
    opacity=0.8
)
trace2 = go.Bar(
    x=yes_x,
    y=yes_y,
    name='Teacher Donors',
    marker=dict(color='#f7bb31'),
    opacity=0.8
)

data = [trace1, trace2]
layout = go.Layout(
    barmode='group',
    legend=dict(dict(x=-.1, y=1.2)),
    margin=dict(b=120),
    title = 'Estados y distribución de donantes docentes y no docentes',
)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar')

# %% [markdown]
# > El número de donantes que son profesores es siempre muy bajo en todos los estados. Los registros que tienen el estado marcado como "others" (otros) presentan la mayor cantidad de donantes profesores, con aproximadamente 28,000.
#
# ## <a id="3">3. Exploración de las Donaciones</a>
#
# El archivo de donaciones incluye información sobre las donaciones realizadas por los donantes, el monto total de la donación, la secuencia del carrito del donante, la fecha, el ID del proyecto y el ID del donante.
#
# ## <a id="3.1">3.1 Panorama de las Donaciones</a>

# %%
donations_df[['Donation ID', 'Donation Included Optional Donation', 'Donation Amount',
       'Donor Cart Sequence', 'Donation Received Date', 'Project ID', 'Donor ID']].head(3)
# donations_df.columns

# len(donations_df)
# len(donations_df[donations_df['Donation Amount'] > 20000]) / len(donations_df)
# len(donations_df[donations_df['Donation Amount'] > 10000]) / len(donations_df)
# len(donations_df[donations_df['Donation Amount'] < 1])
# np.mean(donations_df['Donation Amount'])
# Out:
#                         Donation ID Donation Included Optional Donation  \
# 0  0f1259e0a18ff6b6b535106e122c9a56                                  No
# 1  21df306f8a0b3c3336d8393a7c441fe7                                 Yes
# 2  5ab33edf6e595ed3a8b317fa18d0752b                                 Yes
#
#    Donation Amount  Donor Cart Sequence Donation Received Date  \
# 0          2219.27                    2    2016-06-10 07:17:42
# 1            44.02                    8    2017-04-06 13:12:06
# 2           112.07                   11    2016-10-31 20:06:03
#
#                          Project ID                          Donor ID
# 0  a013ac6ededa4e161b3dbd5ce9a1fa6f  17fc695a07a0ca6e0822e8f36c031199
# 1  b09b2a5cbadcc32ac1590f538a0f4efb  366eb16f508ebad7b7c93acfe059a0ee
# 2  5cec4eb5edd968311ca35cfb04fc6d82  aefcfad8efc89849b3aa7efe4458a885

# %% [markdown]
# Se han realizado un total de **4,687,884 donaciones** hasta abril de 2018 en DonorsChoose. El monto de donación más alto equivale a **USD 60,000**, donado en el año 2013. Solo **6 donaciones son mayores a un monto de USD 20,000**, mientras que solo **61 pagos superan los USD 10,000**. La gran mayoría de los pagos (alrededor del **83%** de todas las donaciones) son **menores a USD 100**. Existen 350 pagos que son menores a USD 1 (cantidades pequeñas, pero que aun así pueden hacer la diferencia). Hasta abril de 2018, DonorsChoose ha recaudado una colosal cantidad total equivalente a **USD 284,408,243** a través de su plataforma. El monto promedio de donación en DonorsChoose equivale a **USD 60**. Echemos un vistazo a los detalles de los donantes y los proyectos relacionados con estas donaciones en las siguientes secciones.
#
# ## <a id="3.2">3.2 Los Proyectos y sus Donaciones</a>
#
# Vamos a identificar los proyectos principales y los valores de sus atributos relacionados:
#
# * **3.2.1** Proyectos con el Mayor número de donantes
# * **3.2.2** Proyectos con los Mayores Montos Totales Financiados
# * **3.2.3** Proyectos con los Mayores Montos Promedios Por Donante
# * **3.2.4** Proyectos con el Monto Máximo de Donación Única

# %%
# ¿Qué proyectos recibieron la mayor cantidad de donaciones?

tempdf = donations_df.groupby('Project ID').agg({
    'Project ID': 'count',
    'Donation Amount': 'sum'
}).rename(columns={
    'Project ID': "Total Donations",
    'Donation Amount': "Total Amount"
}).reset_index()

tempdf['Average Donation Amount'] = tempdf['Total Amount'] / tempdf['Total Donations']

# Total de donaciones
tempdf1 = tempdf.sort_values(by=['Total Donations'], ascending=[False])
x = tempdf1.head(5)['Project ID']
x = ["Pa" + str(i + 1) for i in range(len(x))]
y = tempdf1.head(5)['Total Donations']
tr1 = bar_ver_noagg(x, y, 'Total de Donaciones', '#43ef4b', lm=None, rt=True)

# Monto total donado
tempdf1 = tempdf.sort_values(by=['Total Amount'], ascending=[False])
x = tempdf1.head(5)['Project ID']
x = ["Pb" + str(i + 1) for i in range(len(x))]
y = tempdf1.head(5)['Total Amount']
tr2 = bar_ver_noagg(x, y, 'Monto Total Donado', '#7fef84', lm=None, rt=True)

# Monto promedio por donación (mínimo 10 donaciones)
tempdf1 = tempdf.sort_values(by=['Average Donation Amount'], ascending=[False])
x = tempdf1[tempdf1['Total Donations'] > 10].head(5)['Project ID']
x = ["Pc" + str(i + 1) for i in range(len(x))]
y = tempdf1[tempdf1['Total Donations'] > 10].head(5)['Average Donation Amount']
tr3 = bar_ver_noagg(
    x,
    y,
    'Monto Promedio por Donación (Mínimo: 10 Donaciones)',
    '#a5d1a7',
    lm=None,
    rt=True
)

# Donación individual máxima
tempdf = donations_df.groupby('Project ID').agg({
    'Project ID': 'count',
    'Donation Amount': 'max'
}).rename(columns={
    'Project ID': "Total Donations",
    'Donation Amount': "Maximum Donations"
}).reset_index()

tempdf1 = tempdf.sort_values(by=['Maximum Donations'], ascending=[False])
x = tempdf1.head(5)['Project ID']
x = ["Pd" + str(i + 1) for i in range(len(x))]
y = tempdf1.head(5)['Maximum Donations']
tr4 = bar_ver_noagg(x, y, 'Donación Individual Máxima', '#c0d1c1', lm=None, rt=True)

# Subgráficos
fig = tools.make_subplots(
    rows=2,
    cols=2,
    print_grid=False,
    subplot_titles=[
        'Número de Donaciones',
        'Monto Total Donado',
        'Monto Promedio por Donación (Mínimo: 10 Donaciones)',
        'Monto Máximo de una Donación Individual'
    ]
)

fig.append_trace(tr1, 1, 1)
fig.append_trace(tr2, 1, 2)
fig.append_trace(tr3, 2, 1)
fig.append_trace(tr4, 2, 2)

fig['layout'].update(
    height=600,
    showlegend=False,
    title='Principales proyectos según: Total de Donaciones, Monto Total Donado, Promedio por Donación y Donación Individual Máxima'
)

iplot(fig)

# %% [markdown]
# > * **Proyectos Principales** > * En la historia de DonorsChoose, diferentes proyectos han recibido un número muy variable de donaciones, que van desde tan solo 1 hasta un máximo de 800 donaciones. El número máximo de donaciones realizadas a un solo proyecto es igual a 863. Este fue un proyecto liderado por un profesor y su título fue "**Vallecito StandUpKids Pilot Standing School!**" (mostrado como Pa1 en el primer gráfico). Se financió un monto total equivalente a **USD 108,248.30** para este proyecto y se completó su financiamiento el 26 de agosto de 2015.
# > * Existen otros tres proyectos que cuentan con un número muy grande de donaciones (mayor a 600).
# > * En noviembre de 2016, se inició un proyecto titulado "**Varsity and After-School Fencing Teams in NYC**" (mostrado como Pc1 en el segundo gráfico) y registró un total de 18 donaciones. Este proyecto tuvo el promedio más alto por donante, equivalente a **USD 1,850**.
# > * En el proyecto titulado "**Learning to Play While Playing to Learn!**" (mostrado como Pd1 en el cuarto gráfico), se aportó un monto de donación única de **USD 60,000**, el cual representa la donación individual más alta en toda la historia de DonorsChoose.
#
# ## <a id="3.3">3.3 ¿Quiénes son los Donantes Principales?</a>
#
# Vamos a identificar a los donantes que realizaron las contribuciones más destacadas y sus valores. Es decir:
#
# * **3.3.1** Donantes que han realizado el mayor número de donaciones
# * **3.3.2** Donantes que han financiado los Mayores Montos Totales
# * **3.3.3** Donantes que financian los Mayores Montos Promedios en donaciones únicas
# * **3.3.4** Donantes que han financiado el Monto Máximo de Donación Única

# %%
# ¿Qué donantes realizaron las mayores contribuciones?

tempdf = donations_df.groupby('Donor ID').agg({
    'Donor ID': 'count',
    'Donation Amount': 'sum'
}).rename(columns={
    'Donor ID': "Total Donations",
    'Donation Amount': "Total Amount"
}).reset_index()

tempdf['Average Donation Amount'] = tempdf['Total Amount'] / tempdf['Total Donations']

# Total de donaciones
tempdf1 = tempdf.sort_values(by=['Total Donations'], ascending=[False])
x = tempdf1.head(5)['Donor ID']
x = ["D" + str(i + 1) for i in range(len(x))]
y = tempdf1.head(5)['Total Donations']
tr1 = bar_ver_noagg(x, y, 'Total de Donaciones', '#d141ea', lm=None, rt=True)

# Monto total donado
tempdf1 = tempdf.sort_values(by=['Total Amount'], ascending=[False])
x = tempdf1.head(5)['Donor ID']
x = ["D" + str(i + 1) for i in range(len(x))]
y = tempdf1.head(5)['Total Amount']
tr2 = bar_ver_noagg(x, y, 'Monto Total Donado', '#db85ea', lm=None, rt=True)

# Monto promedio por donación
tempdf1 = tempdf.sort_values(by=['Average Donation Amount'], ascending=[False])
x = tempdf1.head(5)['Donor ID']
x = ["D" + str(i + 1) for i in range(len(x))]
y = tempdf1.head(5)['Average Donation Amount']
tr3 = bar_ver_noagg(x, y, 'Monto Promedio por Donación', '#d5b1db', lm=None, rt=True)

# Donación individual máxima
tempdf = donations_df.groupby('Donor ID').agg({
    'Donor ID': 'count',
    'Donation Amount': 'max'
}).rename(columns={
    'Donor ID': "Total Donations",
    'Donation Amount': "Maximum Donations"
}).reset_index()

tempdf1 = tempdf.sort_values(by=['Maximum Donations'], ascending=[False])
x = tempdf1.head(5)['Donor ID']
x = ["D" + str(i + 1) for i in range(len(x))]
y = tempdf1.head(5)['Maximum Donations']
tr4 = bar_ver_noagg(x, y, 'Donación Individual Máxima', '#ccbece', lm=None, rt=True)

# Subgráficos
fig = tools.make_subplots(
    rows=2,
    cols=2,
    print_grid=False,
    subplot_titles=[
        'Número de Donaciones',
        'Monto Total Donado',
        'Monto Promedio Donado',
        'Monto Máximo Donado'
    ]
)

fig.append_trace(tr1, 1, 1)
fig.append_trace(tr2, 1, 2)
fig.append_trace(tr3, 2, 1)
fig.append_trace(tr4, 2, 2)

fig['layout'].update(
    height=600,
    showlegend=False,
    title='Principales Donantes y sus Mayores Contribuciones'
)

iplot(fig)

# %% [markdown]
# > * **Los Donantes Más Generosos:**
# > * Un donante (que no es profesor) de **Manhattan Beach, California** ha donado más de **18,000 veces** (mostrado como D1 en el gráfico de la esquina superior izquierda) en DonorsChoose. Otro donante (que tampoco es profesor) de Nueva York ha aportado una colosal cantidad total equivalente a **1.8 millones de USD** a lo largo de unas 10,513 donaciones (mostrado como D1 en el gráfico de la esquina superior derecha).
# > * El pago único más alto de **60K** para el proyecto "Learning to Play while Playing to Learn" fue realizado por un donante de **Anahola, Hawái**, quien ha hecho un total de 223 donaciones hasta el momento.
#
# ## <a id="3.4">3.4 ¿Qué montos de donación se recibieron y en qué momentos?</a>
#
# ### Donaciones por Año
# * **3.4.1** Número de Donaciones por Año
# * **3.4.2** Montos Promedios de Donación por Año

# %%
# Análisis de las donaciones por año

donations_df['Donation Date'] = pd.to_datetime(donations_df['Donation Received Date'])
donations_df['Donation Year'] = donations_df['Donation Date'].dt.year
donations_df['Donation Month'] = donations_df['Donation Date'].dt.month
donations_df['Donation Day'] = donations_df['Donation Date'].dt.day
donations_df['Donation Weekday'] = donations_df['Donation Date'].dt.weekday
donations_df['Donation Hour'] = donations_df['Donation Date'].dt.hour

t1 = donations_df.groupby(['Donation Year']).agg({
    'Donation Month': 'count',
    'Donation Amount': 'mean'
}).reset_index().rename(columns={
    'Donation Month': 'Total Donations',
    'Donation Amount': 'Average Amount'
})

x = t1['Donation Year']
y1 = t1['Total Donations']
y2 = t1['Average Amount']

trace1 = go.Scatter(
    x=x[:-1],
    y=y1[:-1],
    fill='tozeroy',
    fillcolor='#fcc45f',
    mode='none'
)

trace2 = go.Scatter(
    x=x[:-1],
    y=y2[:-1],
    fill='tozeroy',
    fillcolor="#e993f9",
    mode='none'
)

fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        "<b>Donaciones por Año</b>",
        "<b>Monto Promedio de Donación por Año</b>"
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

fig['layout'].update(
    height=300,
    showlegend=False,
    title="Análisis Anual de las Donaciones",
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    ),
    yaxis2=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    )
)

iplot(fig)

# %% [markdown]
# > Desde el año 2012, el número de donaciones en DonorsChoose ha aumentado de manera regular. Pasando de cerca de 150 donaciones recibidas en 2012, DonorsChoose recibió alrededor de **1.1 millones de donaciones** en el año 2017. El monto más alto recibido en 2017 fue equivalente a **USD 31,856**, aportado por un donante de **Lafayette, Colorado**. Esta donación se recibió el 2 de marzo de 2017.
# > En ese mismo año, se registró una cantidad gigantesca de donaciones por parte de un solo donante de **Manhattan Beach, California**, quien realizó **13,751 donaciones**.
# > El monto promedio de donación recibido por año es cercano a los **USD 60**, mientras que el valor más alto se registró en el año de inicio (2012), alcanzando los **USD 166**.
#
# ### Donaciones por Mes
# * **3.4.3** Número de Donaciones por Mes
# * **3.4.4** Promedio de Donaciones por Mes

# %%
# Análisis de las donaciones por mes

t2 = donations_df.groupby(['Donation Month']).agg({
    'Donation Year': 'count',
    'Donation Amount': 'mean'
}).reset_index().rename(columns={
    'Donation Year': 'Total Donations',
    'Donation Amount': 'Average Amount'
})

x = t2['Donation Month']
y1 = t2['Total Donations']
y2 = t2['Average Amount']

trace1 = go.Scatter(
    x=x,
    y=y1,
    fill='tozeroy',
    fillcolor='#fcc45f',
    mode='none'
)

trace2 = go.Scatter(
    x=x,
    y=y2,
    fill='tozeroy',
    fillcolor="#e993f9",
    mode='none'
)

fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        "<b>Donaciones por Mes</b>",
        "<b>Monto Promedio de Donación por Mes</b>"
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

fig['layout'].update(
    height=300,
    showlegend=False,
    title="Análisis Mensual de las Donaciones",
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    ),
    yaxis2=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    )
)

iplot(fig)

# %% [markdown]
# > * La mayor cantidad de donaciones se recibe en el mes de **agosto con 577,274 donaciones**, seguido por el mes de **septiembre con 518,908 donaciones**, mientras que el menor número de donaciones se registra en el mes de **junio con 191,221 donaciones** y en el mes de **mayo con 243,440 donaciones** (debido probablemente al periodo de verano y vacaciones). El monto promedio de donación más alto se recibe en el mes de diciembre con **USD 80**, mientras que el más bajo se registra en el mes de julio siendo equivalente a **USD 51**. En general, el monto promedio de donación por año es cercano a los USD 59.
#
# ---
#
# ### Donaciones por Día del Mes
# * **3.4.5** Número de Donaciones por Día del Mes
# * **3.4.6** Promedio de Donaciones por Día del Mes

# %%
# Análisis de las donaciones por día del mes

t3 = donations_df.groupby(['Donation Day']).agg({
    'Donation Year': 'count',
    'Donation Amount': 'mean'
}).reset_index().rename(columns={
    'Donation Year': 'Total Donations',
    'Donation Amount': 'Average Amount'
})

x = t3['Donation Day']
y1 = t3['Total Donations']
y2 = t3['Average Amount']

trace1 = go.Scatter(
    x=x,
    y=y1,
    fill='tozeroy',
    fillcolor='#fcc45f',
    mode='none'
)

trace2 = go.Scatter(
    x=x,
    y=y2,
    fill='tozeroy',
    fillcolor="#e993f9",
    mode='none'
)

fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        "<b>Donaciones por Día del Mes</b>",
        "<b>Monto Promedio de Donación por Día del Mes</b>"
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

fig['layout'].update(
    height=300,
    showlegend=False,
    title="Análisis de las Donaciones por Día del Mes",
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    ),
    yaxis2=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    )
)

iplot(fig)

# %% [markdown]
# ### Donaciones por Día de la Semana
# * **3.4.7** Número de Donaciones por Día de la Semana
# * **3.4.8** Promedio de Donaciones por Día de la Semana

# %%
# Análisis de las donaciones por día de la semana

t4 = donations_df.groupby(['Donation Weekday']).agg({
    'Donation Year': 'count',
    'Donation Amount': 'mean'
}).reset_index().rename(columns={
    'Donation Year': 'Total Donations',
    'Donation Amount': 'Average Amount'
})

x = t4['Donation Weekday']
y1 = t4['Total Donations']
y2 = t4['Average Amount']

trace1 = go.Scatter(
    x=x,
    y=y1,
    fill='tozeroy',
    fillcolor='#fcc45f',
    mode='none'
)

trace2 = go.Scatter(
    x=x,
    y=y2,
    fill='tozeroy',
    fillcolor="#e993f9",
    mode='none'
)

fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        "<b>Donaciones por Día de la Semana</b>",
        "<b>Monto Promedio de Donación por Día de la Semana</b>"
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

fig['layout'].update(
    height=300,
    showlegend=False,
    title="Análisis de las Donaciones por Día de la Semana",
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    ),
    yaxis2=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    )
)

iplot(fig)

# %% [markdown]
# > El número de donaciones alcanza su punto más alto en los primeros días de la semana, es decir, lunes, martes y miércoles, con totales de 700K, 800K y 750K donaciones respectivamente, y la cantidad disminuye en los días posteriores. Tal como se observa en el gráfico, el menor número de donaciones se recibe los sábados.
#
# ---
#
# ### Donaciones por Hora del Día
# * **3.4.9** Número de Donaciones por Hora del Día
# * **3.4.10** Promedio de Donaciones por Hora del Día

# %%
# Análisis de las donaciones por hora

t5 = donations_df.groupby(['Donation Hour']).agg({
    'Donation Month': 'count',
    'Donation Amount': 'mean'
}).reset_index().rename(columns={
    'Donation Month': 'Total Donations',
    'Donation Amount': 'Average Amount'
})

x = t5['Donation Hour']
y1 = t5['Total Donations']
y2 = t5['Average Amount']

trace1 = go.Scatter(
    x=x[:-1],
    y=y1[:-1],
    fill='tozeroy',
    fillcolor='#fcc45f',
    mode='none'
)

trace2 = go.Scatter(
    x=x[:-1],
    y=y2[:-1],
    fill='tozeroy',
    fillcolor="#e993f9",
    mode='none'
)

fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        "<b>Donaciones por Hora</b>",
        "<b>Monto Promedio de Donación por Hora</b>"
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

fig['layout'].update(
    height=300,
    showlegend=False,
    title="Análisis de las Donaciones por Hora",
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    ),
    yaxis2=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    )
)

iplot(fig)

# %% [markdown]
# ## <a id="3.5">3.5 Donaciones Opcionales y Donantes Profesores</a>
#
# ### <a id="3.5.1">3.5.1 Total de Donaciones Opcionales y sus Montos Promedios Asociados</a>

# %%
# Análisis de las donaciones opcionales

tempdf = donations_df.groupby('Donation Included Optional Donation').agg({
    'Donation Included Optional Donation': 'count',
    'Donation Amount': 'mean'
})

values1 = list(tempdf['Donation Included Optional Donation'])
values2 = list(tempdf['Donation Amount'])
values2t = [f"${int(x)}" for x in values2]

domain1 = {'x': [0.2, 0.50], 'y': [0.0, 0.33]}
domain2 = {'x': [0.8, 0.50], 'y': [0.0, 0.33]}

labels = list(tempdf.index)
mp = {
    'Yes': 'Con Donación Opcional',
    'No': 'Sin Donación Opcional'
}
labels = [mp[x] for x in labels]

trace1 = go.Pie(
    labels=labels,
    values=values1,
    marker=dict(colors=['#75e575', '#ea7c96'])
)

trace2 = go.Pie(
    labels=labels,
    values=values2,
    marker=dict(colors=['#75e575', '#ea7c96']),
    textinfo="text",
    text=values2t
)

layout = go.Layout(
    title='Número de Donaciones con Donación Opcional',
    width=800,
    height=400
)

# fig = go.Figure(data=[trace1], layout=layout)
# iplot(fig)

layout = go.Layout(
    title='Monto Promedio Donado en Donaciones Opcionales',
    width=800,
    height=400
)

# fig = go.Figure(data=[trace2], layout=layout)
# iplot(fig)

fig = {
    "data": [
        {
            "values": values1,
            "labels": list(reversed(labels)),
            "domain": {"x": [0, .48]},
            "marker": dict(colors=['#f9345b', '#75e575']),
            "name": "Número de Donaciones con Donación Opcional",
            "type": "pie"
        },
        {
            "values": values2,
            "labels": labels,
            "marker": dict(colors=['#75e575', '#f9345b']),
            "domain": {"x": [.52, 1]},
            "name": "Monto Promedio de Donación con Donación Opcional",
            "text": values2t,
            "textinfo": "text",
            "type": "pie"
        }
    ],
    "layout": {
        "title": "Donaciones Opcionales: Cantidad Total y Monto Promedio Donado"
    }
}

iplot(fig, filename='donut')

# %% [markdown]
# > * Los proyectos de DonorsChoose también cuentan con la opción de Donaciones Opcionales. El monto promedio para una donación opcional es de **USD 58**, mientras que para una donación no opcional es de **USD 73**. Del total de las donaciones realizadas, aproximadamente el **15%** correspondieron a donaciones opciales.
#
# ### <a href="3.5.2">3.5.2 Total de Donaciones de Profesores Donantes y los Montos Promedios Asociados</a>

# %%
# Combinar la información de donantes y donaciones
combined_df = donations_df.merge(donors_df, on='Donor ID', how='inner')
# combined_df.head(10)

tempdf = combined_df.groupby('Donor Is Teacher').agg({
    'Donor Is Teacher': 'count',
    'Donation Amount': 'mean'
})

values1 = list(tempdf['Donor Is Teacher'])
values2 = list(tempdf['Donation Amount'])
values2t = [f"${int(x)}" for x in values2]

domain1 = {'x': [0.2, 0.50], 'y': [0.0, 0.33]}
domain2 = {'x': [0.8, 0.50], 'y': [0.0, 0.33]}

labels = list(tempdf.index)
mp = {
    'Yes': 'Donante Docente',
    'No': 'Donante No Docente'
}
labels = [mp[x] for x in labels]

trace1 = go.Pie(
    labels=labels,
    values=values1,
    marker=dict(colors=['#75e575', '#ea7c96'])
)

trace2 = go.Pie(
    labels=labels,
    values=values2,
    marker=dict(colors=['#75e575', '#ea7c96']),
    textinfo="text",
    text=values2t
)

layout = go.Layout(
    title='Número de Donaciones según si el Donante es Docente',
    width=800,
    height=400
)

# fig = go.Figure(data=[trace1], layout=layout)
# iplot(fig)

layout = go.Layout(
    title='Monto Promedio Donado según si el Donante es Docente',
    width=800,
    height=400
)

# fig = go.Figure(data=[trace2], layout=layout)
# iplot(fig)

fig = {
    "data": [
        {
            "values": values1,
            "labels": labels,
            "domain": {"x": [0, .48]},
            "marker": dict(colors=['#ab97db', '#b0b1b2']),
            "name": "Número de Donaciones",
            "type": "pie"
        },
        {
            "values": values2,
            "labels": labels,
            "marker": dict(colors=['#ab97db', '#b0b1b2']),
            "domain": {"x": [.52, 1]},
            "name": "Monto Promedio Donado",
            "text": values2t,
            "textinfo": "text",
            "type": "pie"
        }
    ],
    "layout": {
        "title": "Donantes Docentes vs. No Docentes: Cantidad de Donaciones y Monto Promedio Donado"
    }
}

iplot(fig, filename='donut')

# %% [markdown]
# > * Aproximadamente el **29%** del total de las donaciones en DonorsChoose son realizadas por donantes que también son profesores. La mayor cantidad de estos profesores donantes proviene de California.
# > * El monto promedio de la donación de un profesor es de **USD 45**, mientras que para los donantes que no son profesores es de **USD 66**.

# %%
def mapp(df, scl, t):
    state_to_code = {'District of Columbia' : 'dc','Mississippi': 'MS', 'Oklahoma': 'OK', 'Delaware': 'DE', 'Minnesota': 'MN', 'Illinois': 'IL', 'Arkansas': 'AR', 'New Mexico': 'NM', 'Indiana': 'IN', 'Maryland': 'MD', 'Louisiana': 'LA', 'Idaho': 'ID', 'Wyoming': 'WY', 'Tennessee': 'TN', 'Arizona': 'AZ', 'Iowa': 'IA', 'Michigan': 'MI', 'Kansas': 'KS', 'Utah': 'UT', 'Virginia': 'VA', 'Oregon': 'OR', 'Connecticut': 'CT', 'Montana': 'MT', 'California': 'CA', 'Massachusetts': 'MA', 'West Virginia': 'WV', 'South Carolina': 'SC', 'New Hampshire': 'NH', 'Wisconsin': 'WI', 'Vermont': 'VT', 'Georgia': 'GA', 'North Dakota': 'ND', 'Pennsylvania': 'PA', 'Florida': 'FL', 'Alaska': 'AK', 'Kentucky': 'KY', 'Hawaii': 'HI', 'Nebraska': 'NE', 'Missouri': 'MO', 'Ohio': 'OH', 'Alabama': 'AL', 'Rhode Island': 'RI', 'South Dakota': 'SD', 'Colorado': 'CO', 'New Jersey': 'NJ', 'Washington': 'WA', 'North Carolina': 'NC', 'New York': 'NY', 'Texas': 'TX', 'Nevada': 'NV', 'Maine': 'ME'}
    df['state_code'] = statesdf['state'].apply(lambda x : state_to_code[x] if x in state_to_code else "")

    data = [ dict(
            type='choropleth',
            colorscale = scl,
            autocolorscale = False,
            locations = df['state_code'],
            z = df['counts'],
            locationmode = 'USA-states',
            text = df['state'],
            marker = dict(
                line = dict (
                    color = 'rgb(255,255,255)',
                    width = 2
                ) ),
            colorbar = dict(
                title = "Donors")
            ) ]

    layout = dict(
            title = t,
            geo = dict(
                scope='usa',
                projection=dict( type='albers usa' ),
                showlakes = True,
                lakecolor = 'rgb(255, 255, 255)'),
                 )

    fig = dict( data=data, layout=layout )
    iplot( fig, filename='d3-cloropleth-map' )

# %% [markdown]
# ## <a id="3.6">3.6 ¿Qué estados recibieron los montos más altos de donación única?</a>
# * **3.6.1** Principales Estados con los Montos de Donación más altos
# * **3.6.2** Principales Ciudades con los Montos de Donación más altos

# %%
# Montos máximos de donación

tempdf = combined_df.groupby(['Donor State']).agg({
    'Donation Amount': 'max'
}).reset_index()

t1 = tempdf.sort_values('Donation Amount', ascending=False)

tempdf = combined_df.groupby(['Donor City']).agg({
    'Donation Amount': 'max'
}).reset_index()

t2 = tempdf.sort_values('Donation Amount', ascending=False)

statesdf = pd.DataFrame()
statesdf['state'] = t1['Donor State']
statesdf['counts'] = t1['Donation Amount']

statesdf

citydf = pd.DataFrame()
citydf['state'] = t2['Donor City']
citydf['counts'] = t2['Donation Amount']

citydf


scl = [
    [0.0, 'rgb(240,240,240)'],
    [0.2, 'rgb(220,220,220)'],
    [0.4, 'rgb(180,180,180)'],
    [0.6, 'rgb(154,154,154)'],
    [0.8, 'rgb(117,117,117)'],
    [1.0, 'rgb(84,84,84)']
]

mapp(statesdf, scl, 'Donaciones Individuales Máximas por Estado')


trace1 = bar_hor_noagg(
    list(reversed(list(statesdf['state'][:10]))),
    list(reversed(list(statesdf['counts'][:10]))),
    "Estados con las Donaciones Individuales Máximas",
    '#a8a1a3',
    600,
    400,
    200,
    limit=10,
    rt=True
)

trace2 = bar_hor_noagg(
    list(reversed(list(citydf['state'][:10]))),
    list(reversed(list(citydf['counts'][:10]))),
    "Ciudades con las Donaciones Individuales Máximas",
    '#a8a1a3',
    600,
    400,
    200,
    limit=10,
    rt=True
)


fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        'Principales Estados con Donación Individual Máxima',
        'Principales Ciudades con Donación Individual Máxima'
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

fig['layout'].update(
    height=400,
    showlegend=False,
    title='Distribución de las Donaciones Individuales Máximas por Ubicación'
)

iplot(fig)

# %% [markdown]
# > * Hawái y Colorado son estados que, a pesar de tener un menor número de donaciones, registraron los montos máximos de donación más altos.
# > * Ciudades: Anahola, Lafayette y Palo Alto han contribuido con los montos individuales más altos: 60K, 31K y 26K respectivamente.
#
# ## <a id="3.7">3.7 ¿Qué estado recibe los montos promedios de donación más altos?</a>

# %%
# Montos promedio de donación

tempdf = combined_df.groupby(['Donor State']).agg({
    'Donation Amount': 'mean'
}).reset_index()

t1 = tempdf.sort_values('Donation Amount', ascending=False)

tempdf = combined_df.groupby(['Donor City']).agg({
    'Donation Amount': 'mean'
}).reset_index()

t2 = tempdf.sort_values('Donation Amount', ascending=False)

statesdf = pd.DataFrame()
statesdf['state'] = t1['Donor State']
statesdf['counts'] = t1['Donation Amount']

statesdf

citydf = pd.DataFrame()
citydf['state'] = t2['Donor City']
citydf['counts'] = t2['Donation Amount']

citydf


scl = [
    [0.0, 'rgb(248,255,206)'],
    [0.2, 'rgb(203,255,205)'],
    [0.4, 'rgb(155,255,164)'],
    [0.6, 'rgb(79,255,178)'],
    [0.8, 'rgb(15,183,132)'],
    [1, '#008059']
]

mapp(statesdf, scl, 'Montos Promedio de Donación por Estado')


trace1 = bar_hor_noagg(
    list(reversed(list(statesdf['state'][:10]))),
    list(reversed(list(statesdf['counts'][:10]))),
    "Estados con Mayor Monto Promedio de Donación",
    '#a8a1a3',
    600,
    400,
    200,
    limit=10,
    rt=True
)

trace2 = bar_hor_noagg(
    list(reversed(list(citydf['state'][:10]))),
    list(reversed(list(citydf['counts'][:10]))),
    "Ciudades con Mayor Monto Promedio de Donación",
    '#a8a1a3',
    600,
    400,
    200,
    limit=10,
    rt=True
)


fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        'Estados y Montos Promedio Donados',
        'Ciudades y Montos Promedio Donados'
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)

fig['layout'].update(
    height=400,
    showlegend=False,
    title='Distribución de los Montos Promedio de Donación por Ubicación'
)

iplot(fig)

# %% [markdown]
# > * Hawái y Massachusetts tienen los montos promedios de donación más altos.
# > * Clarks Point, Swiftwater y North English son las ciudades desde las cuales se reciben los montos promedios de donación más altos.
#
# ## <a id="3.8">3.8 Montos Totales Donados por cada Estado</a>

# %%
statesll=StringIO("""State,Latitude,Longitude
Alabama,32.806671,-86.791130
Alaska,61.370716,-152.404419
Arizona,33.729759,-111.431221
Arkansas,34.969704,-92.373123
California,36.116203,-119.681564
Colorado,39.059811,-105.311104
Connecticut,41.597782,-72.755371
Delaware,39.318523,-75.507141
District of Columbia,38.897438,-77.026817
Florida,27.766279,-81.686783
Georgia,33.040619,-83.643074
Hawaii,21.094318,-157.498337
Idaho,44.240459,-114.478828
Illinois,40.349457,-88.986137
Indiana,39.849426,-86.258278
Iowa,42.011539,-93.210526
Kansas,38.526600,-96.726486
Kentucky,37.668140,-84.670067
Louisiana,31.169546,-91.867805
Maine,44.693947,-69.381927
Maryland,39.063946,-76.802101
Massachusetts,42.230171,-71.530106
Michigan,43.326618,-84.536095
Minnesota,45.694454,-93.900192
Mississippi,32.741646,-89.678696
Missouri,38.456085,-92.288368
Montana,46.921925,-110.454353
Nebraska,41.125370,-98.268082
Nevada,38.313515,-117.055374
New Hampshire,43.452492,-71.563896
New Jersey,40.298904,-74.521011
New Mexico,34.840515,-106.248482
New York,42.165726,-74.948051
North Carolina,35.630066,-79.806419
North Dakota,47.528912,-99.784012
Ohio,40.388783,-82.764915
Oklahoma,35.565342,-96.928917
Oregon,44.572021,-122.070938
Pennsylvania,40.590752,-77.209755
Rhode Island,41.680893,-71.511780
South Carolina,33.856892,-80.945007
South Dakota,44.299782,-99.438828
Tennessee,35.747845,-86.692345
Texas,31.054487,-97.563461
Utah,40.150032,-111.862434
Vermont,44.045876,-72.710686
Virginia,37.769337,-78.169968
Washington,47.400902,-121.490494
West Virginia,38.491226,-80.954453
Wisconsin,44.268543,-89.616508
Wyoming,42.755966,-107.302490""")

tempdf = combined_df.groupby(['Donor State']).agg({'Donation Amount':'sum'}).reset_index()
t1 = tempdf.sort_values('Donation Amount', ascending=False)

sdf = pd.read_csv(statesll).rename(columns={'State':'Donor State'})
sdf = sdf.merge(t1, on='Donor State', how='inner')

map4 = folium.Map(location=[39.50, -98.35], tiles='CartoDB dark_matter', zoom_start=3.5)
for j, rown in sdf.iterrows():
    rown = list(rown)
    folium.CircleMarker([float(rown[1]), float(rown[2])], popup=rown[0]+": $"+str(int(rown[3])), radius=float(rown[3])*0.000001, color='blue', fill=True).add_to(map4)
map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe07f86bf1757de1a2c7f8588cc15450 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe07f86bf1757de1a2c7f8588cc15450&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe07f86bf1757de1a2c7f8588cc15450 = L.map(
#                 &quot;map_fe07f86bf1757de1a2c7f8588cc15450&quot;,
#                 {
#                     center: [39.5, -98.35],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3.5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f3b598449d3ad334c64c26056ce9b83 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f3b598449d3ad334c64c26056ce9b83.addTo(map_fe07f86bf1757de1a2c7f8588cc15450);
#
#
#             var circle_marker_5c9e70651d3d3849ef37e8640c1e1fda = L.circleMarker(
#                 [36.116203, -119.681564],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.0008807299999999999, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fe07f86bf1757de1a2c7f8588cc15450);
#
#
#         var popup_e66e90152dc38561135840eda2b4ac30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03b398f303512590940b75f70d52dcb6 = $(`&lt;div id=&quot;html_03b398f303512590940b75f70d52dcb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;California: $880&lt;/div&gt;`)[0];
#                 popup_e66e90152dc38561135840eda2b4ac30.setContent(html_03b398f303512590940b75f70d52dcb6);
#
#
#
#         circle_marker_5c9e70651d3d3849ef37e8640c1e1fda.bindPopup(popup_e66e90152dc38561135840eda2b4ac30)
#         ;
#
#
#
#
#             var circle_marker_75a857d96c306011d27a249e6d102b2b = L.circleMarker(
#                 [42.165726, -74.948051],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.00019821999999999996, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fe07f86bf1757de1a2c7f8588cc15450);
#
#
#         var popup_7cce96a114d85f501c8e06d401e9b6cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c24ac28c4f6ca1da1493e27605bbf27 = $(`&lt;div id=&quot;html_8c24ac28c4f6ca1da1493e27605bbf27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York: $198&lt;/div&gt;`)[0];
#                 popup_7cce96a114d85f501c8e06d401e9b6cc.setContent(html_8c24ac28c4f6ca1da1493e27605bbf27);
#
#
#
#         circle_marker_75a857d96c306011d27a249e6d102b2b.bindPopup(popup_7cce96a114d85f501c8e06d401e9b6cc)
#         ;
#
#
#
#
#             var circle_marker_8f85d27906e576f880be36d11d7264fe = L.circleMarker(
#                 [31.054487, -97.563461],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.00234783, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fe07f86bf1757de1a2c7f8588cc15450);
#
#
#         var popup_7d88d03e40a19a5fa0b8a7e492abcd9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea312223552dc028a3969804c08bfc2b = $(`&lt;div id=&quot;html_ea312223552dc028a3969804c08bfc2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Texas: $2347&lt;/div&gt;`)[0];
#                 popup_7d88d03e40a19a5fa0b8a7e492abcd9e.setContent(html_ea312223552dc028a3969804c08bfc2b);
#
#
#
#         circle_marker_8f85d27906e576f880be36d11d726

# %% [markdown]
# ## <a id="3.9">3.9 Donaciones de California a lo largo del tiempo</a>
#
# Vamos a ver la tendencia de las donaciones de California a lo largo de los años.

# %%
# Donaciones de California a lo largo del tiempo

combined_df['Donation Date'] = combined_df['Donation Received Date'].apply(
    lambda x: str(x).split()[0]
)

cali = combined_df[combined_df['Donor State'] == 'California']

cali = cali.groupby('Donation Date').agg({
    'Donation Amount': 'count'
}).reset_index()

cali1 = pd.DataFrame()
cali1['Date'] = pd.to_datetime(cali['Donation Date'])
cali1['Donation Amount'] = cali['Donation Amount']


trace1 = go.Scatter(
    x=cali1['Date'],
    y=cali1['Donation Amount'],
    name="California",
    line=dict(color='red'),
    opacity=0.8
)

data = [trace1]

layout = dict(
    title="Donaciones de California a lo largo del tiempo",
    height=400,
    showlegend=False,
    yaxis=dict(
        autorange=True,
        showgrid=False,
        zeroline=False,
        showline=False,
        ticks='',
        showticklabels=False
    )
)

fig = dict(
    data=data,
    layout=layout
)

iplot(fig)

# %% [markdown]
# > El número máximo de donaciones provenientes de California se registró el **25 de enero de 2018** con casi 5,000 donaciones, seguido por el **28 de noviembre de 2017** con 4,699 donaciones.
#
# ## <a id="4">4. Exploración de los Profesores</a>
#
# ## <a id="4.1">4.1 Panorama de los Datos de los Profesores</a>

# %%
teachers_df.head(3)
# len(teachers_df)

# %% [markdown]
# > Hay un total de 402,900 profesores que han publicado al menos un proyecto en DonorsChoose desde el año 2002. La gran mayoría de los profesores son mujeres; echemos un vistazo a quiénes fueron los primeros profesores que publicaron proyectos en DonorsChoose.
#
# ## <a id="4.2">4.2 ¿Quiénes fueron los primeros profesores en DonorsChoose.org?</a>

# %%
teachers_df['Posted Date'] = pd.to_datetime(teachers_df['Teacher First Project Posted Date'])
teachers_df['Posted Year'] = teachers_df['Posted Date'].dt.year

# Lets Find out who were the first donors on DonorsChooseSome of the Earliest Teachers 
teachers_df[['Teacher ID', 'Posted Date']].sort_values(['Posted Date'])[:10]
# Out:
#                            Teacher ID Posted Date
# 29   6f4cc69a4b22d3081c8eaee95715bd6f  2002-01-27
# 78   d450281c6c6f7633a260772317a0df49  2002-01-30
# 114  25c73c443e75c3b4664fa6637e8f8095  2002-02-15
# 68   c07a30f2edd4253b50f0fd0a750cab75  2002-03-18
# 80   b4a69f3c8d3aed99711c21c9bdc14f1f  2002-03-21
# 54   ffd0f9d5a6f2f7b80cf35b5819108be5  2002-05-01
# 162  b63b4dc3a559e46379e13ceab0cbc61f  2002-05-22
# 42   3985c3cf3f76be1d1efa21977394988f  2002-06-22
# 87   2d534dd0cf8ebc5accc56569f9e8a369  2002-07-23
# 95   89456f27d7fa2d8dfb2ca025adf4e62d  2002-08-15

# %% [markdown]
# > Los primeros profesores en DonorsChoose se registraron el 17 de septiembre de 2002. En este día se registraron 2 profesores, ambas mujeres. En el mes de septiembre de 2002, se registraron en total 8 profesores, quienes formaron principalmente el primer grupo de docentes en DonorsChoose.
#
# ## <a id="4.3">4.3 Crecimiento en el Número de Profesores a lo largo de los años</a>

# %%
# Número de profesores que comenzaron a publicar proyectos por año

temp = teachers_df.groupby('Posted Year').agg({
    'Teacher ID': 'count'
}).reset_index()

temp = temp.sort_values('Posted Year')

# Configurar el trazo del gráfico
trace = go.Scatter(
    x=list(temp['Posted Year'])[:-1],
    y=list(temp['Teacher ID'])[:-1],
    mode='lines+markers',
    line=dict(color="#42e5f4", width=8),
    connectgaps=True,
    fillcolor='rgba(0,100,80,0.2)',
)

# Diseñar el diseño del gráfico
layout = go.Layout(
    xaxis=dict(
        showline=True,
        showgrid=False,
        showticklabels=True,
        linecolor='rgb(204, 204, 204)',
        linewidth=2,
        ticks='outside',
        tickcolor='rgb(204, 204, 204)',
        tickwidth=2,
        ticklen=5,
        tickfont=dict(
            family='Arial',
            size=12,
            color='rgb(82, 82, 82)',
        ),
    ),
    title='Cantidad de Profesores que Comenzaron a Publicar sus Proyectos por Año'
)

# Crear la figura y graficar
fig = go.Figure(
    data=[trace],
    layout=layout
)

iplot(fig, filename='news-source')

# %% [markdown]
# > * Un grupo inicial de profesores comenzó a publicar en DonorsChoose cuando la plataforma se lanzó en 2002, pero durante los primeros cinco años se observó una cantidad muy baja de docentes publicando proyectos.
# > * Una tendencia al alza comenzó a desarrollarse alrededor de 2008, y el periodo **2012 - 2013** registró un incremento masivo en el número de profesores que publicaban sus proyectos.
# > * La tendencia alcanzó su cúspide en 2016 con 80K nuevos profesores publicando proyectos, pero **esta cantidad disminuyó a 75K en 2017**. No solo se necesita motivar a los donantes, sino que también se debe incentivar a los profesores para que publiquen más proyectos. Al observar el crecimiento de nuevos docentes a lo largo de los años, parece que DonorsChoose está haciendo un buen trabajo.
#
# ## <a id="4.4">4.4 ¿Cuál es la distribución de los prefijos de los profesores?</a>

# %%
# Distribución de profesores según su prefijo

t = teachers_df['Teacher Prefix'].value_counts()

labels = t.index
values2 = t.values

trace2 = go.Pie(
    labels=labels,
    values=values2,
    marker=dict(colors=['#75e575', '#ea7c96'])
)

layout = go.Layout(
    title='Distribución de Profesores según su Prefijo',
    width=800,
    height=500
)

fig = go.Figure(
    data=[trace2],
    layout=layout
)

iplot(fig)

# %% [markdown]
# ## <a id="4.5">4.5 Serie Temporal de los Profesores publicando sus primeros proyectos</a>

# %%
# Fecha y primeros proyectos publicados por profesores

t = teachers_df['Posted Date'].value_counts()

x = t.index
y = t.values

bar_ver_noagg(
    x,
    y,
    'Fecha de Publicación y Primeros Proyectos de los Profesores',
    'orange'
)

# %% [markdown]
# > * El mayor número de proyectos publicados por primera vez se observó el **13 de septiembre de 2015 con un total de 2,067 proyectos**.
# > * Es interesante notar que se observan picos cada año en el mes de agosto desde 2014 hasta 2017.
#
# ## <a id="5">5. Exploración de las Escuelas</a>
#
# ## <a id="5.1">5.1 Panorama de los Datos de las Escuelas</a>

# %%
# Versión corregida para versiones modernas de Pandas
schools_df = pd.read_csv(path + "Schools.csv", on_bad_lines='skip')
schools_df.head(3)
# Out:
#                           School ID                  School Name  \
# 0  bdd640fb06671ad11c80317fa3b1799d      Miami Elementary School
# 1  07a0ca6e0822e8f36c031199972a8469    Houston Elementary School
# 2  a65ed389b74d0fb132e706298fadc1a6  Sammamish Elementary School
#
#   School Metro Type  School Percentage Free Lunch School State  School Zip  \
# 0             urban                          17.0      Florida       23434
# 1             urban                          64.0        Texas       88907
# 2              town                          75.0   Washington       46463
#
#   School City     School County            School District
# 0       Miami      Miami County      Miami School District
# 1     Houston    Houston County    Houston School District
# 2   Sammamish  Sammamish County  Sammamish School District

# %% [markdown]
# > Se han publicado proyectos de un total de 72,993 escuelas diferentes en DonorsChoose hasta abril de 2018.
#
# ## <a id="5.2">5.2 ¿Qué tipo de zona metropolitana publica proyectos? (y principales Estados y Ciudades)</a>

# %%
# Análisis de escuelas por tipo de zona, estado y ciudad

t1 = schools_df['School Metro Type'].value_counts()
t2 = schools_df['School State'].value_counts()
t3 = schools_df['School City'].value_counts()


trace1 = bar_ver_noagg(
    t1.index[:10],
    t1.values[:10],
    "Tipo de Zona Metropolitana de la Escuela",
    '#e56eb5',
    None,
    None,
    0,
    rt=True
)

trace2 = bar_ver_noagg(
    t2.index[:10],
    t2.values[:10],
    "Estados con Mayor Número de Escuelas",
    '#e88de8',
    None,
    None,
    0,
    rt=True
)

trace3 = bar_ver_noagg(
    t3.index[:10],
    t3.values[:10],
    "Ciudades con Mayor Número de Escuelas",
    '#efc4ef',
    None,
    None,
    0,
    rt=True
)


fig = tools.make_subplots(
    rows=1,
    cols=3,
    print_grid=False,
    subplot_titles=[
        'Tipo de Zona Metropolitana de la Escuela',
        'Estados con Mayor Número de Escuelas',
        'Ciudades con Mayor Número de Escuelas'
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 1, 3)

fig['layout'].update(
    height=400,
    showlegend=False,
    title='Distribución de Escuelas por Ubicación y Tipo de Zona'
)

iplot(fig)

# %% [markdown]
# > * La mayoría de las escuelas están ubicadas en áreas suburbanas y urbanas.
# > * Nueva York, Houston y Chicago son las tres ciudades principales donde se encuentran ubicadas las escuelas.
#
# ## <a id="5.3">5.3 Distribución del Porcentaje de Almuerzo Gratuito en las Escuelas</a>

# %%
# Distribución del porcentaje de estudiantes con almuerzo gratuito en escuelas

plt.figure(figsize=(15, 5))

sns.distplot(
    schools_df['School Percentage Free Lunch'].dropna(),
    bins=120,
    color="#ff002e"
)

plt.xlabel(
    'Porcentaje de Estudiantes con Almuerzo Gratuito en la Escuela',
    fontsize=14
)

plt.title(
    "Distribución del Porcentaje de Almuerzo Gratuito en las Escuelas",
    fontsize=14
)

plt.show()

# %% [markdown]
# ## <a id="5.4">5.4 ¿Qué tipos de escuelas están registradas en su mayoría?</a>

# %%
# Distribución de tipos de escuelas según el nombre de la escuela

words = " ".join(schools_df['School Name']).split()

from collections import Counter

school_types = Counter(words).most_common(30)[1:9]

school_types = [list(x) for x in school_types]

labels = [x[0] + " Escuela" for x in school_types]
values = [x[1] for x in school_types]


trace2 = go.Bar(
    x=labels,
    y=values,
    name='Distribución de Tipos de Escuelas',
    marker=dict(color='#ff00bb'),
    opacity=0.3
)

data = [trace2]

layout = go.Layout(
    barmode='group',
    legend=dict(dict(x=-0.1, y=1.2)),
    title='Distribución de Tipos de Escuelas'
)

fig = go.Figure(
    data=data,
    layout=layout
)

iplot(fig, filename='grouped-bar')

# %% [markdown]
# > Una gran mayoría de las escuelas son Escuelas Primarias (*Elementary Schools*, con cerca de 35K escuelas), lo cual es notablemente mayor que las Escuelas Secundarias / Preparatorias (*High Schools*, unas 12K escuelas), Escuelas Secundarias Medias (*Middle Schools*, unas 9K escuelas) o las Academias (*Academy Schools*, cerca de 4K escuelas).
#
# ## <a id="6">6. Exploración de Recursos</a>
#
# Los datos de recursos consisten en los artículos solicitados bajo diferentes proyectos, lo cual incluye el nombre del artículo, la cantidad del recurso, el precio unitario y el nombre del proveedor (*vendor*).
#
# ## <a id="6.1">6.1 Panorama de los Datos de Recursos</a>

# %%
resources_df = pd.read_csv(path+"Resources.csv")
resources_df.head(5)

# len(resources_df)
# Out:
#                          Project ID  \
# 0  bdd640fb06671ad11c80317fa3b1799d
# 1  f143262fdc5c0eed8da0365bf89897b9
# 2  451b4cf36123fdf77656af7229d4beef
# 3  0e51f30dc6a7ee39c4b032ccd7c524a5
# 4  0e51f30dc6a7ee39c4b032ccd7c524a5
#
#                           Resource Item Name  Resource Quantity  \
# 0  gaiam kids stay-n-play balance ball, grey               44.0
# 1                      apple ipad wi-fi 32gb                8.0
# 2              sony mdr zx100 blk headphones               17.0
# 3  gaiam kids stay-n-play balance ball, grey               41.0
# 4              serta lounger, mini, sky blue               10.0
#
#    Resource Unit Price          Resource Vendor Name
# 0               398.73  Lakeshore Learning Materials
# 1               135.61               Amazon Business
# 2               437.49               Amazon Business
# 3               137.81                           NaN
# 4               171.39               Amazon Business

# %% [markdown]
# > Hasta abril de 2018, los profesores han realizado un total de 7,210,448 solicitudes de recursos en diferentes proyectos.
#
# ## <a id="6.2">6.2 Artículos más populares</a>
#
# Vamos a obtener cuáles son los artículos más populares a partir de los datos de recursos. Los artículos más solicitados son aquellos que aparecieron en una gran cantidad de proyectos; por otro lado, los artículos solicitados en masa (o a granel) representan aquellos que fueron pedidos en grandes cantidades por solicitud.
#
# * **6.2.1** Artículos más solicitados de todos los tiempos
# * **6.2.2** Artículos solicitados en cantidades masivas

# %%
# Análisis de los recursos más solicitados

# 1. Obtener los 15 artículos más solicitados de forma dinámica
tdf = resources_df['Resource Item Name'].value_counts()[:15]

t = pd.DataFrame()
t['item'] = tdf.index
t['count'] = tdf.values

# Usamos directamente los nombres reales para evitar escribir la lista a mano
t['standardized'] = t['item'].astype(str).str.strip()

# Limpieza y agrupación
t1 = t.groupby('standardized').agg({
    'count': 'sum'
}).reset_index()

t1 = t1.sort_values('count', ascending=True)

# Filtrar "Noise" de forma segura
t1 = t1[t1['standardized'].str.lower() != "noise"]


# Generar el primer trazo
trace1 = bar_ver_noagg(
    list(t1['standardized']),
    list(t1['count']),
    "Artículos de Recursos Más Solicitados",
    "#ff5479",
    400,
    400,
    0,
    rt=True
)


# 2. Obtener los artículos solicitados en cantidades masivas (Bulk)
t_bulk = resources_df.sort_values(
    'Resource Quantity',
    ascending=False
).head(10)


trace2 = bar_ver_noagg(
    t_bulk['Resource Item Name'],
    t_bulk['Resource Quantity'],
    "Artículos Solicitados en Grandes Cantidades",
    "#fc839d",
    600,
    400,
    0,
    rt=True
)


# 3. Construir la cuadrícula de subplots
fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        'Artículos Más Solicitados',
        'Artículos Solicitados en Grandes Cantidades'
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)


# Actualizar el diseño final
fig['layout'].update(
    height=400,
    showlegend=False,
    margin=dict(b=120),
    title='Análisis de los Recursos Solicitados'
)

iplot(fig)

# %% [markdown]
# > Como podemos ver, el Apple iPad (iPad Mini, Wifi, 16 o 32 GB) es el artículo más solicitado de todos los tiempos. Fue pedido en más de 30 mil proyectos. Los profesores están muy interesados en utilizar la tecnología en las aulas. Los **viajes** (*Trips*) son otro de los artículos más solicitados de todos los tiempos con más de 20K proyectos, lo que significa que los docentes están interesados en llevar a los estudiantes a viajes educativos o culturales. Otros artículos destacados incluyen divisiones de privacidad (*Privacy Partition*), mobiliario comercial y asientos acolchados (*Soft seats*).
# >
# > Hay muchos artículos que se solicitan en masa (al por mayor) en uno o más proyectos. Algunos de estos artículos incluyen bloques de polietileno reticulado, repuestos para micrófonos Q-Ball (*q-ball renewal glide*) y protectores para patas de sillas (*chair glide*).
#
# ## <a id="6.3">6.3 Artículos más caros</a>

# %%
# Recursos con mayor precio unitario

t = resources_df.sort_values(
    'Resource Unit Price',
    ascending=False
).head(15)

t1 = pd.DataFrame()

t1['item'] = t['Resource Item Name']
t1['price'] = t['Resource Unit Price']

t1['standardized'] = """
Handicapped Playground,
Playground,
CommercialStructure,
Telescopic Gym,
Playground+Playsystem,
Sound System,
CommercialStructure,
Wood Playground,
Playground+Playsystem,
10 Alpha,
Leveled Bookroom,
Daktronic GS6,
Contra Bassoon,
Fencing,
Playground+Playsystem
""".split(",")

t2 = t1.groupby('standardized').agg({
    'price': 'max'
}).reset_index()

t2 = t2.sort_values(
    'price',
    ascending=True
)

trace2 = bar_ver_noagg(
    list(reversed(list(t2['standardized']))),
    list(reversed(list(t2['price']))),
    "Artículos de Recursos Más Costosos",
    "#69efbc",
    800,
    400,
    100
)

# %% [markdown]
# > * Algunos de los artículos de recursos más caros en DonorsChoose son los **parques infantiles, como el Parque Infantil para Personas con Discapacidad** (*Handicapped Playground*), que con casi USD 100,000 es el artículo más costoso, seguido por la **Estructura Comercial Little Tikes** (*Little Tikes Commercial Structure*) y los **Gimnasios Telescópicos** (*Telescopic Gyms*).
#
# ## <a id="6.4">6.4 Proveedores famosos en DonorsChoose</a>

# %%
# Proveedores más destacados

# Proveedores con mayor cantidad de recursos solicitados
t = resources_df['Resource Vendor Name'].value_counts()

k = list(reversed(list(t.index)[:15]))
v = list(reversed(list(t.values)[:15]))

trace2 = bar_hor_noagg(
    k,
    v,
    "Proveedores con Mayor Cantidad de Recursos",
    "#4cc0ff",
    800,
    500,
    200,
    rt=True
)


# Calcular precio total por recurso
resources_df['total_price'] = (
    resources_df['Resource Quantity'] *
    resources_df['Resource Unit Price']
)


# Promedio del monto recibido por proveedor
tempdf = resources_df.groupby('Resource Vendor Name').agg({
    'total_price': 'mean'
}).reset_index()

tempdf = tempdf.sort_values(
    'total_price',
    ascending=False
)[:15]

trace1 = bar_hor_noagg(
    list(reversed(list(tempdf['Resource Vendor Name']))),
    list(reversed(list(tempdf['total_price']))),
    "Monto Promedio por Proyecto del Proveedor",
    "#c1e2f4",
    800,
    400,
    200,
    rt=True
)


# Crear subgráficos
fig = tools.make_subplots(
    rows=1,
    cols=2,
    print_grid=False,
    subplot_titles=[
        "Cantidad Total de Recursos por Proveedor",
        "Monto Promedio por Proyecto del Proveedor"
    ]
)

fig.append_trace(trace2, 1, 1)
fig.append_trace(trace1, 1, 2)

fig['layout'].update(
    height=600,
    showlegend=False,
    margin=dict(l=250),
    title="Análisis de los Proveedores de Recursos"
)

iplot(fig)

# %% [markdown]
# > * La mayoría de los recursos se solicitan a **Amazon Business, con 3.2 millones** de veces en las que se pidió un artículo de esta plataforma. Amazon Business es seguido por Lakeshore Learning Materials y AKJ Education.
# > * Al comparar el costo promedio recibido por un proveedor, **MakerBot** se sitúa en la cima, con un costo promedio recibido por proyecto de **USD 2,000**.
# > * **Best Buy Education** es otro de los proveedores populares entre los profesores y también cuenta con un precio promedio recibido significativamente alto por proyecto.
# <br>
#
# ## <a id="7">7. Exploración de Proyectos</a>
#
# Los datos de los proyectos consisten en todos los detalles sobre las propuestas publicadas, lo cual incluye el ID del profesor y de la escuela, el título, el tipo, la categoría, el costo, etc., de los proyectos. Echemos un vistazo al panorama general.
#
# ## <a id="7.1">7.1 Panorama de los Datos de Proyectos</a>

# %%
projects_df = pd.read_csv(path+"Projects.csv")
projects_df.head(3)
# Out:
#                          Project ID                         School ID  \
# 0  bdd640fb06671ad11c80317fa3b1799d  23b8c1e9392456de3eb13b9046685257
# 1  32e706298fadc1a606cb0fb39a1de644  8b8148f6b38a088ca65ed389b74d0fb1
# 2  d8f564135be6128e18c267976142ea7d  ce9ff57f43b7a3a69a8dca03580d7b71
#
#                          Teacher ID  Teacher Project Posted Sequence  \
# 0  bd9c66b3ad3c2d6d1a3d1fa7bc8960a9                                5
# 1  96da1dac72ff5d2a386ecbe06b65a6a4                                3
# 2  89463e85759cde66bacfb3d00b1f9163                                1
#
#   Project Type                 Project Title  \
# 0  Teacher-Led  Anti-Bullying Begins with Me
# 1  Teacher-Led  Anti-Bullying Begins with Me
# 2  Teacher-Led   Technology in the Classroom
#
#                                     Project Essay  \
# 0  Lorem ipsum dolor sit amet classroom school...
# 1  Lorem ipsum dolor sit amet classroom school...
# 2  Lorem ipsum dolor sit amet classroom school...
#
#            Project Subject Category Tree  \
# 0    Literacy & Language, Math & Science
# 1                       Music & The Arts
# 2  Applied Learning, Literacy & Language
#
#          Project Subject Subcategory Tree Project Grade Level Category  \
# 0  Applied Sciences, Literature & Writing                Grades PreK-2
# 1  Applied Sciences, Literature & Writing                   Grades 3-5
# 2                   Literacy, Mathematics                   Grades 3-5
#
#   Project Resource Category Project Cost Project Posted Date  \
# 0                     Books      $231.17          2014-04-22
# 1                Technology      $317.67          2014-11-21
# 2                     Trips     $1339.63          2015-01-11
#
#   Project Current Status Project Fully Funded Date
# 0                   Live                       NaN
# 1           Fully Funded                2014-12-01
# 2                   Live                       NaN

# %% [markdown]
# ## <a id="7.2"> 7.2 ¿Cuáles son las Categorías, Subcategorías y Categorías de Recursos más frecuentes en los proyectos publicados? </a>

# %%
# Crear características de fecha y hora de los proyectos

projects_df['Posted Date'] = pd.to_datetime(projects_df['Project Posted Date'])

projects_df['Posted Year'] = projects_df['Posted Date'].dt.year
projects_df['Posted Month'] = projects_df['Posted Date'].dt.month
projects_df['Posted Day'] = projects_df['Posted Date'].dt.weekday
projects_df['Posted Quarter'] = projects_df['Posted Date'].dt.quarter

projects_df['Funded Date'] = pd.to_datetime(projects_df['Project Fully Funded Date'])

projects_df['Funded Year'] = projects_df['Funded Date'].dt.year
projects_df['Funded Month'] = projects_df['Funded Date'].dt.month
projects_df['Funded Day'] = projects_df['Funded Date'].dt.weekday
projects_df['Funded Quarter'] = projects_df['Funded Date'].dt.quarter

projects_df['Funding Time'] = (
    projects_df['Funded Date'] -
    projects_df['Posted Date']
)


# Categorías principales de proyectos
t = projects_df['Project Subject Category Tree'].value_counts()

x = list(t.index)
y = list(t.values)

r = {}

for i, val in enumerate(x):
    for each in val.split(","):
        x1 = each.strip()
        if x1 not in r:
            r[x1] = y[i]
        r[x1] += y[i]

sorted_x = list(
    sorted(
        r.items(),
        key=operator.itemgetter(1),
        reverse=True
    )
)[:10]

x1 = [a[0] for a in sorted_x][::-1]
y1 = [a[1] for a in sorted_x][::-1]


# Subcategorías de proyectos
t1 = projects_df['Project Subject Subcategory Tree'].value_counts()

x2 = list(t1.index)
y2 = list(t1.values)

r = {}

for i, val in enumerate(x2):
    for each in val.split(","):
        x1_ = each.strip()
        if x1_ not in r:
            r[x1_] = y2[i]
        r[x1_] += y2[i]

sorted_x = list(
    sorted(
        r.items(),
        key=operator.itemgetter(1),
        reverse=True
    )
)[:10]

x2 = [a[0] for a in sorted_x][::-1]
y2 = [a[1] for a in sorted_x][::-1]


# Categorías de recursos
t = projects_df['Project Resource Category'].value_counts()

x3 = list(t.index[::-1])[:10]
y3 = list(t.values[::-1])[:10]


# Crear gráficos
trace1 = bar_hor_noagg(
    x1,
    y1,
    "",
    "#8cf2a9",
    600,
    400,
    10,
    rt=True
)

trace2 = bar_hor_noagg(
    x2,
    y2,
    "",
    "#8cf2a9",
    600,
    400,
    10,
    rt=True
)

trace3 = bar_hor_noagg(
    x3,
    y3,
    "",
    "#8cf2a9",
    600,
    400,
    10,
    rt=True
)


# Crear subgráficos
fig = tools.make_subplots(
    rows=1,
    cols=5,
    print_grid=False,
    subplot_titles=[
        'Categorías de Proyectos',
        "",
        'Subcategorías de Proyectos',
        "",
        'Categorías de Recursos'
    ]
)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 3)
fig.append_trace(trace3, 1, 5)

fig['layout'].update(
    height=400,
    showlegend=False,
    margin=dict(l=120),
    title="Distribución de Categorías y Recursos de Proyectos"
)

iplot(fig)

# %% [markdown]
# > Una gran mayoría de los proyectos (más de 800K) pertenecen a la categoría principal de **Alfabetización e Idiomas** (*Literacy and Language*). **Matemáticas y Ciencias** (*Math and Science*) es la segunda categoría más famosa. En comparación, se ha publicado un número significativamente menor de proyectos sobre Cuidado y Hambruna (*Care and Hunger*) desde 2013.
# >
# > Entre las subcategorías, Alfabetización (*Literacy*), Matemáticas (*Mathematics*) y Escritura (*Writing*) son las subcategorías más comunes en los proyectos publicados por los profesores, mientras que se registra un menor número de proyectos bajo la categoría de Desarrollo Temprano y Salud.
# > **Tecnología Educativa** (*Instructional Technology*), **Rincones de Lectura** (*Reading Nooks*), **Escritorios y Almacenamiento** (*Desks and Storage*) son las categorías clave de recursos solicitados por los docentes.
#
# ## <a id="7.3">7.3 ¿Cuál es la distribución del Tipo de Proyecto y el Estado Actual del Proyecto?</a>

# %%
# Distribución del tipo y estado actual de los proyectos

# 1. Preparar los datos limpios
t_type = projects_df['Project Type'].value_counts()
t_status = projects_df['Project Current Status'].value_counts()


# 2. Crear la cuadrícula de subplots para gráficos tipo Pie/Donut (1 fila, 2 columnas)
fig = make_subplots(
    rows=1,
    cols=2,
    specs=[[{'type': 'domain'}, {'type': 'domain'}]],
    subplot_titles=[
        'Tipo de Proyecto',
        'Estado Actual del Proyecto'
    ]
)


# 3. Agregar la primera dona (Tipo de Proyecto)
fig.add_trace(
    go.Pie(
        labels=t_type.index,
        values=t_type.values,
        hole=0.7,
        marker=dict(
            colors=["#f77b9c", '#ab97db', '#b0b1b2']
        ),
        name="Tipo",
        hoverinfo="label+percent+name"
    ),
    row=1,
    col=1
)


# 4. Agregar la segunda dona (Estado del Proyecto)
fig.add_trace(
    go.Pie(
        labels=t_status.index,
        values=t_status.values,
        hole=0.7,
        marker=dict(
            colors=["#efbc56", "#81a7e8", "#e295d0"]
        ),
        name="Estado",
        hoverinfo="label+percent+name"
    ),
    row=1,
    col=2
)


# 5. Configurar el diseño y textos centrales de las donas
fig.update_layout(
    title_text="Distribución del Tipo de Proyecto y Estado Actual",
    title_x=0.5,
    showlegend=True,
    height=450,
    annotations=[
        {
            "font": {
                "size": 18,
                "color": "black"
            },
            "showarrow": False,
            "text": "Tipo",
            "x": 0.20,
            "y": 0.5
        },
        {
            "font": {
                "size": 18,
                "color": "black"
            },
            "showarrow": False,
            "text": "Estado",
            "x": 0.80,
            "y": 0.5
        }
    ]
)


# Mostrar el gráfico interactivo
fig.show()

# %% [markdown]
# > Aparte de los proyectos liderados por profesores (que son los dominantes), un número significativamente menor de proyectos son publicados por estudiantes o por servicios de desarrollo profesional. Los datos muestran que cerca del 75% de todos los proyectos publicados han sido completamente financiados, mientras que el 21% de ellos han expirado. Hasta mayo de 2018, cerca de 42K proyectos se encuentran activos en DonorsChoose.
#
# ## <a id="7.4">7.4 ¿En qué días se publicaron y financiaron la mayor cantidad de proyectos?</a>

# %%
# Distribución de días de publicación y financiación de proyectos

t1 = projects_df['Posted Day'].value_counts()
t2 = projects_df['Funded Day'].value_counts()

mapp = {
    0: 'Dom',
    1: 'Lun',
    2: 'Mar',
    3: 'Mié',
    4: 'Jue',
    5: 'Vie',
    6: 'Sáb'
}

values1 = t1.values
index1 = t1.index
index1 = [mapp[x] for x in index1]


values2 = t2.values
index2 = t2.index
index2 = [mapp[x] for x in index2]

tmap = {}

for j, b in enumerate(index2):
    tmap[b] = values2[j]

values2_c = [tmap[c] for c in index1]


domain1 = {'x': [0.2, 0.50], 'y': [0.0, 0.33]}
domain2 = {'x': [0.8, 0.50], 'y': [0.0, 0.33]}


fig = {
    "data": [
        {
            "values": values1,
            "labels": index1,
            "domain": {"x": [0, .48]},
            "marker": dict(
                colors=[
                    "#f77b9c",
                    "#ab97db",
                    "#b0b1b2",
                    "#efbc56",
                    "#81a7e8",
                    "#e295d0"
                ]
            ),
            "name": "Día de Publicación",
            "hoverinfo": "label+percent+name",
            "hole": .7,
            "type": "pie"
        },
        {
            "values": values2_c,
            "labels": index1,
            "marker": dict(
                colors=[
                    "#f77b9c",
                    "#ab97db",
                    "#b0b1b2",
                    "#efbc56",
                    "#81a7e8",
                    "#e295d0"
                ]
            ),
            "domain": {"x": [.52, 1]},
            "textposition": "inside",
            "name": "Día de Financiación",
            "hole": .7,
            "type": "pie"
        }
    ],
    "layout": {
        "title": "Distribución de Días de Publicación y Financiación de Proyectos",
        "annotations": [
            {
                "font": {
                    "size": 20
                },
                "showarrow": False,
                "text": "Día de Publicación",
                "x": 0.17,
                "y": 0.5
            },
            {
                "font": {
                    "size": 20
                },
                "showarrow": False,
                "text": "Día de Financiación",
                "x": 0.83,
                "y": 0.5
            }
        ]
    }
}

iplot(fig, filename='donut')

# %% [markdown]
# > Los profesores generalmente han publicado sus proyectos durante los días de fin de semana: viernes (16%), sábados (16%) y domingos (17%). Por otro lado, los lunes se registra la mayor cantidad de proyectos financiados y cerrados.
#
# ## <a id="7.5">7.5 ¿En qué trimestres se publican y financian los proyectos?</a>

# %%
# Distribución de trimestres de publicación y financiación de proyectos

t1 = projects_df['Posted Quarter'].value_counts()
t2 = projects_df['Funded Quarter'].value_counts()

mappq = {
    1.0: 'Trimestre 1',
    2.0: 'Trimestre 2',
    3.0: 'Trimestre 3',
    4.0: 'Trimestre 4'
}

values1 = t1.values
index1 = t1.index
index1 = [mappq[x] for x in index1]


values2 = t2.values
index2 = t2.index
index2 = [mappq[x] for x in index2]

tmap = {}

for j, b in enumerate(index2):
    tmap[b] = values2[j]

values2_c = [tmap[c] for c in index1]


domain1 = {'x': [0.2, 0.50], 'y': [0.0, 0.33]}
domain2 = {'x': [0.8, 0.50], 'y': [0.0, 0.33]}


fig = {
    "data": [
        {
            "values": values1,
            "labels": index1,
            "domain": {"x": [0, .48]},
            "marker": dict(
                colors=[
                    "#f77b9c",
                    "#ab97db",
                    "#b0b1b2",
                    "#efbc56",
                    "#81a7e8",
                    "#e295d0"
                ]
            ),
            "name": "Publicación por Trimestre",
            "hole": .7,
            "type": "pie"
        },
        {
            "values": values2_c,
            "labels": index1,
            "marker": dict(
                colors=[
                    "#f77b9c",
                    "#ab97db",
                    "#b0b1b2",
                    "#efbc56",
                    "#81a7e8",
                    "#e295d0"
                ]
            ),
            "domain": {"x": [.52, 1]},
            "textposition": "inside",
            "name": "Financiación por Trimestre",
            "hole": .7,
            "type": "pie"
        }
    ],
    "layout": {
        "title": "Distribución de Proyectos por Trimestre de Publicación y Financiación",
        "annotations": [
            {
                "font": {
                    "size": 20
                },
                "showarrow": False,
                "text": "Publicados",
                "x": 0.2,
                "y": 0.5
            },
            {
                "font": {
                    "size": 20
                },
                "showarrow": False,
                "text": "Financiados",
                "x": 0.8,
                "y": 0.5
            }
        ]
    }
}

iplot(fig, filename='donut')

# %% [markdown]
# > El Trimestre 3 (Q3), es decir, julio, agosto y septiembre, es el período en el que los profesores publican la mayor cantidad de proyectos, y de la misma manera ocurre en el trimestre inmediatamente posterior, es decir, el Trimestre 4 (Q4), cuando la mayoría de los proyectos son financiados y cerrados.
#
# ## <a id="7.6">7.6 ¿En qué meses se publicaron los proyectos?</a>

# %%
# Distribución de proyectos publicados por mes

t = projects_df['Posted Month'].value_counts()

lObjectsALLcnts = list(t.values)

lObjectsALLlbls = list(t.index)

mapp1 = {
    1: 'Ene',
    2: 'Feb',
    3: 'Mar',
    4: 'Abr',
    5: 'May',
    6: 'Jun',
    7: 'Jul',
    8: 'Ago',
    9: 'Sep',
    10: 'Oct',
    11: 'Nov',
    12: 'Dic'
}

lObjectsALLlbls = [mapp1[x] for x in lObjectsALLlbls]


iN = len(lObjectsALLcnts)

arrCnts = np.array(lObjectsALLcnts)

theta = np.arange(
    0,
    2 * np.pi,
    2 * np.pi / iN
)

width = (2 * np.pi) / iN * 0.5

bottom = 50


fig = plt.figure(figsize=(8, 8))

ax = fig.add_axes(
    [0.2, 0.1, 1, 0.9],
    polar=True
)

fig.suptitle(
    'Mes de Publicación de Proyectos',
    fontsize=16
)

bars = ax.bar(
    theta,
    arrCnts,
    width=width,
    bottom=bottom,
    color='#f3a0f7'
)

plt.axis('off')


rotations = np.rad2deg(theta)

for x, bar, rotation, label in zip(
    theta,
    bars,
    rotations,
    lObjectsALLlbls
):
    lab = ax.text(
        x,
        bottom + bar.get_height(),
        label,
        ha='left',
        va='center',
        rotation=rotation,
        rotation_mode="anchor"
    )


plt.show()

# %% [markdown]
# > En el Trimestre 3 (Q3), la mayor cantidad de proyectos se publicaron en el mes de septiembre, seguido por agosto. El menor número de proyectos se publicó en el mes de junio.
#
# ## <a id="7.7">7.7 ¿En qué año se publicaron los proyectos?</a>

# %%
t = projects_df.groupby('Posted Year').agg({'Posted Month' : 'count'}).reset_index()
t = t.sort_values('Posted Year')
trace2 = bar_ver_noagg(t['Posted Year'], t['Posted Month'], "", "#9887ed", None, 400, 0)

# %% [markdown]
# > El número de proyectos en DonorsChoose ha aumentado constantemente durante los últimos 5 años. Cerca de 300K proyectos fueron publicados en 2017.
#
# ## <a id="7.8">7.8 ¿En qué año y mes el costo de los proyectos es más alto?</a>

# %%
year_tab = pd.crosstab(projects_df["Project Current Status"], projects_df["Posted Year"]).reset_index()
from itertools import zip_longest
projects_df['cost'] = projects_df['Project Cost'].apply(lambda x : float(str(x).replace(",","").replace("$","")))

def cbp(df, col1, col2, aggcol, func, title, cs, bottom_margin=None):
    tempdf = df.groupby([col1, col2]).agg({aggcol : func}).reset_index()
    tempdf[aggcol] = tempdf[aggcol].apply(lambda x : int(x))
    tempdf = tempdf.sort_values(aggcol, ascending=False)

    sizes = list(reversed([i for i in range(10,31)]))
    intervals = int(len(tempdf) / len(sizes))
    size_array = [9]*len(tempdf)
    
    st = 0
    for i, size in enumerate(sizes):
        for j in range(st, st+intervals):
            size_array[j] = size 
        st = st+intervals
    tempdf['size_n'] = size_array
    # tempdf = tempdf.sample(frac=1).reset_index(drop=True)

    cols = list(tempdf['size_n'])

    trace1 = go.Scatter( x=tempdf[col1], y=tempdf[col2], mode='markers', text=tempdf[aggcol],
        marker=dict( size=tempdf.size_n, color=cols, colorscale=cs ))
    data = [trace1]
    if bottom_margin:
        layout = go.Layout(title=title, margin=dict(b=150))
    else:
        layout = go.Layout(title=title)
    fig = go.Figure(data=data, layout=layout)
    iplot(fig)

cbp(projects_df, 'Posted Month', 'Posted Year', 'cost', 'mean', '', 'Picnic')

# %% [markdown]
# > * Septiembre de 2014 registró una gran cantidad de proyectos publicados con un costo promedio elevado. En 2015, los meses de abril, mayo, septiembre y octubre concentraron los proyectos con los costos totales más altos.
#
# ## <a id="7.9">7.9 ¿En qué año y categoría de grado escolar el costo de los proyectos es más alto?</a>

# %%
cbp(projects_df, 'Project Grade Level Category', 'Posted Year', 'cost', 'mean', '', 'Earth')

# %% [markdown]
# > Para los grados 6-8 (*Grade 6-8*) y de los grados 9-12 (*Grades 9-12*), los proyectos con los costos más altos se registraron en el año 2015; mientras que para los grados 3-5 (*Grade 3-5*) y de preescolar a segundo de primaria (*Grade PreK-2*), se presentaron en 2014.
#
# ## <a id="7.10">7.10 Categorías de Grado Escolar y Categorías de Recursos con los costos de proyecto más altos</a>

# %%
cbp(projects_df, 'Project Resource Category', 'Project Grade Level Category', 'cost', 'mean', '', 'Picnic', bottom_margin=150)

# %% [markdown]
# > * Los **viajes** (*Trips*) se organizan principalmente para los grados superiores, es decir, de 9-12, seguidos por los grados 6-8 y luego de 3-5. El nivel de preescolar a segundo de primaria (*Grades PreK-2*) registra una cantidad significativamente menor en comparación con los demás grados. Los **visitantes** (*Visitors*) son otro recurso clave para todos los niveles escolares.
#
# ## <a id="7.11">7.11 ¿Cómo varía el Estado del Proyecto según el Año?</a>

# %%
# 1. Asegurar la orientación correcta de los datos
# Si los años están en las columnas, los extraemos directamente.
# Si están en el índice, transponemos la tabla para que este código funcione siempre.

if "Project Current Status" in year_tab.columns:
    df_plot = year_tab.set_index("Project Current Status")
else:
    df_plot = year_tab.copy()

# Los años reales serán las columnas resultantes (ej. 2013, 2014, etc.)
years = list(df_plot.columns)

# 2. Configurar el lienzo (2 filas x 3 columnas)
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

# 3. Dibujar los gráficos de pastel para los años existentes
for j, year in enumerate(years):
    axes[j].pie(
        df_plot[year], 
        labels=df_plot.index.tolist(),
        autopct="%1.0f%%", 
        colors=["#ff8ce0", "#9bf46b", "#4cdfef"],
        wedgeprops={"linewidth": 1, "edgecolor": "white"}
    )
    axes[j].set_title(str(year))

# 4. SOLUCIÓN AL CUADRO VACÍO: Ocultar los subplots que no se usen
for k in range(len(years), len(axes)):
    axes[k].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# > Un análisis año tras año de los datos muestra que **alrededor del 70% del total de proyectos** publicados en DonorsChoose en un año son completamente financiados. Ha habido una tendencia creciente en el porcentaje de proyectos totalmente financiados por año, **excepto en 2016**, cuando el número de proyectos financiados disminuyó un 6% en comparación con el año anterior. 2017 y 2015 fueron los mejores años en términos de la tasa de proyectos completamente financiados, alcanzando aproximadamente un **78% de éxito**.
#
# ## <a id="7.12">7.12 ¿Durante cuántos días permanecieron activos los proyectos?</a>

# %%
t = projects_df[projects_df['Project Current Status'] == "Fully Funded"]

t['Funding Time'] = t['Funding Time'].apply(
    lambda x: int(str(x).split()[0])
)

plt.figure(figsize=(12,4))

ax = t['Funding Time'].hist(
    bins=25,
    edgecolor='white',
    color="#e770f9"
)

ax.grid(False)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.xlabel('Número de Días')

plt.title(
    'Tiempo de Finalización de Proyectos Totalmente Financiados'
)

plt.show()

# %% [markdown]
# > * Una gran cantidad de los proyectos tienen un tiempo de finalización menor a 3 días. Alrededor de **"55,000 proyectos"** en el pasado fueron financiados con éxito en un solo día, mientras que cerca de **"48,627 proyectos"** se cerraron el mismo día en que fueron publicados. El número más alto de días para cualquier proyecto es igual a 288 días, el cual correspondió al proyecto titulado "**Empty Bowls, Full Hearts**" (*Sopes Vacíos, Corazones Llenos*). Este proyecto tenía un costo estimado de USD 1,982 y fue publicado por la **Escuela Primaria Harrison Park** (*Harrison Park Elementary School*) en Michigan.
#
# ## <a id="7.13">7.13 ¿Cómo varía la proporción de proyectos Financiados vs No Financiados por Estado?</a>

# %%
projsch_df = projects_df.merge(schools_df, on="School ID")
states = [u'California', u'Texas', u'New York', u'Florida', u'North Carolina',
       u'Illinois', u'Georgia', u'South Carolina', u'Michigan',
       u'Pennsylvania', u'Massachusetts', u'Indiana', u'Oklahoma',
       u'Washington', u'Ohio', u'New Jersey', u'Missouri', u'Arizona',
       u'Virginia', u'Louisiana', u'Tennessee', u'Utah', u'Wisconsin',
       u'Connecticut', u'Alabama', u'Maryland', u'Nevada', u'Oregon',
       u'Colorado', u'Mississippi', u'Minnesota', u'Kentucky', u'Arkansas',
       u'Hawaii', u'Idaho', u'Maine', u'Kansas', u'Iowa',
        u'New Mexico', u'West Virginia', u'Alaska',
       u'New Hampshire', u'Delaware', u'Rhode Island', u'Nebraska',
       u'South Dakota', u'Montana', u'North Dakota', u'Vermont', u'Wyoming'][:30]

length = len(states)
plt.figure(figsize=(18, 24))

for i, j in itertools.zip_longest(states, range(length)):
    if i is None:
        continue
        
    plt.subplot(5, 6, j + 1) # Cambiado a 5x6 para que los 30 estados queden simétricos
    
    # Obtener el conteo de estatus para el estado actual
    status_counts = projsch_df[projsch_df['School State'] == i]['Project Current Status'].value_counts()
    t = dict(status_counts)

    # SOLÚCIÓN: Usar .get() con valor por defecto 0 para evitar el KeyError
    fully_funded = t.get('Fully Funded', 0)
    not_funded = t.get('Expired', 0)
    
    total = fully_funded + not_funded
    
    # Evitar división por cero si un estado no tiene proyectos válidos en el dataset
    if total > 0:
        t1 = {
            'Funded': float(fully_funded) * 100 / total, 
            'Not Funded': float(not_funded) * 100 / total
        }
    else:
        t1 = {'Funded': 0.0, 'Not Funded': 0.0}

    # Ajuste de sintaxis moderna para Seaborn asignando x e y de forma explícita
    ax = sns.barplot(x=list(t1.keys()), y=list(t1.values()), alpha=.7, palette='cool')
    ax.grid(False)
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    # Reducimos los límites fijos del eje Y al 100% para mantener consistencia visual
    ax.set_ylim(0, 100) 
    
    plt.subplots_adjust(wspace=0.6, hspace=0.8)
    plt.title(i, color="black", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# > * Algunos de los estados donde el porcentaje de proyectos expirados o no financiados es menor son "Georgia", "South Carolina" y "Mississippi".
#
# ## <a id="7.14">7.14 ¿Cuál es el Costo Promedio de los Proyectos según el Tipo de Zona Escolar (Metro Type) y la categoría del Recurso Solicitado?</a>

# %%
cbp(projsch_df, 'Project Resource Category', 'School Metro Type', 'cost', 'mean', '', 'Rainbow', bottom_margin = 150)

# %% [markdown]
# > * Los viajes (*Trips*) y los visitantes (*Visitors*) son siempre las categorías más costosas entre todos los diferentes tipos de zonas escolares (*School Metro Types*). Las zonas catalogadas como pueblos ("Towns") registran el costo promedio máximo en aquellos proyectos donde se solicitaron recursos pertenecientes a equipos de deportes y ejercicio (*Sports and Exercise Equipments*).
#
# ## <a id="7.15">7.15 ¿Cuál es el Costo Promedio de los Proyectos según el Tipo de Zona Escolar (Metro Type) y la Categoría de Grado Escolar?</a>

# %%
cbp(projsch_df, 'Project Grade Level Category', 'School Metro Type', 'cost', 'mean', '', 'Rainbow')

# %% [markdown]
# > * Los grados de 9-12 (*Grades 9-12*) presentan el costo promedio de proyecto más alto en comparación con cualquier otra categoría de grado escolar. Entre ellos, las zonas suburbanas (*SubUrban*) tienen los precios de proyecto más elevados, mientras que los pueblos (*towns*) registran los más bajos.
#
# ## <a id="8">8. Procesamiento de Lenguaje Natural para el Perfilado de Proyectos</a>
#
# Se puede obtener un gran nivel de comprensión mediante el análisis de texto de los ensayos de los proyectos (*Project Essays*). Vamos a realizar un análisis de texto básico / procesamiento de lenguaje natural con el fin de extraer información relevante de dichos ensayos. Para este propósito, me enfocaré en un subconjunto de proyectos recientes de abril de 2018.
#
# ## <a id="8.1">8.1 Limpieza de Texto</a>
#
# Escribe una función utilitaria que normalice el texto y elimine el ruido. Esta función de limpieza de texto se encarga de remover las palabras vacías (*stopwords*) y los signos de puntuación del texto.

# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PC-22\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: nltk>=3.9 in c:\users\pc-22\anaconda3\lib\site-packages (from textblob) (3.9.2)
# Requirement already satisfied: click in c:\users\pc-22\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in c:\users\pc-22\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pc-22\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\pc-22\anaconda3\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\pc-22\anaconda3\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.20.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 625.0/625.0 kB 4.5 MB/s  0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.20.0

# %%
from nltk.corpus import stopwords 
from textblob import TextBlob
import string 

stopwords = stopwords.words("english")

def _clean(txt):
    # lower case
    txt = txt.lower()

    # punctuation removal 
    txt = ''.join(x for x in txt if x not in string.punctuation)

    # stopwords and lemmatization
    clean_txt = ""
    for word in txt.split():
        if word in stopwords:
            continue 
        clean_txt += " "
        clean_txt += word 
    
    noise = ['students','my','title', 'would', 'every', 'will', 'many','also','donotremoveessaydivider']
    for ns in noise:
        clean_txt = clean_txt.replace(ns, "")

    return clean_txt

projects_df = projects_df.merge(schools_df, on='School ID', how='inner')
april18_df = projects_df[(projects_df['Posted Year'] == 2018) & (projects_df['Posted Month'] == 4)]
april18_df['clean_essay'] = april18_df['Project Essay'].apply(_clean)

# %%
projects_df.columns.tolist()
# Out:
# ['Project ID',
#  'School ID',
#  'Teacher ID',
#  'Teacher Project Posted Sequence',
#  'Project Type',
#  'Project Title',
#  'Project Essay',
#  'Project Subject Category Tree',
#  'Project Subject Subcategory Tree',
#  'Project Grade Level Category',
#  'Project Resource Category',
#  'Project Cost',
#  'Project Posted Date',
#  'Project Current Status',
#  'Project Fully Funded Date',
#  'Posted Date',
#  'Posted Year',
#  'Posted Month',
#  'Posted Day',
#  'Posted Quarter',
#  'Funded Date',
#  'Funded Year',
#  'Funded Month',
#  'Funded Day',
#  'Funded Quarter',
#  'Funding Time',
#  'cost',
#  'School Name',
#  'School Metro Type',
#  'School Percentage Free Lunch',
#  'School State',
#  'School Zip',
#  'School City',
#  'School County',
#  'School District']

# %% [markdown]
# ## <a id="8.2">8.2 Análisis de Bolsa de Palabras (Bag of Words)</a>
#
# ## <a id="8.2.1">8.2.1 ¿Cuáles son las palabras y frases más utilizadas por los profesores en los ensayos?</a>

# %%
### Bolsa de Palabras (Bag of Words)

from collections import Counter

def generate_ngrams(txt, N):
    grams = [txt[i:i+N] for i in range(len(txt)-N+1)]
    grams = [" ".join(b) for b in grams]
    return grams 


april18_df['unigrams'] = april18_df['clean_essay'].apply(
    lambda x: generate_ngrams(x.split(), 1)
)

april18_df['bigrams'] = april18_df['clean_essay'].apply(
    lambda x: generate_ngrams(x.split(), 2)
)

april18_df['trigrams'] = april18_df['clean_essay'].apply(
    lambda x: generate_ngrams(x.split(), 3)
)


# Unigramas
all_unigrams = []

for each in april18_df['unigrams']:
    all_unigrams.extend(each)

t = Counter(all_unigrams).most_common(25)

x = [a[0] for a in t]
y = [a[1] for a in t]


# Bigramas
all_bigrams = []

for each in april18_df['bigrams']:
    all_bigrams.extend(each)

t1 = Counter(all_bigrams).most_common(25)

x1 = [a[0] for a in t1]
y1 = [a[1] for a in t1]


# Trigramas
all_trigrams = []

for each in april18_df['trigrams']:
    all_trigrams.extend(each)

t2 = Counter(all_trigrams).most_common(25)

x2 = [a[0] for a in t2]
y2 = [a[1] for a in t2]


sns.set_style("dark")

fig, axes = plt.subplots(
    nrows=1,
    ncols=5,
    squeeze=True,
    figsize=(12,10)
)


bar = sns.barplot(
    y=x,
    x=y,
    ax=axes[0],
    palette='GnBu_d',
    edgecolor="white"
)

bar.set(
    xlabel='',
    xticks=[]
)

axes[0].set_title(
    "Palabras Clave Más Usadas por Profesores"
)


fig.delaxes(axes[1])


bar1 = sns.barplot(
    y=x1,
    x=y1,
    ax=axes[2],
    palette='GnBu_d',
    edgecolor="white"
)

bar1.set(
    xlabel='',
    xticks=[]
)

axes[2].set_title(
    "Bigramas Más Usados por Profesores"
)


fig.delaxes(axes[3])


bar1 = sns.barplot(
    y=x2,
    x=y2,
    ax=axes[4],
    palette='GnBu_d',
    edgecolor="white"
)

bar1.set(
    xlabel='',
    xticks=[]
)

axes[4].set_title(
    "Trigramas Más Usados por Profesores"
)
# Out:
# Text(0.5, 1.0, 'Trigramas Más Usados por Profesores')

# %% [markdown]
# > * Las palabras clave más utilizadas en todos los ensayos, estados y tipos de escuela son **"school"** (escuela), **"learning"** (aprendizaje), **"classroom"** (aula) y **"reading"** (lectura). Por otro lado, los bigramas incluyen un enfoque principal en **"flexible seating"** (asientos adaptables/flexibles) y **"english language"** (idioma inglés). Una gran cantidad de los ensayos de los profesores tratan sobre **"Free Breakfast and Lunch"** (desayuno y almuerzo gratuitos), **"learning english language"** (aprendizaje del idioma inglés) y **"several challenges faced"** (diversos desafíos enfrentados).
#
# ## <a id="8.2.2">8.2.2 ¿Cómo varían las frases más utilizadas según el Estado?</a>

# %%
ignores = ['every day', 'come school']
all_unigrams = []
for each in april18_df[april18_df['School State'] == 'California']['trigrams']:
    all_unigrams.extend([x for x in each if x not in ignores])
t = Counter(all_unigrams).most_common(15)
x = [a[0] for a in t]
y = [a[1] for a in t]

all_bigrams = []
april18_df['School State_x' == 'Georgia']['trigrams']:
    all_bigrams.extend([x for x in each if x not in ignores])
t1 = Counter(all_bigrams).most_common(15)
x1 = [a[0] for a in t1]
y1 = [a[1] for a in t1]

all_trigrams = []
for each in april18_df[april18_df['School State'] == 'Florida']['trigrams']:
    all_trigrams.extend([x for x in each if x not in ignores])
t2 = Counter(all_trigrams).most_common(15)
x2 = [a[0] for a in t2]
y2 = [a[1] for a in t2]

sns.set_style("dark")
fig, axes = plt.subplots(nrows=1, ncols=5, squeeze=True, figsize = (12,6));

bar = sns.barplot(y=x, x=y, ax=axes[0], palette='GnBu_d', edgecolor="white");
bar.set(xlabel='', xticks=[]);
axes[0].set_title("Top used Phrases - California");

fig.delaxes(axes[1]);

bar1 = sns.barplot(y=x1, x=y1, ax=axes[2], palette='GnBu_d', edgecolor="white");
bar1.set(xlabel='', xticks=[]);
axes[2].set_title("Top used Phrases - Georgia");

fig.delaxes(axes[3]);

bar1 = sns.barplot(y=x2, x=y2, ax=axes[4], palette='GnBu_d', edgecolor="white");
bar1.set(xlabel='', xticks=[]);
axes[4].set_title("Top used Phrases - Florida");

all_unigrams = []
for each in april18_df[april18_df['School State'] == 'Iowa']['trigrams']:
    all_unigrams.extend([x for x in each if x not in ignores])
t = Counter(all_unigrams).most_common(15)
x = [a[0] for a in t]
y = [a[1] for a in t]

all_bigrams = []
for each in april18_df[april18_df['School State'] == 'New York']['trigrams']:
    all_bigrams.extend([x for x in each if x not in ignores])
t1 = Counter(all_bigrams).most_common(15)
x1 = [a[0] for a in t1]
y1 = [a[1] for a in t1]

all_trigrams = []
for each in april18_df[april18_df['School State'] == 'Texas']['trigrams']:
    all_trigrams.extend([x for x in each if x not in ignores])
t2 = Counter(all_trigrams).most_common(15)
x2 = [a[0] for a in t2]
y2 = [a[1] for a in t2]

sns.set_style("dark")
fig, axes = plt.subplots(nrows=1, ncols=5, squeeze=True, figsize = (12,6));

bar = sns.barplot(y=x, x=y, ax=axes[0], palette='GnBu_d', edgecolor="white");
bar.set(xlabel='', xticks=[]);
axes[0].set_title("Top used Phrases - Iowa");

fig.delaxes(axes[1]);

bar1 = sns.barplot(y=x1, x=y1, ax=axes[2], palette='GnBu_d', edgecolor="white");
bar1.set(xlabel='', xticks=[]);
axes[2].set_title("Top used Phrases - New York");

fig.delaxes(axes[3]);

bar1 = sns.barplot(y=x2, x=y2, ax=axes[4], palette='GnBu_d', edgecolor="white");
bar1.set(xlabel='', xticks=[]);
axes[4].set_title("Top used Phrases - Texas");
# Out:
#   Cell In[120], line 10
#     april18_df['School State_x' == 'Georgia']['trigrams']:
#                                                           ^
# SyntaxError: invalid syntax

# %%
april18_df.columns.tolist()
# Out:
# ['Project ID',
#  'School ID',
#  'Teacher ID',
#  'Teacher Project Posted Sequence',
#  'Project Type',
#  'Project Title',
#  'Project Essay',
#  'Project Subject Category Tree',
#  'Project Subject Subcategory Tree',
#  'Project Grade Level Category',
#  'Project Resource Category',
#  'Project Cost',
#  'Project Posted Date',
#  'Project Current Status',
#  'Project Fully Funded Date',
#  'Posted Date',
#  'Posted Year',
#  'Posted Month',
#  'Posted Day',
#  'Posted Quarter',
#  'Funded Date',
#  'Funded Year',
#  'Funded Month',
#  'Funded Day',
#  'Funded Quarter',
#  'Funding Time',
#  'cost',
#  'School Name_x',
#  'School Metro Type_x',
#  'School Percentage Free Lunch_x',
#  'School State_x',
#  'School Zip_x',
#  'School City_x',
#  'School County_x',
#  'School District_x',
#  'School Name_y',
#  'School Metro Type_y',
#  'School Percentage Free Lunch_y',
#  'School State_y',
#  'School Zip_y',
#  'School City_y',
#  'School County_y',
#  'School District_y',
#  'clean_essay',
#  'unigrams',
#  'bigrams',
#  'trigrams']

# %% [markdown]
# > * El enfoque principal de los ensayos en los diferentes estados es prácticamente el mismo, aunque se observan algunas diferencias en estados como Texas, donde una gran cantidad de ensayos tratan sobre **estudiantes afectados por el Huracán Harvey**. Los profesores describieron los "diversos desafíos enfrentados" (*several challenges faced*) por los alumnos. Por su parte, las **"Opciones de Asientos Flexibles"** (*Flexible Seating Options*) constituyen el foco principal en la mayoría de los ensayos.
# > * En Iowa, los profesores describieron que cuentan con **"estudiantes provenientes de diferentes orígenes"** y **"diferentes nacionalidades"**. En Nueva York, los ensayos también se centran en **"profesores de educación especial"** (*special education teachers*), **"escuelas en distritos de pobreza"** (*poverty district schools*) y **"bajos ingresos"** (*low income*).
# > * En Florida, los profesores hicieron mención de los **"precios reducidos de desayuno y almuerzo"**.
#
# ## <a id="8.2.3">8.2.3 "<i>Mis estudiantes son ______ ______ ______</i>" : Qué describen los profesores sobre sus alumnos</a>

# %%
from textblob import TextBlob, Word
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
mask = np.array(Image.open('../input/word-cloud-masks/cloud1.png'))

mystudents = []
for x in april18_df['Project Essay']:
    if x.lower().startswith("my students are"):
        phrase = " ".join(x.replace('My students are', '').split(". ")[0].split("!")[0].strip().split()[:6])
        mystudents.append(phrase)

t3 = Counter(mystudents).most_common(25)
x = [a[0] for a in t3]
y = [a[1] for a in t3]

sns.set_style("dark")
plt.figure(figsize = (12,10))
plt.title("Context of My Students Are ___ ___ ___ ");
bar = sns.barplot(y=x, x=y, palette="BuGn_r", edgecolor="white");
bar.set(xlabel='', xticks=[]);
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[122], line 4
#       2 from wordcloud import WordCloud, STOPWORDS
#       3 from PIL import Image
# ----> 4 mask = np.array(Image.open('../input/word-cloud-masks/cloud1.png'))
#       6 mystudents = []
#       7 for x in april18_df['Project Essay']:
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../input/word-cloud-masks/cloud1.png'

# %% [markdown]
# > * Los profesores utilizaron una gran cantidad de descriptores para hablar de sus alumnos, por ejemplo: **"amazing"** (increíbles), **"awesome"** (maravillosos), **"incredible"** (fantásticos) y **"creative"** (creativos). Mientras tanto, en algunos ensayos, los maestros describen a sus estudiantes como **"muy especiales para ellos"** (*very special to them*) y **"extraordinarios"** (*remarkable*).
#
# ## <a id="8.2.4">8.2.4 Según lo descrito por los profesores, ¿Qué necesitan los estudiantes? (______ ______ ______)</a>

# %%
mystudents = []
for x in april18_df['clean_need']:
    if x.lower().strip().startswith("need"):
        phrase = " ".join(x.lower().strip().replace('need', '').split(". ")[0].split("!")[0].strip().split()[:3])
        mystudents.append(phrase)

t3 = Counter(mystudents).most_common(25)
x = [a[0] for a in t3]
y = [a[1] for a in t3]

sns.set_style("dark")
plt.figure(figsize = (12,10))
plt.title("Content of What Students Need")
bar = sns.barplot(y=x, x=y, palette="BuGn_r", edgecolor="white");
bar.set(xlabel='', xticks=[]);
axes[0].set_title("Top Keywords");
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'clean_need'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[123], line 2
#       1 mystudents = []
# ----> 2 for x in april18_df['clean_need']:
#       3     if x.lower().strip().startswith("need"):
#       4         phrase = " ".join(x.lower().strip().replace('need', '').split(". ")[0].split("!")[0].strip().split()[:3])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'clean_need'

# %% [markdown]
# > * Además de la necesidad principal sugerida por los profesores, es decir, las **"opciones de asientos flexibles"** (*Flexible seating options*), otras de las necesidades más destacadas son los **"robots de codificación"** (*Coding Robot*) y los **"útiles escolares básicos"** (*Basic School Supplies*). Dentro de los asientos flexibles, se centran principalmente en solicitar **"sillas tambaleantes"** (*Wobble Chairs*) y **"asientos de pelota de equilibrio"** (*Balance Ball Seats*). Otras necesidades relacionadas con la tecnología incluyen **"tabletas Amazon Fire"**, **"juegos de auriculares"** (*Headphones Set*) y el **"kit Osmo Genius"**.
#
# ## <a id="8.2.5">8.2.5 Título del Proyecto: Principales Palabras Utilizadas**</a>

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS  # <--- ¡Añadido para solucionar el NameError!

# Consolidar el texto de los títulos
text = " ".join(april18_df['Project Title']).lower()

# Eliminar ruido adicional específico de los títulos
for w in ['need', 'student', 'classroom']: 
    text = text.replace(w, " ")

# Configurar y generar la nube de palabras
# Nota: Asegúrate de que la variable 'mask' ya esté definida previamente en tu notebook, 
# de lo contrario, puedes remover el parámetro (mask=mask) para que genere una nube rectangular estándar.
wc = WordCloud(
    max_words=1200, 
    stopwords=STOPWORDS, 
    colormap='cool', 
    background_color='white', 
    mask=mask if 'mask' in locals() else None
).generate(text)

# Desplegar el gráfico
plt.figure(figsize=(13, 13))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.title('')
plt.show()

# %% [markdown]
# ## <a id="9">9. Comprensión y Comparación de las Características Clave de los Proyectos</a>
#
# ## <a id="9.1">9.1 Proyectos Expirados vs Proyectos Financiados</a>
#
# En esta sección, exploremos y comprendamos las características clave de los proyectos que lograron ser financiados con éxito y comparémoslos con aquellos que expiraron. Me enfocaré en los proyectos del año anterior, es decir, 2017.

# %%
# ... (Todo tu código anterior de la celda permanece igual hasta la parte de cost)

funded['binnedcost'] = pd.cut(funded['cost'], bins)
t2 = dict(funded['binnedcost'].value_counts())
labels = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t2.keys()] # Corregido t2
vals = [float(a)*100/sum(t2.values()) for a in list(t2.values())] # Corregido t2
d = {}
for i, v in enumerate(labels):
    d[v] = vals[i]
values = [d[v] for v in order]

tr16 = go.Scatter(
    x=order,
    y=values,
    name='Funded',fill='tozeroy',
    marker=dict(color='#0de286'),
    opacity=0.9)


############# CONFIGURACIÓN DEL SUBPLOT Y LAYOUT #############

titles = ['Project Grade Level Category', "School Metro Type","Project Cost (in $)", 
          "Project Essay Word Count", "Project Posted Month", "Resource Category"]

fig = tools.make_subplots(rows=3, cols=2, subplot_titles=titles, print_grid=False, 
                          specs=[[{}, {}], [{},{}], [{}, {}]]) 

fig.append_trace(tr1, 1,1)
fig.append_trace(tr2, 1,1)
fig.append_trace(tr3, 1,2)
fig.append_trace(tr4, 1,2)
fig.append_trace(tr15, 2,1)
fig.append_trace(tr16, 2,1)
fig.append_trace(tr13, 2,2)
fig.append_trace(tr14, 2,2)
fig.append_trace(tr7, 3,2)
fig.append_trace(tr8, 3,2)
fig.append_trace(tr9, 3,1)
fig.append_trace(tr10, 3,1)

# SOLÚCIÓN AL VALUERROR: Se unificó 'title' y 'titlefont' en la estructura moderna compatible
fig['layout'].update(
    barmode='group',
    title=dict(
        text='Key Project Features Comparison: <b>Expired Vs Funded Projects</b>',
        font=dict(
            size=22,
            color='#000'
        )
    ),
    margin=dict(t=100, b=100),
    paper_bgcolor='rgb(254, 247, 234)',
    plot_bgcolor='rgb(254, 247, 234)',
    height=1000
)

iplot(fig)

# %%
pos_text_cln = " ".join(funded['Project Title'])
neg_text_cln = " ".join(expired['Project Title'])

# Funciones personalizadas de color basadas en HSL
def green_color(word, font_size, position, orientation, random_state=None, **kwargs):
    return 'hsl({:d}, 80%, {:d}%)'.format(random.randint(85, 140), random.randint(30, 50)) # Ajustado el brillo para mejor legibilidad

def red_color(word, font_size, position, orientation, random_state=None, **kwargs):
    return 'hsl({:d}, 80%, {:d}%)'.format(random.randint(0, 35), random.randint(40, 60))

# SOLÚCIÓN AL FILENOTFOUNDERROR: Quitamos la máscara externa para evitar la caída del script
mask = None 

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=[16, 8], facecolor='#fef7ea')

# 1. Nube de palabras - Proyectos Expirados (Rojo)
wordcloud1 = WordCloud(
    max_words=1200,
    background_color='#fef7ea', 
    mask=mask
).generate(neg_text_cln)

# Aplicamos tu función red_color
wordcloud1.recolor(color_func=red_color)

ax1.imshow(wordcloud1, interpolation='bilinear')
ax1.axis('off')
ax1.set_title('Top Words - Expired Projects', fontsize=16, pad=10, weight='bold')

# 2. Nube de palabras - Proyectos Financiados (Verde)
wordcloud2 = WordCloud(
    max_words=1200,
    background_color='#fef7ea', 
    mask=mask
).generate(pos_text_cln)

# Aplicamos tu función green_color
wordcloud2.recolor(color_func=green_color)

ax2.imshow(wordcloud2, interpolation='bilinear')
ax2.axis('off')
ax2.set_title('Top Words - Funded Projects', fontsize=16, pad=10, weight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# > La comparación revela los siguientes hallazgos (*insights*):
# > * Los proyectos pertenecientes al nivel escolar de **Grades PreK-2** (Prejardín a 2do de primaria) tienen un mayor porcentaje de éxito que de expiración. En cambio, todas las demás categorías de grado presentan un porcentaje de proyectos expirados superior al de proyectos financiados con éxito. Es posible que los donantes prefieran **donar a los niños de grados menores** en comparación con los grados superiores.
# > * Los proyectos financiados con éxito registran un mayor porcentaje en escuelas ubicadas en **áreas urbanas**, mientras que los proyectos expirados muestran un mayor porcentaje en escuelas situadas en **áreas rurales, suburbanas o pueblos**.
# > * Otra característica de los proyectos financiados está relacionada con el costo del proyecto. Aquellos cuyo costo total es menor a USD 500 tienen un porcentaje muy alto de financiamiento exitoso, mientras que lo contrario también se cumple: un alto porcentaje de los proyectos que expiraron presentan costos más elevados, es decir, mayores a USD 500.
# > * Los ensayos del proyecto (*Project Essays*) son una parte esencial en DonorsChoose, y la cantidad de palabras utilizadas en el texto juega un rol importante en el resultado, tal como se observa en el cuarto gráfico: los proyectos financiados con éxito son más comunes cuando el **conteo de palabras del ensayo es mayor a 250**. Esto indica que se debe motivar a los profesores a escribir sobre sus proyectos de forma más exhaustiva y detallada.
# > * Una cantidad significativa de los proyectos publicados en el cuarto trimestre del año calendario (es decir, entre **octubre y diciembre**) logran financiarse con éxito en su mayoría. Esto señala un excelente periodo de tiempo en el que los donantes tienden a aportar más. Quizás los profesores que sientan que no están recibiendo donaciones en sus proyectos deberían comenzar a publicarlos en los meses de noviembre o diciembre. Todos los demás meses del año registran un mayor porcentaje de proyectos expirados que de financiados.
# > * Se observa un hallazgo interesante entre los proyectos que expiraron: un gran porcentaje de ellos requería insumos tecnológicos de alto costo, tales como **iPads, Chromebooks**, etc. Las categorías de recursos de **suministros (*supplies*) y tecnología (*technologies*)** concentran un número sumamente elevado de proyectos expirados.
# > * En todo Estados Unidos, son pocos los estados en los que el porcentaje de proyectos financiados supera al de proyectos expirados. Algunos de estos estados son **Illinois, Massachusetts y Oklahoma**. El porcentaje de proyectos expirados es mayor en el resto de los estados. Tal vez DonorsChoose podría incrementar sus campañas de marketing y correo electrónico para atraer a más donantes en esas regiones.
# > * Un mayor porcentaje de los proyectos financiados solicitaba **Asientos Flexibles (*Flexible Seating*) y Materiales de Lectura**, mientras que los proyectos expirados contaban con un alto porcentaje de **artículos relacionados con tecnología**.
#
#
# ## <a id="9.2">9.2 Proyectos con Corta vs Larga Duración de Financiamiento</a>
#
# Comparemos ahora las características de los proyectos que fueron financiados con éxito en un lapso corto (es decir, menos de 1 día) frente a aquellos proyectos que tardaron más de 2 meses en completarse.

# %%
# 1. Preparación de variables temporales
projects_df['time'] = projects_df['Funding Time'].apply(lambda x : str(x).split()[0])

tempdf = projects_df[projects_df['time'] != "NaT"].copy()
tempdf['time'] = tempdf['time'].apply(int)
tempdf = tempdf[tempdf['Posted Year'] == 2017]

df1 = tempdf[tempdf['time'] <= 1].copy() 
df2 = tempdf[tempdf['time'] >= 60].copy() 

df1 = df1.merge(teachers_df, on="Teacher ID")
df2 = df2.merge(teachers_df, on="Teacher ID")


# 2. Función generadora de trazos
def get_trace(col, func, flag=None, leg=False):
    t1 = df1[col].value_counts()
    t2 = df2[col].value_counts()

    if flag == 'num':
        t1 = df1[df1['NumProjects'] <= 20][col].value_counts()    
        t2 = df2[df2['NumProjects'] <= 20][col].value_counts() 
    
    trace1 = func(
        x=t1.index,
        y=[float(a)*100/sum(t1.values) for a in t1.values],
        name='Small Funding Duration',
        marker=dict(color='#0de286'),
        showlegend=leg,
        opacity=0.9
    )
    trace2 = func(
        x=t2.index,
        y=[float(a)*100/sum(t2.values) for a in t2.values],
        name='Large Funding Duration',
        marker=dict(color='#e82041'),
        opacity=0.9, 
        showlegend=leg
    )
    return trace1, trace2

tr1, tr2 = get_trace('Project Grade Level Category', go.Scatter)
tr3, tr4 = get_trace('School Metro Type', go.Scatter)
tr5, tr6 = get_trace('School State', go.Bar)
tr7, tr8 = get_trace('Project Resource Category', go.Bar)
tr9, tr10 = get_trace('Posted Month', go.Bar, leg=True)


####### Análisis de Conteo de Palabras (Word Count) #######
df1['wc'] = df1['Project Essay'].apply(lambda x : len(x.split()))
df2['wc'] = df2['Project Essay'].apply(lambda x : len(x.split()))

bins = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 10000]

# Subconjunto df1 (Duración Corta)
df1['wc'] = pd.cut(df1['wc'], bins)
t1 = dict(df1['wc'].value_counts())
labels1 = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t1.keys()]
vals1 = [float(a)*100/sum(t1.values()) for a in list(t1.values())]
d1 = {}
for i, v in enumerate(labels1):
    d1[v] = vals1[i]
order = ['0-50', '50-100', '100-150', '150-200', '200-250', '250-300', '300-350', '350-400', '400-450', '450-500', '500-10000']
values1 = [d1[v] for v in order]

tr13 = go.Bar(
    x=order, y=values1,
    name='Small Funding Duration',
    marker=dict(color='#0de286'), showlegend=False, opacity=0.9
)

# Subconjunto df2 (Duración Larga) - CORREGIDO: Se cambiaron las referencias de t1 a t2
df2['wc'] = pd.cut(df2['wc'], bins)
t2 = dict(df2['wc'].value_counts())
labels2 = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t2.keys()] # Corregido t2
vals2 = [float(a)*100/sum(t2.values()) for a in list(t2.values())] # Corregido t2
d2 = {}
for i, v in enumerate(labels2):
    d2[v] = vals2[i]
values2 = [d2[v] for v in order]

tr14 = go.Bar(
    x=order, y=values2,
    name='Large Funding Duration',
    marker=dict(color='#e82041'), showlegend=False, opacity=0.9
)


####### Análisis de Costos (Binned Cost) #######
bins_cost = [0, 100, 500, 1000, 1500, 2000, 2500, 3000, 70000]

# Costos df1
df1['binnedcost'] = pd.cut(df1['cost'], bins_cost)
tc1 = dict(df1['binnedcost'].value_counts())
labels_c1 = [str(b).replace("]","").replace("(","").replace(", ","-") for b in tc1.keys()]
vals_c1 = [float(a)*100/sum(tc1.values()) for a in list(tc1.values())]
dc1 = {}
for i, v in enumerate(labels_c1):
    dc1[v] = vals_c1[i]
order_cost = ['100-500', '500-1000', '1000-1500', '1500-2000', '2000-2500', '2500-3000', '3000-70000']
values_c1 = [dc1[v] for v in order_cost]

tr15 = go.Scatter(
    x=order_cost, y=values_c1,
    name='Small Funding Time', fill='tozeroy',
    marker=dict(color='#0de286'), showlegend=False, opacity=0.9
)

# Costos df2 - CORREGIDO: Se cambiaron las referencias de tc1 a tc2
df2['binnedcost'] = pd.cut(df2['cost'], bins_cost)
tc2 = dict(df2['binnedcost'].value_counts())
labels_c2 = [str(b).replace("]","").replace("(","").replace(", ","-") for b in tc2.keys()] # Corregido tc2
vals_c2 = [float(a)*100/sum(tc2.values()) for a in list(tc2.values())] # Corregido tc2
dc2 = {}
for i, v in enumerate(labels_c2):
    dc2[v] = vals_c2[i]
values_c2 = [dc2[v] for v in order_cost]

tr16 = go.Scatter(
    x=order_cost, y=values_c2,
    name='Large Funding Time', fill='tozeroy',
    marker=dict(color='#e82041'), showlegend=False, opacity=0.9
)


####### Inicialización de Subplots y Render #######
titles = ['Project Grade Level Category', "School Metro Type", "Project Cost (in $)", 
          "Project Essay Word Count", "Project Posted Month", "Resource Category"]

fig = tools.make_subplots(rows=3, cols=2, subplot_titles=titles, print_grid=False, 
                          specs=[[{}, {}], [{},{}], [{}, {}]]) 

fig.append_trace(tr1, 1,1)
fig.append_trace(tr2, 1,1)
fig.append_trace(tr3, 1,2)
fig.append_trace(tr4, 1,2)
fig.append_trace(tr15, 2,1)
fig.append_trace(tr16, 2,1)
fig.append_trace(tr13, 2,2)
fig.append_trace(tr14, 2,2)
fig.append_trace(tr7, 3,2)
fig.append_trace(tr8, 3,2)
fig.append_trace(tr9, 3,1)
fig.append_trace(tr10, 3,1)

# SOLÚCIÓN AL VALUERROR: Se estructuró el título de forma moderna en la propiedad 'title'
fig['layout'].update(
    barmode='group',
    title=dict(
        text='Key Project Features Comparison: <b>Projects with Small Vs Larger Funding Time</b>',
        font=dict(
            size=22,
            color='#000'
        )
    ),
    legend=dict(x=0.25, y=1.06, orientation="h"),
    margin=dict(t=100, b=100),
    paper_bgcolor='rgb(254, 247, 234)',
    plot_bgcolor='rgb(254, 247, 234)',
    height=1000
)

iplot(fig)

# %%
pos_text_cln = " ".join(df2['Project Title'])
neg_text_cln = " ".join(df1['Project Title'])

# Limpieza de ruido (remueve tanto mayúsculas como minúsculas)
noise = ['Learning', 'Student', 'Classroom']
for n in noise:
    pos_text_cln = pos_text_cln.replace(n, " ").replace(n.lower(), " ")
    neg_text_cln = neg_text_cln.replace(n, " ").replace(n.lower(), " ")
    
# Funciones de color personalizadas
def green_color(word, font_size, position, orientation, random_state=None, **kwargs):
    return 'hsl({:d}, 80%, {:d}%)'.format(random.randint(85, 140), random.randint(30, 50))

def red_color(word, font_size, position, orientation, random_state=None, **kwargs):
    return 'hsl({:d}, 80%, {:d}%)'.format(random.randint(0, 35), random.randint(40, 60))
    
# SOLUCIÓN AL FILE NOT FOUND: Desactivamos la máscara local
mask = None

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=[17, 8], facecolor='#fef7ea')

# 1. Nube de palabras - Tiempo de Financiamiento Corto (Rojo / Alerta / Rápido)
wordcloud1 = WordCloud(
    max_words=1200,
    background_color='#fef7ea',
    mask=mask
).generate(neg_text_cln)

# Aplicamos tu función de color para la primera nube
wordcloud1.recolor(color_func=red_color)

ax1.imshow(wordcloud1, interpolation='bilinear')
ax1.axis('off')
ax1.set_title('Top Words - Projects with Lower Funding Time', fontsize=15, pad=10, weight='bold')

# 2. Nube de palabras - Tiempo de Financiamiento Largo (Verde)
wordcloud2 = WordCloud(
    max_words=1200, 
    background_color='#fef7ea', 
    mask=mask
).generate(pos_text_cln)

# Aplicamos tu función de color para la segunda nube
wordcloud2.recolor(color_func=green_color)

ax2.imshow(wordcloud2, interpolation='bilinear')
ax2.axis('off')
ax2.set_title('Top Words - Projects with Higher Funding Time', fontsize=15, pad=10, weight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# > La comparación revela los siguientes hallazgos (*insights*):
# > * Podemos observar que los proyectos que lograron ser financiados con éxito en un día o menos pertenecen con mayor frecuencia a los niveles escolares de **Grades 6-12** (Grados de 6to a 12vo). Por el contrario, un mayor porcentaje de los proyectos que tardaron más tiempo en completar sus donaciones corresponden a los grados menores.
# > * Las **áreas suburbanas** registraron un mayor porcentaje de proyectos completados en lapsos de tiempo más cortos en comparación con cualquier otro tipo de zona escolar.
# > * Como es de esperarse, los proyectos con un costo total menor (es decir, menos de USD 500) tienen mayores probabilidades de cerrarse o financiarse en muy poco tiempo a diferencia de los proyectos que requieren montos más altos. Esto mismo se puede apreciar en los gráficos.
# > * En los proyectos que se financiaron en menos de un día, los profesores utilizaron una cantidad relativamente **mayor de palabras** (es decir, más de 250) en sus ensayos. Para los proyectos con ensayos que tenían menos de 500 palabras, se observó una mayor proporción de proyectos financiados en lapsos de tiempo más largos.
# > * Una mayor cantidad de los proyectos publicados en los meses de **febrero, marzo, agosto y octubre** se financiaron con éxito en un periodo corto, mientras que el mayor porcentaje de proyectos financiados a largo plazo se observó en los meses de diciembre y septiembre.
#
# ## <a id="9.3">9.3 Proyectos con un Solo Donante vs Múltiples Donantes</a>
#
# Comparemos ahora las características de los proyectos que fueron financiados por un único donante (*single donor*) frente a aquellos que requirieron la colaboración de más de diez donantes (*more than ten donors*).

# %%
num_donations = donations_df.groupby('Project ID').agg({'Donation ID' : 'count'}).reset_index().rename(columns={'Donation ID' : 'NumDonations'})
tempdf = projects_df.merge(num_donations, on="Project ID")
df1 = tempdf[tempdf['Posted Year'] == 2017][tempdf['NumDonations'] == 1] 
df2 = tempdf[tempdf['Posted Year'] == 2017][tempdf['NumDonations'] > 10] 
df1 = df1.merge(teachers_df, on="Teacher ID")
df2 = df2.merge(teachers_df, on="Teacher ID")

def get_trace(col, func, flag=None, leg=False):

    t1 = df1[col].value_counts()
    t2 = df2[col].value_counts()

    if flag == 'num':
        t1 = df1[df1['NumProjects'] <= 20][col].value_counts()    
        t2 = df2[df2['NumProjects'] <= 20][col].value_counts() 
    
    trace1 = func(
        x=t1.index,
        y=[float(a)*100/sum(t1.values) for a in t1.values],
        name='Single Donors',
        marker=dict(color='#0de286'),
        showlegend=leg,
        opacity=0.9
    )
    trace2 = func(
        x=t2.index,
        y=[float(a)*100/sum(t2.values) for a in t2.values],
        name='Multiple Donors',
        marker=dict(color='#e82041'),
        opacity=0.9, 
        showlegend=leg
    )
    return trace1, trace2

tr1, tr2 = get_trace('Project Grade Level Category', go.Scatter)
tr3, tr4 = get_trace('School Metro Type', go.Scatter)
tr5, tr6 = get_trace('School State', go.Bar)
tr7, tr8 = get_trace('Project Resource Category', go.Bar)
tr9, tr10 = get_trace('Posted Month', go.Bar, leg=True)


########################
df1['wc'] = df1['Project Essay'].apply(lambda x : len(x.split()))
df2['wc'] = df2['Project Essay'].apply(lambda x : len(x.split()))

bins = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 10000]

df1['wc'] = pd.cut(df1['wc'], bins)
t1 = dict(df1['wc'].value_counts())
labels = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t1.keys()]
vals = [float(a)*100/sum(t1.values()) for a in list(t1.values())]
d = {}
for i, v in enumerate(labels):
    d[v] = vals[i]
order = ['0-50', '50-100', '100-150', '150-200', '200-250', '250-300', '300-350', '350-400', '400-450', '450-500', '500-10000',]
values = [d[v] for v in order]

tr13 = go.Bar(
    x=order,
    y=values,
    name='Single Donors',
    marker=dict(color='#0de286'),showlegend=False,
    opacity=0.9
)


df2['wc'] = pd.cut(df2['wc'], bins)
t2 = dict(df2['wc'].value_counts())
labels = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t1.keys()]
vals = [float(a)*100/sum(t2.values()) for a in list(t2.values())]
d = {}
for i, v in enumerate(labels):
    d[v] = vals[i]
order = ['0-50', '50-100', '100-150', '150-200', '200-250', '250-300', '300-350', '350-400', '400-450', '450-500', '500-10000',]
values = [d[v] for v in order]

tr14 = go.Bar(
    x=order,
    y=values,
    name='Multiple Donors',
    marker=dict(color='#e82041'),showlegend=False,
    opacity=0.9
)



############### cost ###########
bins = [0, 100, 500, 1000, 1500, 2000, 2500, 3000, 70000]

df1['binnedcost'] = pd.cut(df1['cost'], bins)
t1 = dict(df1['binnedcost'].value_counts())
labels = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t1.keys()]
vals = [float(a)*100/sum(t1.values()) for a in list(t1.values())]
d = {}
for i, v in enumerate(labels):
    d[v] = vals[i]
order = ['100-500', '500-1000', '1000-1500', '1500-2000', '2000-2500', '2500-3000', '3000-70000']
values = [d[v] for v in order]

tr15 = go.Scatter(
    x=order,
    y=values,
    name='Single Donors',fill='tozeroy',
    marker=dict(color='#0de286'),showlegend=False,
    opacity=0.9
)


df2['binnedcost'] = pd.cut(df2['cost'], bins)
t2 = dict(df2['binnedcost'].value_counts())
labels = [str(b).replace("]","").replace("(","").replace(", ","-") for b in t1.keys()]
vals = [float(a)*100/sum(t2.values()) for a in list(t2.values())]
d = {}
for i, v in enumerate(labels):
    d[v] = vals[i]
values = [d[v] for v in order]

tr16 = go.Scatter(
    x=order,
    y=values,
    name='Multiple Donors',fill='tozeroy',
    marker=dict(color='#e82041'),showlegend=False,

    opacity=0.9)



#############


titles = ['Project Grade Level Category', "School Metro Type","Project Cost (in $)", 
          "Project Essay Word Count", "Project Posted Month", "Resource Category"]
fig = tools.make_subplots(rows=3, cols=2, subplot_titles=titles, print_grid=False, specs=[[{}, {}],
                                                                  [{},{}], 
                                                                  [{}, {}],]) 
#                                                                   [{'colspan':2}, None],
#                                                                   [{}, None]
fig.append_trace(tr1, 1,1)
fig.append_trace(tr2, 1,1)
fig.append_trace(tr3, 1,2)
fig.append_trace(tr4, 1,2)
fig.append_trace(tr15, 2,1)
fig.append_trace(tr16, 2,1)
fig.append_trace(tr13, 2,2)
fig.append_trace(tr14, 2,2)
fig.append_trace(tr7, 3,2)
fig.append_trace(tr8, 3,2)
fig.append_trace(tr9, 3,1)
fig.append_trace(tr10, 3,1)

fig['layout'].update(
    barmode='group',
    # SOLUCIÓN: Agrupamos 'text' y 'font' dentro del diccionario 'title'
    title=dict(
        text='Key Project Features Comparison: <b>Projects with Single Vs Multiple Donors</b>',
        font=dict(
            size=22,
            color='#000'
        )
    ),
    legend=dict(x=0.25, y=1.06, orientation="h"),
    margin=dict(t=100, b=100),
    paper_bgcolor='rgb(254, 247, 234)',
    plot_bgcolor='rgb(254, 247, 234)',
    height=1000
)

iplot(fig);

# %%
# Asegurar la extracción de strings limpios
pos_text_cln = " ".join(df2['Project Title'])
neg_text_cln = " ".join(df1['Project Title'])

# Limpieza de ruido (remueve variaciones con mayúsculas y minúsculas)
noise = ['Learning', 'Student', 'Classroom', 'Need']
for n in noise:
    pos_text_cln = pos_text_cln.replace(n, " ").replace(n.lower(), " ")
    neg_text_cln = neg_text_cln.replace(n, " ").replace(n.lower(), " ")
    
# Funciones de color personalizadas HSL
def green_color(word, font_size, position, orientation, random_state=None, **kwargs):
    return 'hsl({:d}, 80%, {:d}%)'.format(random.randint(85, 140), random.randint(30, 50))

def red_color(word, font_size, position, orientation, random_state=None, **kwargs):
    return 'hsl({:d}, 80%, {:d}%)'.format(random.randint(0, 35), random.randint(40, 60))
    
# SOLÚCIÓN: Desactivamos la máscara externa para evitar el FileNotFoundError local
mask = None

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=[17, 8], facecolor='#fef7ea')

# 1. Nube de palabras - Proyectos con Un Solo Donante (Rojo)
wordcloud1 = WordCloud(
    max_words=1200,
    background_color='#fef7ea',
    mask=mask
).generate(neg_text_cln)

# Forzamos la aplicación de tu paleta roja
wordcloud1.recolor(color_func=red_color)

ax1.imshow(wordcloud1, interpolation='bilinear')
ax1.axis('off')
ax1.set_title('Top Words - Projects with Single Donors', fontsize=15, pad=10, weight='bold')

# 2. Nube de palabras - Proyectos con Múltiples Donantes (Verde)
wordcloud2 = WordCloud(
    max_words=1200, 
    background_color='#fef7ea', 
    mask=mask
).generate(pos_text_cln)

# Forzamos la aplicación de tu paleta verde
wordcloud2.recolor(color_func=green_color)

ax2.imshow(wordcloud2, interpolation='bilinear')
ax2.axis('off')
ax2.set_title('Top Words - Projects with Multiple Donors', fontsize=15, pad=10, weight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# > * Con base en los gráficos y comparaciones anteriores, podemos destacar los siguientes puntos: <br><br>
# >
# > * Un mayor porcentaje de los proyectos en los que donó un **solo donante** presentó las siguientes características:
# >   * Pertenecer a los grados **PreK-2**, haber sido publicados por escuelas en **Áreas Urbanas**, tener costos de proyecto más bajos, contar con ensayos donde los profesores utilizaron **pocas palabras** (es decir, menos de 250), haber sido publicados en los meses de **septiembre, octubre y diciembre**, y tratar principalmente sobre **Libros** (*Books*).
# > * Un mayor porcentaje de los proyectos en los que donaron **múltiples donantes** presentó las siguientes características:
# >   * Pertenecer a grados más altos, es decir, niveles de **Grado del 3 al 12**, haber sido publicados por escuelas en **áreas suburbanas y rurales**, registrar un costo de proyecto **mayor a USD 500**, contar con una mayor cantidad de palabras utilizadas en los ensayos del proyecto, y estar relacionados con **Tecnología y Suministros** (*Technologies and Supplies*).

# %% [markdown]
# ## <a id="9.4">Conclusión</a>
#
# A partir del análisis exploratorio realizado sobre los proyectos publicados, donaciones, profesores, escuelas y recursos, se identificaron varios patrones relevantes dentro de la plataforma. Los proyectos con mayor cantidad de donaciones y mayor financiamiento muestran que ciertos tipos de necesidades educativas tienen una mayor capacidad de atraer apoyo. Asimismo, se observó que factores como la ubicación geográfica, el tipo de escuela y las características de los donantes influyen en la distribución de las contribuciones.
#
# El análisis temporal permitió identificar tendencias en la publicación y financiación de proyectos, mostrando diferencias según meses, días y años. Además, el estudio de categorías y recursos reveló cuáles son las áreas educativas más solicitadas y qué materiales representan una mayor demanda o inversión.
#
# Finalmente, mediante el análisis de texto de las descripciones de los proyectos se encontraron palabras y frases frecuentes utilizadas por los profesores, lo que permite comprender mejor las principales necesidades expresadas por las escuelas. En conjunto, estos resultados ayudan a entender los factores que influyen en la creación, difusión y éxito de los proyectos educativos dentro de la plataforma.
